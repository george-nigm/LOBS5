# %%
# %cd /app
# Out:
# /app

# %%
import argparse
import os
import sys

os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

import torch
torch.multiprocessing.set_start_method('spawn')

import jax
from lob.encoding import Vocab, Message_Tokenizer

from lob import inference_no_errcorr as inference
from lob.init_train import init_train_state, load_checkpoint, load_metadata, load_args_from_checkpoint

from lob import inference_no_errcorr as inference
import lob.encoding as encoding
import preproc as preproc

import jax.numpy as jnp
import numpy as np

from pathlib import Path
import os

import pandas as pd
import plotly.graph_objs as go
import yaml

from filtration_utils import summary_table, build_zero_padded_series, plot_midprice_series_with_insertions, prepare_volatility_filtered_series, plot_midprice_series_with_mean_std
# Out:
# 2025-08-12 13:13:04.819111: W external/xla/xla/service/gpu/nvptx_compiler.cc:718] The NVIDIA driver's CUDA version is 12.8 which is older than the ptxas CUDA version (12.9.41). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# WARNING:absl:Type handler registry overriding type "<class 'float'>" collision on scalar
# WARNING:absl:Type handler registry overriding type "<class 'bytes'>" collision on scalar
# WARNING:absl:Type handler registry overriding type "<class 'numpy.number'>" collision on scalar
# 2025-08-12 13:13:08.094510: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
experiment_name = 'exp_43_20250809_085521'  #      exp_24_20250805_101039_gen_buy_whole_55


CONFIG_PATH = f"/app/data_saved/{experiment_name}/used_config.yaml"

# Load YAML config
with open(CONFIG_PATH, 'r') as f:
    config = yaml.safe_load(f)

# Extract values
num_insertions      = config["num_insertions"]
num_coolings        = config["num_coolings"]
midprice_step_size  = config["midprice_step_size"]
hist_msgs           = config["n_messages"]
n_gen_msgs          = config["n_gen_msgs"]
Direction           = config["DIRECTION_i"]

print(f"Aggressive {'buy' if Direction == 0 else 'sell'}\n")
print(f'num_insertions: {num_insertions}')
print(f'num_coolings: {num_coolings}')
print(f'midprice_step_size: {midprice_step_size}')
print(f'hist_msgs: {hist_msgs}')
print(f'n_gen_msgs: {n_gen_msgs}')
# Out:
# Aggressive buy
#
# num_insertions: 20
# num_coolings: 30
# midprice_step_size: 1
# hist_msgs: 500
# n_gen_msgs: 50

# %%
# order_volume = config["order_volume"]
# order_volume_ratio = config["order_volume_ratio"]
# use_relative_volume = config["use_relative_volume"]

# print(f'use_relative_volume: {use_relative_volume}')
# print(f'order_volume: {order_volume}')
# print(f'order_volume_ratio: {order_volume_ratio}')

# use_sample_file = config["use_sample_file"]
# sample_file_path = config["sample_file_path"]
# start_batch = config["start_batch"]
# end_batch = config["end_batch"]

# print(f'\nuse_sample_file: {use_sample_file}')
# print(f'sample_file_path: {sample_file_path}')
# print(f'start_batch: {start_batch}')
# print(f'end_batch: {end_batch}')

# %%
hist_steps = hist_msgs // midprice_step_size       # 500
gen_steps = n_gen_msgs // midprice_step_size     # 50
gen_block = gen_steps + 1                        # 51

merged = summary_table(experiment_name)
x, all_series = build_zero_padded_series(hist_msgs, n_gen_msgs, midprice_step_size, merged)

print(merged)
# Out:
#        id                                        merged_data
# 0      69  [898300, 898300, 898300, 898300, 898300, 89830...
# 1      97  [902800, 902800, 902800, 902800, 902800, 90280...
# 2     140  [905500, 905500, 905500, 905500, 905500, 90550...
# 3     220  [903700, 903700, 903700, 903700, 903700, 90370...
# 4     275  [907900, 907900, 907900, 907900, 907900, 90790...
# ..    ...                                                ...
# 163  6936  [890800, 890800, 890800, 890800, 890800, 89080...
# 164  6991  [890500, 890500, 890500, 890500, 890500, 89050...
# 165  7009  [890100, 890100, 890100, 890100, 890100, 89010...
# 166  7098  [888300, 888300, 888300, 888400, 888400, 88840...
# 167  7187  [886700, 886800, 886800, 886800, 886800, 88680...
#
# [168 rows x 2 columns]

# %%
fig = plot_midprice_series_with_insertions(
    merged,
    all_series,
    x,
    hist_steps,
    gen_block,
    num_insertions,
    num_coolings,
    n_gen_msgs,
    midprice_step_size
)
fig.show()
# Out:
# insertion positions: [551, 602, 653, 704, 755, 806, 857, 908, 959, 1010, 1061, 1112, 1163, 1214, 1265, 1316, 1367, 1418, 1469, 1520]
# cooling positions:   [1570, 1620, 1670, 1720, 1770, 1820, 1870, 1920, 1970, 2020, 2070, 2120, 2170, 2220, 2270, 2320, 2370, 2420, 2470, 2520, 2570, 2620, 2670, 2720, 2770, 2820, 2870, 2920, 2970, 3020]

# %%
x, all_series, merged, hist_steps, gen_block = prepare_volatility_filtered_series(merged, hist_msgs, n_gen_msgs, midprice_step_size, volatility_cutoff=0.3)

# %%
fig, mean_series, std_series = plot_midprice_series_with_mean_std(
    merged=merged,
    all_series=all_series,
    x=x,
    hist_steps=hist_steps,
    gen_block=gen_block,
    num_insertions=num_insertions,
    num_coolings=num_coolings,
    n_gen_msgs=n_gen_msgs,
    midprice_step_size=midprice_step_size,
)
fig.show()
# Out:
# insertion positions: [551, 602, 653, 704, 755, 806, 857, 908, 959, 1010, 1061, 1112, 1163, 1214, 1265, 1316, 1367, 1418, 1469, 1520]
# cooling positions:   [1570, 1620, 1670, 1720, 1770, 1820, 1870, 1920, 1970, 2020, 2070, 2120, 2170, 2220, 2270, 2320, 2370, 2420, 2470, 2520, 2570, 2620, 2670, 2720, 2770, 2820, 2870, 2920, 2970, 3020]

# %%
# np.save("/app/data_saved/exp_96_20250703_212149/exp_96_20250703_212149_mean.npy", mean_series)
# np.save("/app/data_saved/exp_96_20250703_212149/exp_96_20250703_212149_std.npy", std_series)

# %% [markdown]
# # ----------------------------------------------------

# %% [markdown]
# # OREDER-PLAYER

# %%
import os, glob, re
import numpy as np
import pandas as pd

def build_and_merge(folder, batch_prefix, inp_prefix):
    # STEP 1: load every .npy (shape (batch_size, time, feat)) into a DataFrame
    files   = glob.glob(os.path.join(folder, "*.npy"))
    rx_iter = re.compile(rf"{re.escape(batch_prefix)}_\[(.+)\]_iter_(\d+)\.npy$")
    rx_inp  = re.compile(rf"{re.escape(inp_prefix)}_\[(.+)\]\.npy$")
    rec = []
    for f in files:
        nm = os.path.basename(f)
        m  = rx_iter.match(nm)
        if m:
            rng, itr = m.group(1).replace(" ", ""), int(m.group(2))
        else:
            m2 = rx_inp.match(nm)
            if not m2:
                continue
            rng, itr = m2.group(1).replace(" ", ""), 0

        batch = np.load(f)  # shape (batch_size, time, features)
        print(f"Loaded {nm} with shape {batch.shape}")

        rec.append({"range": rng, "iteration": itr, "batch": batch})
    df = pd.DataFrame(rec).sort_values(["range","iteration"]).reset_index(drop=True)

    # STEP 2: parse the comma‐separated list of IDs into Python lists
    df["ids"] = df["range"].str.split(",").apply(lambda L: [int(x) for x in L])

    # explode each batch into one row per sample, с учётом slicing
    rows = []
    for _, r in df.iterrows():
        for idx, sample_id in enumerate(r["ids"]):
            single = r["batch"][idx]   # shape (time, features)

            # ====== здесь происходит нужный slice ======
            if r["iteration"] > 0:
                n_keep = 51 if r["iteration"] <= num_insertions else 50
                single = single[-n_keep:, :]
            # ============================================

            rows.append({
                "id":        sample_id,
                "iteration": r["iteration"],
                "data":      single
            })

    df_sorted = pd.DataFrame(rows).sort_values(["id","iteration"]).reset_index(drop=True)

    merged = []
    for id_val, grp in df_sorted.groupby("id", sort=True):
        arrs = [row.data for _, row in grp.iterrows()]
        big  = np.concatenate(arrs, axis=0)
        merged.append({"id": id_val, "merged_data": big})
    merged_df = pd.DataFrame(merged).sort_values("id").reset_index(drop=True)

    return df, df_sorted, merged_df

b_folder      = f"/app/data_saved/{experiment_name}/b_seq_gen_doubled"
b_batch_pref  = "b_seq_gen_doubled_batch"
b_inp_pref    = "b_seq_inp"

m_folder      = f"/app/data_saved/{experiment_name}/msgs_decoded_doubled"
m_batch_pref  = "msgs_decoded_doubled_batch"
m_inp_pref    = "m_seq_raw_inp"

_, b_sorted, b_merged = build_and_merge(b_folder, b_batch_pref, b_inp_pref)
_, m_sorted, m_merged = build_and_merge(m_folder, m_batch_pref, m_inp_pref)

b_dict = { int(r.id): np.array(r.merged_data) for _, r in b_merged.iterrows() }
m_dict = { int(r.id): np.array(r.merged_data) for _, r in m_merged.iterrows() }

for d in (b_dict, m_dict):
    for key, arr in d.items():
        zero = np.zeros((1, arr.shape[1]), dtype=arr.dtype)
        d[key] = np.vstack([zero, arr])
# Out:
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[1652, 6865, 3808, 6681].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_inp_[453, 3952, 4972, 6029].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[865, 1225, 5874, 5305].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[140, 4708, 1141, 5951].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[6866, 6936, 2681, 6698].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_inp_[5580, 220, 4907, 2025].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[1928, 2921, 461, 97].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[1833, 6991, 5093, 899].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[5964, 4470, 3909, 6469].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[3683, 6629, 1469, 5105].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_42.npy with shape (4, 500, 501)
# ...
# Loaded msgs_decoded_doubled_batch_[6931, 4464, 4402, 2408]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_44.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_31.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6372, 3567, 1479, 3127]_iter_44.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1833, 6991, 5093, 899]_iter_7.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2640, 4030, 1086, 2674]_iter_13.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3948, 69, 5452, 1947]_iter_18.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3600, 2758, 4892, 2560]_iter_15.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3398, 945, 3019, 1832]_iter_22.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6931, 4464, 4402, 2408]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_47.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6931, 4464, 4402, 2408]_iter_5.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1833, 6991, 5093, 899]_iter_13.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1928, 2921, 461, 97]_iter_48.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3374, 2414, 3786, 879]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2087, 3994, 414, 2821]_iter_2.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6372, 3567, 1479, 3127]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6372, 3567, 1479, 3127]_iter_43.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5527, 4242, 1062, 4386]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_29.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5499, 339, 4819, 797]_iter_14.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6372, 3567, 1479, 3127]_iter_1.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1833, 6991, 5093, 899]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[410, 4610, 3384, 3588]_iter_7.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2087, 3994, 414, 2821]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1928, 2921, 461, 97]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_29.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1833, 6991, 5093, 899]_iter_36.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_5.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2640, 4030, 1086, 2674]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1638, 2934, 1548, 2634]_iter_24.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5527, 4242, 1062, 4386]_iter_26.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[865, 1225, 5874, 5305]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5499, 339, 4819, 797]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5527, 4242, 1062, 4386]_iter_37.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_32.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_22.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3398, 945, 3019, 1832]_iter_14.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1928, 2921, 461, 97]_iter_14.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6931, 4464, 4402, 2408]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_37.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2640, 4030, 1086, 2674]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_17.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_2.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_26.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3803, 1404, 4513, 3763]_iter_29.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[865, 1225, 5874, 5305]_iter_31.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_39.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2029, 5967, 5558, 3773]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5905, 6920, 2417, 2757]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_41.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2640, 4030, 1086, 2674]_iter_1.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1638, 2934, 1548, 2634]_iter_50.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_28.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_22.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[975, 6842, 5118, 5252]_iter_34.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1652, 6865, 3808, 6681]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[865, 1225, 5874, 5305]_iter_3.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2649, 1217, 5285, 1579]_iter_32.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5499, 339, 4819, 797]_iter_43.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1652, 6865, 3808, 6681]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_15.npy with shape (4, 51, 14)
# Loaded m_seq_raw_inp_[5905, 6920, 2417, 2757].npy with shape (4, 500, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_3.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5905, 6920, 2417, 2757]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5499, 339, 4819, 797]_iter_10.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3374, 2414, 3786, 879]_iter_14.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5527, 4242, 1062, 4386]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5905, 6920, 2417, 2757]_iter_2.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1652, 6865, 3808, 6681]_iter_47.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3803, 1404, 4513, 3763]_iter_20.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1833, 6991, 5093, 899]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_50.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_17.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_19.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3803, 1404, 4513, 3763]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6031, 5446, 739, 4418]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_33.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[410, 4610, 3384, 3588]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_19.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_7.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_41.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3948, 69, 5452, 1947]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3398, 945, 3019, 1832]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_45.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_40.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3398, 945, 3019, 1832]_iter_27.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5580, 220, 4907, 2025]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1833, 6991, 5093, 899]_iter_22.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[865, 1225, 5874, 5305]_iter_24.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_26.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_43.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1638, 2934, 1548, 2634]_iter_34.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[453, 3952, 4972, 6029]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5527, 4242, 1062, 4386]_iter_39.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5905, 6920, 2417, 2757]_iter_34.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[865, 1225, 5874, 5305]_iter_4.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1928, 2921, 461, 97]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6540, 5120, 5066, 5127]_iter_1.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6372, 3567, 1479, 3127]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6031, 5446, 739, 4418]_iter_31.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_39.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_31.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5964, 4470, 3909, 6469]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5964, 4470, 3909, 6469]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_5.npy with shape (4, 51, 14)
# Loaded m_seq_raw_inp_[869, 5837, 2713, 5383].npy with shape (4, 500, 14)
# Loaded msgs_decoded_doubled_batch_[4238, 275, 2107, 4834]_iter_32.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6031, 5446, 739, 4418]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_9.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_34.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3948, 69, 5452, 1947]_iter_44.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5964, 4470, 3909, 6469]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2087, 3994, 414, 2821]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_40.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6031, 5446, 739, 4418]_iter_36.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5317, 2178, 3859, 1730]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_18.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_32.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3600, 2758, 4892, 2560]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1652, 6865, 3808, 6681]_iter_7.npy with shape (4, 51, 14)
# Loaded m_seq_raw_inp_[1928, 2921, 461, 97].npy with shape (4, 500, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_47.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_33.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_40.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2029, 5967, 5558, 3773]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5580, 220, 4907, 2025]_iter_26.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3948, 69, 5452, 1947]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[4238, 275, 2107, 4834]_iter_39.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5317, 2178, 3859, 1730]_iter_41.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6931, 4464, 4402, 2408]_iter_22.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_1.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_45.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[4238, 275, 2107, 4834]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5317, 2178, 3859, 1730]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_3.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3600, 2758, 4892, 2560]_iter_18.npy with shape (4, 51, 14)

# %%
import numpy as np
import pandas as pd
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import ipywidgets as widgets
from IPython.display import display

def interactive_lob_plot(b_seq_inp, msg_seq_raw):
    # allow DataFrame or dict
    if isinstance(b_seq_inp, pd.DataFrame):
        b_seq_inp = {int(r.id): np.array(r.merged_data) for _,r in b_seq_inp.iterrows()}
    if isinstance(msg_seq_raw, pd.DataFrame):
        msg_seq_raw = {int(r.id): np.array(r.merged_data) for _,r in msg_seq_raw.iterrows()}

    # controls
    id_dd       = widgets.Dropdown(options=sorted(b_seq_inp.keys()), description="Sample ID:")
    time_slider = widgets.IntSlider(min=1, max=1, step=1, description="t:")
    btn_prev    = widgets.Button(description="←")
    btn_next    = widgets.Button(description="→")
    msg_box     = widgets.HTML()

    # figure with two subplots
    fig = make_subplots(rows=1, cols=2, subplot_titles=["Book state t–1","Book state t"])
    fig.add_trace(go.Bar(x=[],y=[]), row=1,col=1)
    fig.add_trace(go.Bar(x=[],y=[]), row=1,col=2)
    fig.update_layout(width=800, height=400, showlegend=False, template='plotly_white')
    fig_widget = go.FigureWidget(fig)

    def update_slider_range(*_):
        arr = b_seq_inp[id_dd.value]
        
        time_slider.min = 1
        time_slider.max = arr.shape[0] - 1
        time_slider.value = 1

    def update_plot(*_):
        sid = id_dd.value
        t   = time_slider.value
        arr = b_seq_inp[sid]
        msgs= msg_seq_raw[sid]

        
        s0 = arr[t-1, 240:263]
        s1 = arr[t,   240:263]

        diff = abs(s1) - abs(s0)
        x = np.arange(len(s0)) - len(s0)//2

        with fig_widget.batch_update():
            fig_widget.data = []
            fig_widget.add_bar(x=x, y=s0, row=1, col=1, marker_color='orange')
            
            colors = ['orange' if abs(d)<1e-8 else ('red' if d>0 else 'blue') for d in diff]
                        
            fig_widget.add_bar(x=x, y=s1, row=1, col=2, marker_color=colors)
            fig_widget.layout.annotations[0].text = f"Book state {t-1}"
            fig_widget.layout.annotations[1].text = f"Book state {t}"

        # show message at index t
        m = msgs[t].astype(int)
        # fields: [0]=timestamp, [1]=etype, [2]=dir, [3]=abspr, [4]=relpr, [5]=size, …
        et, dr, abspr, relpr, sz = m[1], m[2], m[3], m[4], m[5]
        et_map = {1:"Limit",2:"PartialCancel",3:"Delete",4:"Execution"}
        dr_map = {1:"Buy",0:"Sell"}
        info = (
            f"{et_map.get(et,'?')} • "
            f"{dr_map.get(dr,'?')} • "
            f"abs={abspr} • rel={relpr} • size={sz}"
        )
        msg_box.value = f"<b>{info}<br></b>raw:{m.tolist()}"

    def on_prev(b):
        if time_slider.value>time_slider.min:
            time_slider.value -= 1
    def on_next(b):
        if time_slider.value<time_slider.max:
            time_slider.value += 1

    # wire up events
    id_dd.observe(lambda c: update_slider_range(), names='value')
    time_slider.observe(lambda c: update_plot(), names='value')
    btn_prev.on_click(on_prev)
    btn_next.on_click(on_next)

    # initial draw
    update_slider_range()
    update_plot()

    display(widgets.HBox([id_dd, btn_prev, btn_next, time_slider]))
    display(fig_widget, msg_box)


interactive_lob_plot(b_dict, m_dict)
# Out:
# HBox(children=(Dropdown(description='Sample ID:', options=(69, 97, 140, 220, 275, 339, 346, 410, 414, 453, 461…
# FigureWidget({
#     'data': [{'marker': {'color': 'orange'},
#               'type': 'bar',
#               'uid': '447b03c9-6b64-4bc9-9a98-705cd93d5726',
#               'x': {'bdata': '9fb3+Pn6+/z9/v8AAQIDBAUGBwgJCgs=', 'dtype': 'i1'},
#               'xaxis': 'x',
#               'y': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA' ... 'AAAAAAAAAAAAAAAAAAAAAAAAAAAAA='),
#                     'dtype': 'f4'},
#               'yaxis': 'y'},
#              {'marker': {'color': [red, red, red, red, red, red, red, red, red,
#                                    red, orange, orange, red, orange, red, red, red,
#                                    red, red, red, red, red, red]},
#               'type': 'bar',
#               'uid': '14cc731d-7b7d-48ca-a45d-ebd3fe9b870e',
#               'x': {'bdata': '9fb3+Pn6+/z9/v8AAQIDBAUGBwgJCgs=', 'dtype': 'i1'},
#               'xaxis': 'x2',
#               'y': {'bdata': ('XY+CPhWuhz4shzY/E4PAPqjGiz4AAI' ... 'C+AACAvjQzs77c+f6+4E+Nvjq0KL8='),
#                     'dtype': 'f4'},
#               'yaxis': 'y2'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Book state 0',
#                                 'x': 0.225,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Book state 1',
#                                 'x': 0.775,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 400,
#                'showlegend': False,
#                'template': '...',
#                'width': 800,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 0.45]},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.55, 1.0]},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0]},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.0, 1.0]}}
# })
# HTML(value='<b>Limit • Buy • abs=897700 • rel=-6 • size=22<br></b>raw:[34998638, 1, 1, 897700, -6, 22, 0, 0, 3…

# %%
def show_execution_indices(m_dict):
    """
    For each sample_id in m_dict, prints indices t where etype == 4 (Execution).
    """
    for sid, msgs in m_dict.items():
        etypes = msgs[:, 1]
        exec_indices = np.where(etypes == 4)[0]
        if len(exec_indices) > 0:
            print(f"Sample ID {sid}: Execution at indices {exec_indices.tolist()}")
        else:
            print(f"Sample ID {sid}: No Executions found")

show_execution_indices(m_dict)
# Out:
# Sample ID 69: Execution at indices [13, 14, 112, 131, 551, 602, 624, 625, 626, 627, 653, 675, 676, 677, 678, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1032, 1033, 1034, 1035, 1061, 1083, 1084, 1085, 1086, 1112, 1163, 1185, 1186, 1187, 1188, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1642, 1643, 1644, 1645, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895, 1942, 1943, 1944, 1945, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2192, 2193, 2194, 2195, 2292, 2293, 2294, 2295, 2342, 2343, 2344, 2345, 2464, 2492, 2493, 2494, 2495, 2497, 2514, 2542, 2543, 2544, 2545, 2547, 2564, 2566, 2592, 2593, 2594, 2595, 2597, 2614, 2616, 2620, 2642, 2643, 2644, 2645, 2742, 2743, 2744, 2745, 2747, 2764, 2792, 2793, 2794, 2795, 2797, 2814, 2816, 2820, 2842, 2843, 2844, 2845, 2847, 2864, 2866, 2914, 2964, 2966, 2992, 2993, 2994, 2995, 2997, 3014, 3016]
# Sample ID 97: Execution at indices [181, 315, 336, 341, 468, 551, 601, 602, 607, 608, 620, 652, 653, 704, 709, 710, 722, 754, 755, 760, 761, 773, 805, 806, 811, 812, 824, 856, 857, 862, 863, 875, 907, 908, 913, 914, 926, 958, 959, 964, 965, 977, 990, 1009, 1010, 1015, 1016, 1060, 1061, 1079, 1092, 1111, 1112, 1117, 1118, 1130, 1143, 1162, 1163, 1168, 1169, 1181, 1213, 1214, 1219, 1220, 1264, 1265, 1270, 1271, 1283, 1315, 1316, 1321, 1322, 1334, 1347, 1366, 1367, 1372, 1373, 1385, 1398, 1417, 1418, 1423, 1424, 1436, 1449, 1468, 1469, 1474, 1475, 1487, 1500, 1519, 1520, 1525, 1526, 1538, 1551, 1570, 1575, 1576, 1588, 1601, 1620, 1625, 1626, 1638, 1651, 1670, 1675, 1676, 1688, 1701, 1720, 1725, 1726, 1738, 1751, 1770, 1775, 1776, 1788, 1801, 1820, 1825, 1826, 1838, 1851, 1870, 1875, 1876, 1888, 1901, 1920, 1925, 1926, 1938, 1951, 1970, 1975, 1976, 1988, 2020, 2038, 2051, 2070, 2075, 2076, 2088, 2120, 2125, 2126, 2138, 2151, 2170, 2175, 2176, 2188, 2220, 2225, 2226, 2238, 2251, 2270, 2275, 2276, 2288, 2301, 2320, 2325, 2326, 2338, 2351, 2370, 2375, 2376, 2388, 2420, 2425, 2426, 2438, 2451, 2470, 2475, 2476, 2488, 2501, 2520, 2525, 2526, 2538, 2570, 2575, 2576, 2588, 2601, 2620, 2625, 2626, 2638, 2670, 2675, 2676, 2688, 2701, 2720, 2725, 2726, 2738, 2751, 2770, 2775, 2776, 2788, 2801, 2820, 2825, 2826, 2838, 2851, 2870, 2875, 2876, 2888, 2901, 2920, 2925, 2926, 2938, 2951, 2970, 2975, 2976, 2988, 3001, 3020]
# Sample ID 140: Execution at indices [98, 233, 476, 477, 522, 524, 525, 527, 551, 552, 573, 575, 576, 578, 583, 594, 595, 596, 598, 602, 603, 619, 624, 626, 627, 629, 634, 645, 646, 647, 649, 653, 654, 664, 670, 673, 675, 677, 678, 680, 685, 696, 697, 698, 700, 704, 705, 715, 721, 724, 726, 728, 729, 731, 736, 747, 748, 749, 751, 755, 756, 766, 772, 777, 779, 780, 782, 787, 798, 799, 800, 802, 806, 807, 823, 828, 830, 831, 833, 838, 849, 850, 851, 853, 857, 858, 868, 874, 879, 881, 882, 884, 889, 900, 901, 902, 904, 908, 909, 925, 930, 932, 933, 935, 940, 951, 952, 953, 955, 959, 960, 970, 976, 979, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1006, 1010, 1011, 1027, 1032, 1034, 1035, 1037, 1042, 1053, 1054, 1055, 1057, 1061, 1062, 1072, 1078, 1083, 1085, 1086, 1088, 1093, 1104, 1105, 1106, 1108, 1112, 1113, 1129, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1159, 1163, 1164, 1174, 1180, 1185, 1187, 1188, 1190, 1195, 1206, 1207, 1208, 1210, 1214, 1215, 1225, 1231, 1236, 1238, 1239, 1241, 1246, 1257, 1258, 1259, 1260, 1261, 1265, 1266, 1276, 1282, 1287, 1289, 1290, 1292, 1297, 1308, 1309, 1310, 1312, 1316, 1317, 1327, 1333, 1338, 1340, 1341, 1343, 1348, 1359, 1360, 1361, 1363, 1367, 1368, 1378, 1384, 1389, 1391, 1392, 1394, 1399, 1410, 1411, 1412, 1414, 1418, 1419, 1429, 1435, 1440, 1442, 1443, 1445, 1450, 1461, 1462, 1463, 1465, 1469, 1470, 1480, 1486, 1491, 1493, 1494, 1496, 1501, 1503, 1512, 1513, 1514, 1515, 1516, 1520, 1521, 1531, 1537, 1542, 1544, 1545, 1547, 1552, 1563, 1564, 1565, 1567, 1581, 1587, 1592, 1594, 1595, 1597, 1602, 1613, 1614, 1615, 1616, 1617, 1631, 1637, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1667, 1687, 1692, 1694, 1695, 1697, 1702, 1704, 1713, 1714, 1715, 1716, 1717, 1737, 1742, 1744, 1745, 1747, 1752, 1763, 1764, 1765, 1766, 1767, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1817, 1831, 1837, 1842, 1844, 1845, 1847, 1852, 1863, 1864, 1865, 1867, 1881, 1887, 1892, 1894, 1895, 1897, 1902, 1913, 1914, 1915, 1917, 1942, 1944, 1945, 1947, 1952, 1963, 1964, 1965, 1967, 1992, 1994, 1995, 1997, 2002, 2013, 2014, 2015, 2017, 2042, 2044, 2045, 2047, 2052, 2063, 2064, 2065, 2067, 2081, 2087, 2090, 2092, 2094, 2095, 2097, 2102, 2113, 2114, 2115, 2117, 2142, 2144, 2145, 2147, 2152, 2163, 2164, 2165, 2167, 2192, 2194, 2195, 2197, 2202, 2213, 2214, 2215, 2217, 2231, 2237, 2240, 2242, 2244, 2245, 2247, 2252, 2263, 2264, 2265, 2266, 2267, 2292, 2294, 2295, 2297, 2302, 2304, 2313, 2314, 2315, 2317, 2342, 2344, 2345, 2347, 2352, 2363, 2364, 2365, 2366, 2367, 2387, 2392, 2394, 2395, 2397, 2402, 2413, 2414, 2415, 2417, 2437, 2442, 2444, 2445, 2447, 2452, 2463, 2464, 2465, 2467, 2487, 2492, 2494, 2495, 2497, 2502, 2513, 2514, 2515, 2517, 2542, 2544, 2545, 2547, 2552, 2563, 2564, 2565, 2567, 2592, 2594, 2595, 2597, 2602, 2613, 2614, 2615, 2616, 2617, 2642, 2644, 2645, 2647, 2652, 2654, 2663, 2664, 2665, 2666, 2667, 2681, 2687, 2690, 2692, 2694, 2695, 2697, 2702, 2713, 2714, 2715, 2717, 2737, 2742, 2744, 2745, 2747, 2752, 2763, 2764, 2765, 2767, 2787, 2792, 2794, 2795, 2797, 2802, 2813, 2814, 2815, 2817, 2842, 2844, 2845, 2847, 2852, 2892, 2894, 2895, 2897, 2902, 2913, 2914, 2915, 2916, 2917, 2942, 2944, 2945, 2947, 2952, 2992, 2994, 2995, 2997, 3002]
# Sample ID 220: Execution at indices [32, 46, 47, 100, 253, 551, 602, 653, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1032, 1033, 1034, 1035, 1061, 1083, 1084, 1085, 1086, 1112, 1134, 1135, 1136, 1137, 1163, 1185, 1186, 1187, 1188, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1592, 1593, 1594, 1595, 1642, 1643, 1644, 1645, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895, 1942, 1943, 1944, 1945, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2192, 2193, 2194, 2195, 2242, 2243, 2244, 2245, 2292, 2293, 2294, 2295, 2342, 2343, 2344, 2345, 2392, 2393, 2394, 2395, 2542, 2543, 2544, 2545, 2592, 2593, 2594, 2595, 2642, 2643, 2644, 2645, 2692, 2693, 2694, 2695, 2742, 2743, 2744, 2745, 2792, 2793, 2794, 2795, 2842, 2843, 2844, 2845, 2892, 2893, 2894, 2895, 2942, 2943, 2944, 2945, 2992, 2993, 2994, 2995]
# Sample ID 275: Execution at indices [70, 76, 82, 85, 88, 196, 203, 206, 207, 288, 293, 294, 331, 332, 333, 350, 396, 402, 406, 407, 413, 419, 424, 425, 433, 438, 522, 523, 524, 525, 551, 573, 574, 575, 576, 602, 624, 625, 626, 627, 653, 675, 676, 677, 678, 704, 726, 727, 728, 729, 755, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1061, 1112, 1163, 1214, 1265, 1316, 1367, 1389, 1390, 1391, 1392, 1418, 1469, 1520, 1542, 1543, 1544, 1545, 1642, 1643, 1644, 1645, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1842, 1843, 1844, 1845, 1942, 1943, 1944, 1945, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2192, 2193, 2194, 2195, 2242, 2243, 2244, 2245, 2292, 2293, 2294, 2295, 2342, 2343, 2344, 2345, 2392, 2393, 2394, 2395, 2492, 2493, 2494, 2495, 2542, 2543, 2544, 2545, 2642, 2643, 2644, 2645, 2692, 2693, 2694, 2695, 2842, 2843, 2844, 2845, 2892, 2893, 2894, 2895, 2942, 2943, 2944, 2945, 2992, 2993, 2994, 2995]
# Sample ID 339: Execution at indices [8, 9, 54, 55, 56, 57, 100, 101, 102, 103, 114, 115, 204, 205, 458, 459, 460, 522, 523, 524, 525, 551, 573, 574, 575, 576, 602, 624, 625, 626, 627, 653, 675, 676, 677, 678, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1032, 1033, 1034, 1035, 1061, 1083, 1084, 1085, 1086, 1112, 1163, 1214, 1265, 1316, 1338, 1339, 1340, 1341, 1367, 1418, 1469, 1520]
# Sample ID 346: Execution at indices [132, 134, 262, 263, 359, 522, 524, 525, 551, 552, 562, 568, 573, 575, 576, 578, 583, 594, 595, 596, 597, 598, 602, 603, 619, 624, 626, 627, 629, 634, 645, 646, 647, 649, 653, 654, 664, 670, 675, 677, 678, 680, 685, 696, 697, 698, 700, 704, 705, 715, 721, 726, 728, 729, 731, 736, 747, 748, 749, 751, 755, 756, 766, 772, 777, 779, 780, 782, 787, 798, 799, 800, 802, 806, 807, 828, 830, 831, 833, 838, 849, 850, 851, 853, 857, 858, 874, 879, 881, 882, 884, 889, 900, 901, 902, 904, 908, 909, 925, 930, 932, 933, 935, 940, 951, 952, 953, 955, 959, 960, 970, 976, 979, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1006, 1010, 1011, 1021, 1027, 1030, 1032, 1034, 1035, 1037, 1042, 1053, 1054, 1055, 1057, 1061, 1062, 1072, 1078, 1081, 1083, 1085, 1086, 1088, 1093, 1104, 1105, 1106, 1108, 1112, 1113, 1123, 1129, 1132, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1159, 1163, 1164, 1174, 1180, 1183, 1185, 1187, 1188, 1190, 1195, 1206, 1207, 1208, 1210, 1214, 1215, 1225, 1231, 1234, 1236, 1238, 1239, 1241, 1246, 1257, 1258, 1259, 1261, 1265, 1266, 1276, 1282, 1287, 1289, 1290, 1292, 1297, 1308, 1309, 1310, 1312, 1316, 1317, 1327, 1333, 1338, 1340, 1341, 1343, 1348, 1359, 1360, 1361, 1363, 1367, 1368, 1378, 1384, 1389, 1391, 1392, 1394, 1399, 1410, 1411, 1412, 1414, 1418, 1419, 1429, 1435, 1440, 1442, 1443, 1445, 1450, 1461, 1462, 1463, 1465, 1469, 1470, 1480, 1486, 1491, 1493, 1494, 1496, 1501, 1503, 1512, 1513, 1514, 1516, 1520, 1521, 1531, 1537, 1542, 1544, 1545, 1547, 1552, 1554, 1563, 1564, 1565, 1567, 1581, 1587, 1592, 1594, 1595, 1597, 1602, 1613, 1614, 1615, 1617, 1631, 1637, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1667, 1681, 1687, 1692, 1694, 1695, 1697, 1702, 1713, 1714, 1715, 1717, 1731, 1737, 1742, 1744, 1745, 1747, 1752, 1754, 1756, 1763, 1764, 1765, 1767, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1804, 1813, 1814, 1815, 1817, 1837, 1842, 1844, 1845, 1847, 1852, 1854, 1863, 1864, 1865, 1866, 1867, 1881, 1887, 1892, 1894, 1895, 1897, 1902, 1913, 1914, 1915, 1916, 1917, 1931, 1937, 1942, 1944, 1945, 1947, 1952, 1954, 1963, 1964, 1965, 1966, 1967, 1981, 1987, 1992, 1994, 1995, 1997, 2002, 2004, 2013, 2014, 2015, 2017, 2031, 2037, 2042, 2044, 2045, 2047, 2052, 2063, 2064, 2065, 2067, 2081, 2087, 2092, 2094, 2095, 2097, 2102, 2113, 2114, 2115, 2116, 2117, 2131, 2137, 2140, 2142, 2144, 2145, 2147, 2152, 2163, 2164, 2165, 2167, 2187, 2192, 2194, 2195, 2197, 2202, 2213, 2214, 2215, 2217, 2231, 2237, 2242, 2244, 2245, 2247, 2252, 2263, 2264, 2265, 2267, 2281, 2287, 2292, 2294, 2295, 2297, 2302, 2313, 2314, 2315, 2317, 2331, 2337, 2342, 2344, 2345, 2347, 2352, 2363, 2364, 2365, 2367, 2381, 2387, 2392, 2394, 2395, 2397, 2402, 2413, 2414, 2415, 2417, 2431, 2437, 2442, 2444, 2445, 2447, 2452, 2463, 2464, 2465, 2467, 2481, 2487, 2492, 2494, 2495, 2497, 2502, 2513, 2514, 2515, 2517, 2531, 2537, 2542, 2544, 2545, 2547, 2552, 2563, 2564, 2565, 2567, 2587, 2592, 2594, 2595, 2597, 2602, 2613, 2614, 2615, 2617, 2631, 2637, 2642, 2644, 2645, 2647, 2652, 2663, 2664, 2665, 2667, 2681, 2687, 2692, 2694, 2695, 2697, 2702, 2704, 2713, 2714, 2715, 2716, 2717, 2731, 2737, 2742, 2744, 2745, 2747, 2752, 2763, 2764, 2765, 2766, 2767, 2781, 2787, 2792, 2794, 2795, 2797, 2802, 2813, 2814, 2815, 2817, 2831, 2837, 2842, 2844, 2845, 2847, 2852, 2863, 2864, 2865, 2866, 2867, 2881, 2887, 2892, 2894, 2895, 2897, 2902, 2913, 2914, 2915, 2917, 2931, 2937, 2942, 2944, 2945, 2947, 2952, 2963, 2964, 2965, 2967, 2981, 2987, 2992, 2994, 2995, 2997, 3002, 3013, 3014, 3015, 3016, 3017]
# Sample ID 410: Execution at indices [223, 225, 249, 278, 339, 340, 344, 345, 358, 359, 404, 421, 422, 522, 524, 525, 527, 532, 551, 552, 573, 575, 576, 578, 602, 603, 624, 626, 627, 629, 645, 646, 647, 648, 649, 653, 654, 670, 675, 677, 678, 680, 685, 696, 697, 698, 699, 700, 704, 705, 721, 726, 728, 729, 731, 736, 747, 748, 749, 750, 751, 755, 756, 772, 777, 779, 780, 782, 787, 806, 807, 817, 823, 828, 830, 831, 833, 853, 857, 858, 868, 874, 879, 881, 882, 884, 889, 891, 900, 901, 902, 904, 908, 909, 919, 925, 930, 932, 933, 935, 940, 951, 952, 953, 954, 955, 959, 960, 970, 976, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1006, 1010, 1011, 1021, 1027, 1030, 1032, 1034, 1035, 1037, 1042, 1044, 1046, 1053, 1054, 1055, 1056, 1057, 1061, 1062, 1072, 1078, 1083, 1085, 1086, 1088, 1093, 1104, 1105, 1106, 1107, 1108, 1112, 1113, 1123, 1129, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1158, 1159, 1163, 1164, 1174, 1180, 1185, 1187, 1188, 1190, 1195, 1197, 1199, 1206, 1207, 1208, 1209, 1210, 1214, 1215, 1225, 1231, 1236, 1238, 1239, 1241, 1246, 1257, 1258, 1259, 1260, 1261, 1265, 1266, 1276, 1282, 1285, 1286, 1287, 1288, 1289, 1290, 1292, 1297, 1299, 1308, 1309, 1310, 1311, 1312, 1316, 1317, 1327, 1333, 1336, 1338, 1340, 1341, 1343, 1348, 1359, 1360, 1361, 1363, 1367, 1368, 1378, 1384, 1389, 1391, 1392, 1394, 1399, 1410, 1411, 1412, 1413, 1414, 1418, 1419, 1429, 1435, 1438, 1440, 1442, 1443, 1445, 1450, 1461, 1462, 1463, 1465, 1469, 1470, 1480, 1486, 1489, 1491, 1493, 1494, 1496, 1501, 1512, 1513, 1514, 1515, 1516, 1520, 1521, 1531, 1537, 1540, 1542, 1544, 1545, 1547, 1552, 1554, 1556, 1567, 1581, 1587, 1592, 1594, 1595, 1597, 1602, 1613, 1614, 1615, 1616, 1617, 1637, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1666, 1667, 1681, 1687, 1690, 1692, 1694, 1695, 1697, 1702, 1704, 1713, 1714, 1715, 1717, 1731, 1737, 1740, 1742, 1744, 1745, 1747, 1752, 1763, 1764, 1765, 1766, 1767, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1817, 1831, 1837, 1842, 1844, 1845, 1847, 1852, 1863, 1864, 1865, 1867, 1881, 1887, 1892, 1894, 1895, 1897, 1902, 1913, 1914, 1915, 1917, 1937, 1942, 1944, 1945, 1947, 1952, 1963, 1964, 1965, 1966, 1967, 1981, 1987, 1992, 1994, 1995, 1997, 2002, 2013, 2014, 2015, 2017, 2037, 2042, 2044, 2045, 2047, 2052, 2063, 2064, 2065, 2067, 2081, 2087, 2092, 2094, 2095, 2097, 2102, 2113, 2114, 2115, 2116, 2117, 2131, 2137, 2142, 2144, 2145, 2147, 2152, 2154, 2163, 2164, 2165, 2166, 2167, 2181, 2187, 2192, 2194, 2195, 2197, 2202, 2213, 2214, 2215, 2216, 2217, 2218, 2219, 2220, 2221, 2222, 2231, 2237, 2240, 2241, 2242, 2243, 2244, 2245, 2246, 2247, 2248, 2249, 2250, 2251, 2252, 2253, 2254, 2255, 2256, 2257, 2258, 2259, 2260, 2261, 2262, 2263, 2264, 2265, 2266, 2267, 2268, 2269, 2270, 2271, 2272, 2281, 2287, 2290, 2291, 2292, 2293, 2294, 2295, 2296, 2297, 2298, 2299, 2300, 2301, 2302, 2303, 2304, 2305, 2306, 2307, 2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321, 2322, 2330, 2331, 2337, 2340, 2341, 2342, 2343, 2344, 2345, 2346, 2347, 2348, 2349, 2350, 2351, 2352, 2353, 2354, 2355, 2356, 2357, 2358, 2359, 2360, 2361, 2362, 2363, 2364, 2365, 2366, 2367, 2368, 2369, 2370, 2371, 2372, 2381, 2387, 2390, 2391, 2392, 2393, 2394, 2395, 2396, 2397, 2398, 2399, 2400, 2401, 2402, 2403, 2404, 2405, 2406, 2407, 2408, 2409, 2410, 2411, 2412, 2413, 2414, 2415, 2416, 2417, 2418, 2419, 2420, 2421, 2422, 2424, 2426, 2430, 2431, 2432, 2437, 2440, 2441, 2442, 2443, 2444, 2445, 2446, 2447, 2448, 2449, 2450, 2451, 2452, 2453, 2454, 2455, 2456, 2457, 2458, 2459, 2460, 2461, 2462, 2463, 2464, 2465, 2466, 2467, 2468, 2469, 2470, 2471, 2472, 2480, 2481, 2487, 2490, 2491, 2492, 2493, 2494, 2495, 2496, 2497, 2498, 2499, 2500, 2501, 2502, 2503, 2504, 2505, 2506, 2507, 2508, 2509, 2510, 2511, 2512, 2513, 2514, 2515, 2516, 2517, 2518, 2519, 2520, 2521, 2522, 2524, 2525, 2526, 2527, 2528, 2529, 2530, 2531, 2532, 2537, 2540, 2541, 2542, 2543, 2544, 2545, 2546, 2547, 2548, 2549, 2550, 2551, 2552, 2553, 2554, 2555 ...
# Sample ID 414: Execution at indices [9, 10, 11, 85, 86, 285, 286, 365, 366, 551, 602, 639, 646, 653, 704, 755, 806, 857, 908, 945, 952, 959, 1010, 1061, 1112, 1163, 1207, 1208, 1209, 1214, 1265, 1316, 1367, 1418, 1469, 1520, 1664, 1665, 1666, 1814, 1815, 1816, 1864, 1865, 1866, 1907, 1914, 1915, 1916, 1957, 1964, 1965, 1966, 2064, 2065, 2066, 2067, 2314, 2315, 2316, 2317, 2364, 2365, 2366, 2367, 2414, 2415, 2416, 2417, 2464, 2465, 2466, 2467, 2564, 2565, 2566, 2567, 2664, 2665, 2666, 2667, 2714, 2715, 2716, 2717, 2749, 2750, 2751, 2752, 2754, 2755, 2757, 2814, 2815, 2816, 2817, 2864, 2865, 2866, 2867, 2899, 2900, 2901, 2907, 2914, 2915, 2916, 2917]
# Sample ID 453: Execution at indices [3, 4, 5, 308, 309, 412, 413, 421, 460, 461, 462, 522, 524, 525, 527, 532, 551, 552, 602, 603, 624, 626, 627, 629, 634, 653, 654, 675, 677, 678, 680, 685, 696, 697, 698, 700, 704, 705, 728, 729, 731, 736, 747, 748, 749, 751, 755, 756, 777, 779, 780, 782, 787, 798, 799, 800, 802, 806, 807, 823, 828, 830, 831, 833, 838, 840, 849, 850, 851, 853, 857, 858, 868, 874, 877, 879, 881, 882, 884, 889, 900, 901, 902, 904, 908, 909, 919, 925, 930, 932, 933, 935, 940, 951, 952, 953, 955, 959, 960, 970, 976, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1005, 1006, 1010, 1011, 1021, 1027, 1032, 1034, 1035, 1037, 1042, 1044, 1046, 1053, 1054, 1055, 1056, 1057, 1061, 1062, 1072, 1078, 1081, 1083, 1085, 1086, 1088, 1093, 1104, 1105, 1106, 1108, 1112, 1113, 1123, 1129, 1132, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1159, 1163, 1164, 1174, 1180, 1183, 1185, 1187, 1188, 1190, 1195, 1206, 1207, 1208, 1210, 1214, 1215, 1225, 1231, 1236, 1238, 1239, 1241, 1246, 1248, 1250, 1257, 1258, 1259, 1261, 1265, 1266, 1276, 1282, 1285, 1287, 1289, 1290, 1292, 1297, 1308, 1309, 1310, 1312, 1316, 1317, 1327, 1333, 1338, 1340, 1341, 1343, 1348, 1350, 1359, 1360, 1361, 1363, 1367, 1368, 1378, 1384, 1389, 1391, 1392, 1394, 1399, 1401, 1403, 1410, 1411, 1412, 1414, 1418, 1419, 1429, 1435, 1440, 1442, 1443, 1445, 1450, 1452, 1461, 1462, 1463, 1465, 1469, 1470, 1480, 1486, 1491, 1493, 1494, 1496, 1501, 1520, 1521, 1531, 1537, 1542, 1544, 1545, 1547, 1552, 1554, 1563, 1564, 1565, 1567, 1581, 1587, 1590, 1592, 1594, 1595, 1597, 1602, 1604, 1613, 1614, 1615, 1617, 1631, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1667, 1681, 1687, 1690, 1692, 1694, 1695, 1697, 1702, 1713, 1714, 1715, 1717, 1737, 1742, 1744, 1745, 1747, 1752, 1763, 1764, 1765, 1766, 1767, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1817, 1831, 1837, 1842, 1844, 1845, 1847, 1852, 1863, 1864, 1865, 1867, 1881, 1887, 1892, 1894, 1895, 1897, 1902, 1913, 1914, 1915, 1917, 1931, 1937, 1940, 1942, 1944, 1945, 1947, 1952, 1963, 1964, 1965, 1967, 1981, 1987, 1990, 1992, 1994, 1995, 1997, 2002, 2013, 2014, 2015, 2017, 2037, 2040, 2042, 2044, 2045, 2047, 2052, 2063, 2064, 2065, 2066, 2067, 2081, 2087, 2090, 2092, 2094, 2095, 2097, 2102, 2113, 2114, 2115, 2117, 2131, 2137, 2140, 2142, 2144, 2145, 2147, 2152, 2163, 2164, 2165, 2167, 2187, 2190, 2192, 2194, 2195, 2197, 2202, 2213, 2214, 2215, 2217, 2237, 2242, 2244, 2245, 2247, 2252, 2263, 2264, 2265, 2267, 2287, 2290, 2292, 2294, 2295, 2297, 2302, 2313, 2314, 2315, 2317, 2337, 2342, 2344, 2345, 2347, 2352, 2363, 2364, 2365, 2367, 2387, 2392, 2394, 2395, 2397, 2402, 2413, 2414, 2415, 2417, 2437, 2442, 2444, 2445, 2447, 2452, 2463, 2464, 2465, 2467, 2487, 2492, 2494, 2495, 2497, 2502, 2513, 2514, 2515, 2517, 2531, 2537, 2542, 2544, 2545, 2547, 2552, 2563, 2564, 2565, 2566, 2567, 2571, 2581, 2587, 2592, 2594, 2595, 2597, 2602, 2604, 2606, 2613, 2614, 2615, 2617, 2631, 2637, 2642, 2644, 2645, 2647, 2652, 2654, 2663, 2664, 2665, 2666, 2667, 2671, 2681, 2687, 2690, 2692, 2694, 2695, 2697, 2702, 2704, 2706, 2713, 2714, 2715, 2716, 2717, 2721, 2731, 2737, 2740, 2742, 2744, 2745, 2747, 2752, 2754, 2756, 2763, 2764, 2765, 2766, 2767, 2771, 2781, 2787, 2790, 2792, 2794, 2795, 2797, 2802, 2804, 2806, 2813, 2814, 2815, 2817, 2821, 2831, 2837, 2840, 2842, 2844, 2845, 2847, 2852, 2854, 2856, 2863, 2864, 2865, 2867, 2881, 2887, 2890, 2892, 2894, 2895, 2897, 2902, 2904, 2906, 2913, 2914, 2915, 2916, 2917, 2921, 2931, 2937, 2940, 2942, 2944, 2945, 2947, 2952, 2963, 2964, 2965, 2966, 2967, 2971, 2981, 2987, 2990, 2992, 2994, 2995, 2997, 3002, 3004, 3006, 3013, 3014, 3015, 3016, 3017]
# Sample ID 461: Execution at indices [10, 37, 174, 301, 302, 413, 551, 602, 653, 690, 704, 741, 748, 755, 806, 857, 894, 908, 959, 996, 1003, 1004, 1005, 1010, 1061, 1098, 1105, 1106, 1107, 1112, 1163, 1200, 1207, 1208, 1209, 1214, 1265, 1302, 1309, 1310, 1311, 1316, 1367, 1418, 1469, 1506, 1513, 1514, 1515, 1520, 1557, 1564, 1565, 1566, 1657, 1664, 1757, 1764, 1765, 1766, 1857, 1907, 1914, 2007, 2057, 2064, 2457, 2464, 2557, 2564, 2565, 2607, 2614, 2707, 2714, 2757, 2764, 3007, 3014]
# Sample ID 568: Execution at indices [454, 551, 602, 653, 675, 676, 677, 678, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 1010, 1061, 1112, 1134, 1135, 1136, 1137, 1163, 1185, 1186, 1187, 1188, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1692, 1693, 1694, 1695]
# Sample ID 646: Execution at indices [165, 166, 421, 422, 423, 551, 602, 653, 704, 755, 806, 857, 908, 959, 1010, 1061, 1112, 1163, 1214, 1265, 1316, 1367, 1417, 1418, 1469, 1520]
# Sample ID 731: Execution at indices [94, 137, 138, 144, 294, 295, 427, 453, 522, 523, 524, 525, 551, 602, 624, 625, 626, 627, 653, 675, 676, 677, 678, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1032, 1033, 1034, 1035, 1061, 1083, 1084, 1085, 1086, 1112, 1134, 1135, 1136, 1137, 1163, 1185, 1186, 1187, 1188, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1642, 1643, 1644, 1645, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895, 1942, 1943, 1944, 1945, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2292, 2293, 2294, 2295, 2392, 2393, 2394, 2395, 2414, 2542, 2543, 2544, 2545, 2592, 2593, 2594, 2595, 2642, 2643, 2644, 2645, 2647, 2692, 2693, 2694, 2695, 2697, 2742, 2743, 2744, 2745, 2792, 2793, 2794, 2795, 2842, 2843, 2844, 2845, 2942, 2943, 2944, 2945]
# Sample ID 739: Execution at indices [57, 58, 59, 194, 440, 488, 551, 588, 602, 653, 704, 755, 806, 857, 908, 945, 959, 996, 1010, 1047, 1061, 1112, 1149, 1163, 1200, 1207, 1214, 1251, 1258, 1265, 1316, 1367, 1404, 1418, 1469, 1520, 1564, 1565, 1566, 1657, 1664, 1707, 1714, 1957, 1964, 2057, 2064, 2157, 2207, 2214, 2257, 2307, 2314, 2457, 2507, 2607, 2614, 2657, 2664, 2707, 2714, 2757, 2807, 2814]
# Sample ID 797: Execution at indices [266, 344, 345, 389, 390, 397, 401, 492, 493, 551, 556, 557, 602, 607, 608, 620, 653, 658, 659, 671, 704, 709, 710, 722, 754, 755, 760, 761, 773, 805, 806, 811, 812, 824, 856, 857, 862, 863, 875, 888, 907, 908, 913, 914, 926, 958, 959, 964, 965, 977, 1009, 1010, 1015, 1016, 1060, 1061, 1066, 1067, 1079, 1111, 1112, 1117, 1118, 1130, 1163, 1168, 1169, 1181, 1213, 1214, 1219, 1220, 1264, 1265, 1315, 1316, 1321, 1322, 1334, 1366, 1367, 1372, 1373, 1385, 1417, 1418, 1423, 1424, 1468, 1469, 1474, 1475, 1519, 1520, 1525, 1526, 1538, 1570, 1575, 1576, 1588, 1620, 1625, 1626, 1670, 1675, 1676, 1720, 1725, 1726, 1770, 1775, 1776, 1820, 1825, 1826, 1888, 1970, 1975, 1976, 2020, 2025, 2026, 2070, 2075, 2076, 2120, 2125, 2126, 2138, 2270, 2275, 2276, 2370, 2375, 2376, 2488, 2520, 2525, 2526, 2538, 2570, 2575, 2576, 2670, 2675, 2676, 2838, 2988, 3020]
# Sample ID 865: Execution at indices [29, 32, 34, 35, 36, 37, 39, 218, 219, 220, 221, 288, 289, 290, 400, 404, 405, 406, 407, 409, 411, 412, 413, 419, 423, 522, 524, 525, 527, 532, 547, 551, 552, 562, 568, 573, 575, 576, 578, 583, 602, 603, 613, 619, 624, 626, 627, 629, 634, 653, 654, 664, 670, 675, 677, 678, 680, 685, 704, 705, 715, 721, 726, 728, 729, 731, 736, 755, 756, 766, 772, 777, 779, 780, 782, 787, 806, 807, 817, 823, 828, 830, 831, 833, 838, 849, 850, 851, 853, 857, 858, 868, 874, 877, 879, 881, 882, 884, 889, 908, 909, 919, 925, 930, 932, 933, 935, 940, 959, 960, 970, 976, 979, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1006, 1010, 1011, 1027, 1032, 1034, 1035, 1037, 1042, 1053, 1054, 1055, 1056, 1057, 1061, 1062, 1072, 1078, 1083, 1085, 1086, 1088, 1093, 1095, 1104, 1105, 1106, 1107, 1108, 1112, 1113, 1123, 1129, 1132, 1134, 1136, 1137, 1139, 1144, 1163, 1164, 1180, 1183, 1185, 1187, 1188, 1190, 1195, 1214, 1215, 1231, 1236, 1238, 1239, 1241, 1246, 1257, 1258, 1259, 1260, 1261, 1265, 1266, 1276, 1282, 1287, 1289, 1290, 1292, 1297, 1308, 1309, 1310, 1311, 1312, 1313, 1314, 1315, 1316, 1317, 1327, 1333, 1338, 1340, 1341, 1343, 1348, 1359, 1360, 1361, 1363, 1367, 1368, 1378, 1384, 1389, 1391, 1392, 1394, 1399, 1410, 1411, 1412, 1413, 1414, 1418, 1419, 1429, 1435, 1440, 1442, 1443, 1445, 1450, 1461, 1462, 1463, 1464, 1465, 1469, 1470, 1480, 1486, 1491, 1493, 1494, 1496, 1501, 1512, 1513, 1514, 1515, 1516, 1517, 1518, 1519, 1520, 1521, 1522, 1531, 1537, 1542, 1544, 1545, 1547, 1552, 1563, 1564, 1565, 1566, 1567, 1581, 1587, 1592, 1594, 1595, 1597, 1602, 1613, 1614, 1615, 1616, 1617, 1618, 1619, 1620, 1621, 1622, 1626, 1630, 1631, 1637, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1667, 1681, 1687, 1690, 1691, 1692, 1693, 1694, 1695, 1696, 1697, 1698, 1699, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1726, 1730, 1731, 1737, 1740, 1742, 1744, 1745, 1747, 1752, 1754, 1763, 1764, 1765, 1766, 1767, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1816, 1817, 1831, 1837, 1842, 1844, 1845, 1847, 1852, 1863, 1864, 1865, 1866, 1867, 1881, 1887, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1926, 1930, 1931, 1937, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1976, 1980, 1981, 1987, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2026, 2030, 2031, 2037, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2076, 2080, 2081, 2087, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100, 2101, 2102, 2103, 2104, 2105, 2106, 2107, 2108, 2109, 2110, 2111, 2112, 2113, 2114, 2115, 2116, 2117, 2118, 2119, 2120, 2121, 2122, 2131, 2137, 2140, 2141, 2142, 2143, 2144, 2145, 2146, 2147, 2148, 2149, 2150, 2151, 2152, 2153, 2154, 2155, 2156, 2157, 2158, 2159, 2160, 2161, 2162, 2163, 2164, 2165, 2166, 2167, 2168, 2169, 2170, 2171, 2172, 2174, 2175, 2176, 2177, 2178, 2179, 2180, 2181, 2182, 2187, 2188, 2190, 2191, 2192, 2193, 2194, 2195, 2196, 2197, 2198, 2199, 2200, 2201, 2202, 2203, 2204, 2205, 2206, 2207, 2208, 2209, 2210, 2211, 2212, 2213, 2214, 2215, 2216, 2217, 2218, 2219, 2220, 2221, 2222, 2224, 2225, 2226, 2227, 2228, 2229, 2230, 2231, 2232, 2237, 2238, 2239, 2240, 2241, 2242, 2243, 2244, 2245, 2246, 2247, 2248, 2249, 2250, 2251, 2252, 2253, 2254, 2255, 2256, 2257, 2258, 2259, 2260, 2261, 2262, 2263, 2264, 2265, 2266, 2267, 2268, 2269, 22 ...
# Sample ID 869: Execution at indices [61, 62, 63, 64, 65, 66, 139, 140, 216, 217, 261, 262, 389, 408, 462, 463, 522, 524, 525, 527, 532, 543, 544, 545, 547, 551, 552, 562, 568, 573, 575, 576, 578, 583, 594, 595, 596, 598, 602, 603, 613, 619, 624, 626, 627, 629, 634, 653, 654, 675, 677, 678, 680, 685, 696, 697, 698, 700, 704, 705, 715, 721, 726, 728, 729, 731, 736, 747, 748, 749, 751, 755, 756, 766, 772, 775, 777, 779, 780, 782, 787, 798, 799, 800, 802, 806, 807, 828, 830, 831, 833, 838, 849, 850, 851, 852, 853, 857, 858, 879, 881, 882, 884, 889, 908, 909, 930, 932, 933, 935, 940, 959, 960, 976, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1006, 1010, 1011, 1032, 1034, 1035, 1037, 1042, 1053, 1054, 1055, 1057, 1061, 1062, 1072, 1078, 1083, 1085, 1086, 1088, 1093, 1112, 1113, 1123, 1129, 1132, 1134, 1136, 1137, 1139, 1144, 1163, 1164, 1180, 1185, 1187, 1188, 1190, 1195, 1197, 1199, 1206, 1207, 1208, 1209, 1210, 1214, 1215, 1225, 1231, 1234, 1236, 1238, 1239, 1241, 1246, 1248, 1250, 1257, 1258, 1259, 1260, 1261, 1265, 1266, 1276, 1282, 1285, 1287, 1289, 1290, 1292, 1297, 1312, 1316, 1317, 1327, 1333, 1338, 1340, 1341, 1343, 1348, 1350, 1352, 1359, 1360, 1361, 1362, 1363, 1367, 1368, 1378, 1384, 1389, 1391, 1392, 1394, 1399, 1410, 1411, 1412, 1413, 1414, 1418, 1419, 1429, 1435, 1440, 1442, 1443, 1445, 1450, 1452, 1454, 1461, 1462, 1463, 1464, 1465, 1469, 1470, 1480, 1486, 1491, 1493, 1494, 1496, 1501, 1503, 1505, 1512, 1513, 1514, 1515, 1516, 1520, 1521, 1531, 1537, 1542, 1544, 1545, 1547, 1552, 1563, 1564, 1565, 1566, 1567, 1581, 1587, 1592, 1594, 1595, 1597, 1602, 1604, 1606, 1613, 1614, 1615, 1616, 1617, 1621, 1631, 1637, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1666, 1667, 1681, 1687, 1692, 1694, 1695, 1697, 1702, 1704, 1706, 1713, 1714, 1715, 1716, 1717, 1731, 1737, 1742, 1744, 1745, 1747, 1752, 1754, 1756, 1763, 1764, 1765, 1766, 1767, 1771, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1804, 1806, 1813, 1814, 1815, 1816, 1817, 1831, 1837, 1840, 1842, 1844, 1845, 1847, 1852, 1854, 1856, 1863, 1864, 1865, 1866, 1867, 1881, 1887, 1890, 1892, 1894, 1895, 1897, 1902, 1904, 1913, 1914, 1915, 1917, 1931, 1937, 1940, 1942, 1944, 1945, 1947, 1952, 1954, 1956, 1963, 1964, 1965, 1966, 1967, 1981, 1987, 1990, 1992, 1994, 1995, 1997, 2002, 2013, 2014, 2015, 2016, 2017, 2031, 2037, 2040, 2042, 2044, 2045, 2047, 2052, 2063, 2064, 2065, 2066, 2067, 2081, 2087, 2090, 2092, 2094, 2095, 2097, 2102, 2113, 2114, 2115, 2116, 2117, 2131, 2137, 2142, 2144, 2145, 2147, 2152, 2154, 2156, 2163, 2164, 2165, 2166, 2167, 2181, 2187, 2192, 2194, 2195, 2197, 2202, 2204, 2206, 2213, 2214, 2215, 2216, 2217, 2231, 2237, 2242, 2244, 2245, 2247, 2252, 2254, 2263, 2264, 2265, 2266, 2267, 2281, 2287, 2292, 2294, 2295, 2297, 2302, 2313, 2314, 2315, 2316, 2317, 2331, 2337, 2340, 2342, 2344, 2345, 2347, 2352, 2363, 2364, 2365, 2366, 2367, 2387, 2390, 2392, 2394, 2395, 2397, 2402, 2413, 2414, 2415, 2417, 2437, 2442, 2444, 2445, 2447, 2452, 2463, 2464, 2465, 2466, 2467, 2487, 2492, 2494, 2495, 2497, 2502, 2513, 2514, 2515, 2517, 2542, 2544, 2545, 2547, 2552, 2563, 2564, 2565, 2567, 2581, 2587, 2590, 2592, 2594, 2595, 2597, 2602, 2604, 2606, 2613, 2614, 2615, 2616, 2617, 2631, 2637, 2642, 2644, 2645, 2647, 2652, 2663, 2664, 2665, 2666, 2667, 2692, 2694, 2695, 2697, 2702, 2704, 2713, 2714, 2715, 2716, 2717, 2737, 2742, 2744, 2745, 2747, 2752, 2763, 2764, 2765, 2767, 2781, 2787, 2790, 2792, 2794, 2795, 2797, 2802, 2813, 2814, 2815, 2817, 2831, 2837, 2840, 2842, 2844, 2845, 2847, 2852, 2863, 2864, 2865, 2866, 2867, 2881, 2887, 2890, 2892, 2894, 2895, 2897, 2902, 2913, 2914, 2915, 2916, 2917, 2931, 2937, 2940, 2942, 2944, 2945, 2947, 2952, 2963, 2964, 2965, 2966, 2967, 2981, 2987, 2990, 2992, 2994, 2995, 2997, 3002, 3013, 3014, 3015, 3016, 3017]
# Sample ID 875: Execution at indices [169, 200, 201, 282, 283, 493, 522, 524, 525, 532, 543, 544, 545, 547, 551, 552, 573, 575, 576, 578, 602, 603, 613, 619, 624, 626, 627, 629, 634, 653, 654, 675, 677, 678, 680, 685, 696, 697, 698, 700, 704, 705, 715, 721, 724, 726, 728, 729, 731, 736, 738, 747, 748, 749, 750, 751, 755, 756, 766, 772, 775, 777, 779, 780, 782, 787, 798, 799, 800, 802, 806, 807, 817, 823, 826, 828, 830, 831, 833, 838, 849, 850, 851, 853, 857, 858, 868, 874, 877, 879, 881, 882, 884, 889, 900, 901, 902, 903, 904, 908, 909, 919, 925, 928, 930, 932, 933, 935, 940, 951, 952, 953, 955, 959, 960, 970, 976, 979, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1005, 1006, 1010, 1011, 1021, 1027, 1030, 1032, 1034, 1035, 1037, 1042, 1053, 1054, 1055, 1057, 1061, 1062, 1072, 1078, 1081, 1083, 1085, 1086, 1088, 1093, 1104, 1105, 1106, 1108, 1112, 1113, 1123, 1129, 1132, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1158, 1159, 1163, 1164, 1174, 1180, 1183, 1185, 1187, 1188, 1190, 1195, 1206, 1207, 1208, 1210, 1214, 1215, 1225, 1231, 1234, 1236, 1238, 1239, 1241, 1246, 1248, 1257, 1258, 1259, 1261, 1265, 1266, 1276, 1282, 1285, 1287, 1289, 1290, 1292, 1297, 1308, 1309, 1310, 1311, 1312, 1316, 1317, 1327, 1333, 1336, 1338, 1340, 1341, 1343, 1348, 1359, 1360, 1361, 1363, 1367, 1368, 1378, 1384, 1387, 1389, 1391, 1392, 1394, 1399, 1401, 1403, 1410, 1411, 1412, 1413, 1414, 1418, 1419, 1429, 1435, 1440, 1442, 1443, 1445, 1450, 1452, 1461, 1462, 1463, 1464, 1465, 1469, 1470, 1479, 1480, 1486, 1489, 1491, 1493, 1494, 1496, 1501, 1512, 1513, 1514, 1516, 1520, 1521, 1531, 1537, 1540, 1542, 1544, 1545, 1547, 1552, 1554, 1563, 1564, 1565, 1567, 1581, 1587, 1590, 1592, 1594, 1595, 1597, 1602, 1613, 1614, 1615, 1617, 1637, 1640, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1666, 1667, 1681, 1687, 1690, 1692, 1694, 1695, 1697, 1702, 1713, 1714, 1715, 1717, 1731, 1737, 1740, 1742, 1744, 1745, 1747, 1752, 1763, 1764, 1765, 1767, 1781, 1787, 1790, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1817, 1831, 1837, 1840, 1842, 1844, 1845, 1847, 1852, 1863, 1864, 1865, 1867, 1881, 1887, 1890, 1892, 1894, 1895, 1897, 1902, 1913, 1914, 1915, 1916, 1917, 1931, 1937, 1942, 1944, 1945, 1947, 1952, 1963, 1964, 1965, 1966, 1967, 1981, 1987, 1992, 1994, 1995, 1997, 2002, 2013, 2014, 2015, 2016, 2017, 2031, 2037, 2042, 2044, 2045, 2047, 2052, 2063, 2064, 2065, 2066, 2067, 2087, 2092, 2094, 2095, 2097, 2102, 2113, 2114, 2115, 2117, 2131, 2137, 2142, 2144, 2145, 2147, 2152, 2163, 2164, 2165, 2166, 2167, 2171, 2181, 2187, 2190, 2192, 2194, 2195, 2197, 2202, 2213, 2214, 2215, 2217, 2231, 2237, 2242, 2244, 2245, 2247, 2252, 2263, 2264, 2265, 2266, 2267, 2281, 2287, 2292, 2294, 2295, 2297, 2302, 2313, 2314, 2315, 2316, 2317, 2331, 2337, 2342, 2344, 2345, 2347, 2352, 2354, 2356, 2363, 2364, 2365, 2366, 2367, 2381, 2387, 2390, 2392, 2394, 2395, 2397, 2402, 2404, 2406, 2413, 2414, 2415, 2416, 2417, 2421, 2431, 2437, 2440, 2442, 2444, 2445, 2447, 2452, 2463, 2464, 2465, 2466, 2467, 2481, 2487, 2492, 2494, 2495, 2497, 2502, 2504, 2513, 2514, 2515, 2516, 2517, 2531, 2537, 2540, 2542, 2544, 2545, 2547, 2552, 2563, 2564, 2565, 2566, 2567, 2581, 2587, 2592, 2594, 2595, 2597, 2602, 2613, 2614, 2615, 2616, 2617, 2631, 2637, 2642, 2644, 2645, 2647, 2652, 2654, 2656, 2663, 2664, 2665, 2666, 2667, 2671, 2681, 2687, 2690, 2692, 2694, 2695, 2697, 2702, 2704, 2706, 2713, 2714, 2715, 2716, 2717, 2731, 2737, 2740, 2742, 2744, 2745, 2747, 2752, 2754, 2756, 2763, 2764, 2765, 2766, 2767, 2781, 2787, 2790, 2792, 2794, 2795, 2797, 2802, 2804, 2806, 2813, 2814, 2815, 2816, 2817, 2821, 2831, 2837, 2840, 2842, 2844, 2845, 2847, 2852, 2854, 2856, 2863, 2864, 2865, 2866, 2867, 2871, 2881, 2887, 2890, 2892, 2894, 2895, 2897, 2902, 2904, 2906, 2913, 2914, 2915, 2916, 2917, 2921, 2931, 2937, 2940, 2942, 2944, 2945, 2947, 2952, 2954, 2963, 2964, 2965, 2966, 2967, 2971, 2981, 2987, 2990, 2992, 2994, 2995, 2997, 3002, 3004, 3006, 3013, 3014, 3015, 3016, 3017]
# Sample ID 879: Execution at indices [131, 286, 287, 551, 602, 653, 704, 755, 805, 806, 811, 812, 824, 856, 857, 907, 908, 959, 1010, 1061, 1111, 1112, 1163, 1214, 1265, 1316, 1367, 1418, 1469, 1519, 1520, 1720, 1870, 1875, 1876, 1920, 1925, 1926, 1970, 2020, 2070, 2438, 2538, 2588, 2638]
# Sample ID 899: Execution at indices [256, 317, 454, 550, 551, 569, 601, 602, 652, 653, 671, 703, 704, 755, 805, 806, 811, 812, 824, 856, 857, 908, 959, 964, 965, 1010, 1028, 1060, 1061, 1066, 1067, 1111, 1112, 1117, 1118, 1162, 1163, 1168, 1169, 1213, 1214, 1219, 1220, 1264, 1265, 1270, 1271, 1315, 1316, 1321, 1322, 1366, 1367, 1372, 1373, 1417, 1418, 1423, 1424, 1468, 1469, 1474, 1475, 1487, 1519, 1520, 1525, 1526, 1570, 1575, 1576, 1620, 1625, 1626, 1670, 1688, 1720, 1725, 1726, 1738, 1770, 1775, 1776, 1820, 1825, 1826, 1870, 1875, 1876, 1920, 1925, 1926, 1970, 1975, 1976, 1988, 2020, 2025, 2026, 2070, 2120, 2138, 2170, 2175, 2176, 2220, 2270, 2275, 2276, 2320, 2325, 2326, 2370, 2388, 2420, 2470, 2475, 2476, 2488, 2501, 2520, 2525, 2526, 2570, 2575, 2576, 2620, 2625, 2626, 2670, 2675, 2676, 2720, 2725, 2726, 2738, 2770, 2775, 2776, 2820, 2825, 2826, 2870, 2920, 2938, 2970, 2988, 3020]
# Sample ID 945: Execution at indices [68, 105, 106, 225, 268, 450, 551, 602, 653, 704, 755, 806, 857, 908, 959, 1010, 1032, 1033, 1034, 1035, 1061, 1112, 1134, 1135, 1136, 1137, 1163, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1592, 1593, 1594, 1595, 1642, 1643, 1644, 1645, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895, 1942, 1943, 1944, 1945, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2192, 2193, 2194, 2195, 2242, 2243, 2244, 2245, 2292, 2293, 2294, 2295, 2392, 2393, 2394, 2395, 2442, 2443, 2444, 2445, 2492, 2493, 2494, 2495, 2542, 2543, 2544, 2545, 2592, 2593, 2594, 2595, 2642, 2643, 2644, 2645, 2742, 2743, 2744, 2745, 2792, 2793, 2794, 2795, 2842, 2843, 2844, 2845, 2942, 2943, 2944, 2945, 2992, 2993, 2994, 2995]
# Sample ID 975: Execution at indices [99, 115, 255, 256, 522, 524, 525, 551, 552, 573, 575, 576, 578, 583, 594, 595, 596, 598, 602, 603, 624, 626, 627, 629, 634, 645, 646, 647, 649, 653, 654, 670, 675, 677, 678, 680, 685, 696, 697, 698, 699, 700, 704, 705, 715, 721, 726, 728, 729, 731, 736, 747, 748, 749, 751, 755, 756, 766, 772, 777, 779, 780, 782, 787, 798, 799, 800, 801, 802, 806, 807, 817, 823, 826, 828, 830, 831, 833, 838, 849, 850, 851, 853, 857, 858, 868, 874, 877, 879, 881, 882, 884, 889, 900, 901, 902, 903, 904, 908, 909, 919, 925, 928, 930, 932, 933, 935, 940, 951, 952, 953, 954, 955, 959, 960, 970, 976, 979, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1005, 1006, 1010, 1011, 1021, 1027, 1032, 1034, 1035, 1037, 1042, 1053, 1054, 1055, 1056, 1057, 1061, 1062, 1072, 1078, 1081, 1083, 1085, 1086, 1088, 1093, 1104, 1105, 1106, 1107, 1108, 1112, 1113, 1123, 1129, 1132, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1158, 1159, 1163, 1164, 1174, 1180, 1183, 1185, 1187, 1188, 1190, 1195, 1206, 1207, 1208, 1210, 1214, 1215, 1225, 1231, 1234, 1236, 1238, 1239, 1241, 1246, 1257, 1258, 1259, 1261, 1265, 1266, 1276, 1282, 1285, 1287, 1289, 1290, 1292, 1297, 1308, 1309, 1310, 1312, 1316, 1317, 1327, 1333, 1336, 1338, 1340, 1341, 1343, 1348, 1359, 1360, 1361, 1363, 1367, 1368, 1378, 1384, 1389, 1391, 1392, 1394, 1399, 1410, 1411, 1412, 1414, 1418, 1419, 1429, 1435, 1438, 1440, 1442, 1443, 1445, 1450, 1461, 1462, 1463, 1465, 1469, 1470, 1480, 1486, 1491, 1493, 1494, 1496, 1501, 1512, 1513, 1514, 1515, 1516, 1520, 1521, 1531, 1537, 1542, 1544, 1545, 1547, 1552, 1563, 1564, 1565, 1567, 1581, 1587, 1592, 1594, 1595, 1597, 1602, 1604, 1606, 1613, 1614, 1615, 1617, 1631, 1637, 1642, 1644, 1645, 1647, 1652, 1654, 1656, 1663, 1664, 1665, 1666, 1667, 1681, 1687, 1692, 1694, 1695, 1697, 1702, 1713, 1714, 1715, 1717, 1731, 1737, 1742, 1744, 1745, 1747, 1752, 1754, 1756, 1763, 1764, 1765, 1767, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1817, 1831, 1837, 1842, 1844, 1845, 1847, 1852, 1854, 1856, 1863, 1864, 1865, 1867, 1881, 1887, 1892, 1894, 1895, 1897, 1902, 1904, 1913, 1914, 1915, 1917, 1931, 1937, 1942, 1944, 1945, 1947, 1952, 1954, 1963, 1964, 1965, 1967, 1981, 1987, 1990, 1992, 1994, 1995, 1997, 2002, 2013, 2014, 2015, 2017, 2037, 2042, 2044, 2045, 2047, 2052, 2063, 2064, 2065, 2067, 2087, 2092, 2094, 2095, 2097, 2102, 2104, 2113, 2114, 2115, 2116, 2117, 2131, 2137, 2142, 2144, 2145, 2147, 2152, 2154, 2156, 2163, 2164, 2165, 2167, 2181, 2187, 2192, 2194, 2195, 2197, 2202, 2204, 2206, 2213, 2214, 2215, 2217, 2231, 2237, 2242, 2244, 2245, 2247, 2252, 2254, 2263, 2264, 2265, 2266, 2267, 2281, 2287, 2292, 2294, 2295, 2297, 2302, 2313, 2314, 2315, 2317, 2337, 2342, 2344, 2345, 2347, 2352, 2354, 2363, 2364, 2365, 2367, 2381, 2387, 2390, 2392, 2394, 2395, 2397, 2402, 2404, 2413, 2414, 2415, 2417, 2437, 2442, 2444, 2445, 2447, 2452, 2463, 2464, 2465, 2467, 2487, 2492, 2494, 2495, 2497, 2502, 2504, 2513, 2514, 2515, 2516, 2517, 2531, 2537, 2542, 2544, 2545, 2547, 2552, 2563, 2564, 2565, 2567, 2581, 2587, 2592, 2594, 2595, 2597, 2602, 2604, 2606, 2613, 2614, 2615, 2616, 2617, 2631, 2637, 2642, 2644, 2645, 2647, 2652, 2654, 2656, 2663, 2664, 2665, 2667, 2681, 2687, 2692, 2694, 2695, 2697, 2702, 2704, 2706, 2713, 2714, 2715, 2717, 2731, 2737, 2742, 2744, 2745, 2747, 2752, 2763, 2764, 2765, 2767, 2781, 2787, 2792, 2794, 2795, 2797, 2802, 2813, 2814, 2815, 2816, 2817, 2837, 2842, 2844, 2845, 2847, 2852, 2863, 2864, 2865, 2867, 2887, 2892, 2894, 2895, 2897, 2902, 2913, 2914, 2915, 2916, 2917, 2921, 2931, 2937, 2942, 2944, 2945, 2947, 2952, 2954, 2956, 2963, 2964, 2965, 2967, 2981, 2987, 2992, 2994, 2995, 2997, 3002, 3004, 3013, 3014, 3015, 3016, 3017]
# Sample ID 1062: Execution at indices [239, 245, 265, 353, 551, 602, 653, 690, 697, 704, 741, 755, 806, 843, 850, 851, 852, 857, 894, 901, 902, 903, 908, 959, 1010, 1047, 1054, 1055, 1056, 1061, 1112, 1156, 1157, 1158, 1163, 1207, 1208, 1209, 1214, 1265, 1316, 1353, 1360, 1361, 1362, 1367, 1404, 1411, 1412, 1413, 1418, 1462, 1463, 1464, 1469, 1506, 1513, 1514, 1515, 1520, 1564, 1565, 1566, 1664, 1665, 1666, 1714, 1715, 1716, 1764, 1765, 1766, 1814, 1815, 1816, 1864, 1865, 1866, 1907, 1914, 1915, 1916, 1964, 1965, 1966, 2007, 2014, 2064, 2065, 2066, 2114, 2115, 2116, 2164, 2165, 2166, 2214, 2215, 2216, 2257, 2264, 2265, 2266, 2314, 2315, 2316, 2357, 2364, 2365, 2366, 2414, 2415, 2416, 2464, 2465, 2466, 2507, 2514, 2515, 2516, 2517, 2557, 2564, 2565, 2566, 2657, 2664, 2665, 2666, 2707, 2714, 2715, 2716, 2757, 2807, 2814, 2815, 2816, 2957, 2964, 3007, 3014]
# Sample ID 1070: Execution at indices [214, 216, 522, 524, 525, 527, 551, 552, 562, 568, 573, 575, 576, 578, 602, 603, 613, 619, 624, 626, 627, 629, 634, 645, 646, 647, 649, 653, 654, 664, 670, 675, 677, 678, 680, 685, 696, 697, 698, 700, 704, 705, 715, 721, 726, 728, 729, 731, 736, 747, 748, 749, 750, 751, 755, 756, 766, 772, 777, 779, 780, 782, 787, 798, 799, 800, 801, 802, 806, 807, 817, 823, 828, 830, 831, 833, 838, 849, 850, 851, 852, 853, 857, 858, 868, 874, 877, 879, 881, 882, 884, 889, 904, 908, 909, 919, 925, 930, 932, 933, 935, 940, 959, 960, 970, 976, 979, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1005, 1006, 1010, 1011, 1021, 1027, 1032, 1034, 1035, 1037, 1042, 1044, 1046, 1053, 1054, 1055, 1056, 1057, 1061, 1062, 1072, 1078, 1081, 1082, 1083, 1084, 1085, 1086, 1088, 1093, 1095, 1104, 1105, 1106, 1107, 1108, 1112, 1113, 1123, 1129, 1132, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1158, 1159, 1163, 1164, 1174, 1180, 1183, 1185, 1187, 1188, 1190, 1195, 1206, 1207, 1208, 1209, 1210, 1214, 1215, 1225, 1231, 1234, 1236, 1238, 1239, 1241, 1246, 1257, 1258, 1259, 1261, 1265, 1266, 1276, 1282, 1285, 1287, 1289, 1290, 1292, 1297, 1308, 1309, 1310, 1311, 1312, 1316, 1317, 1327, 1333, 1338, 1340, 1341, 1343, 1348, 1359, 1360, 1361, 1362, 1363, 1367, 1368, 1378, 1384, 1387, 1389, 1391, 1392, 1394, 1399, 1410, 1411, 1412, 1413, 1414, 1418, 1419, 1429, 1435, 1438, 1440, 1442, 1443, 1445, 1450, 1461, 1462, 1463, 1465, 1469, 1470, 1480, 1486, 1489, 1491, 1493, 1494, 1496, 1501, 1512, 1513, 1514, 1516, 1520, 1521, 1531, 1537, 1540, 1542, 1544, 1545, 1547, 1552, 1554, 1563, 1564, 1565, 1567, 1581, 1587, 1590, 1592, 1594, 1595, 1597, 1602, 1613, 1614, 1615, 1617, 1637, 1640, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1667, 1687, 1690, 1692, 1694, 1695, 1697, 1702, 1713, 1714, 1715, 1717, 1731, 1737, 1742, 1744, 1745, 1747, 1752, 1763, 1764, 1765, 1766, 1767, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821, 1822, 1831, 1837, 1840, 1841, 1842, 1843, 1844, 1845, 1846, 1847, 1848, 1849, 1850, 1851, 1852, 1853, 1854, 1855, 1856, 1857, 1858, 1859, 1860, 1861, 1862, 1863, 1864, 1865, 1866, 1867, 1868, 1869, 1870, 1871, 1872, 1881, 1887, 1890, 1891, 1892, 1893, 1894, 1895, 1896, 1897, 1898, 1899, 1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1930, 1931, 1937, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1981, 1987, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2030, 2031, 2037, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2048, 2049, 2050, 2051, 2052, 2053, 2054, 2055, 2056, 2057, 2058, 2059, 2060, 2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2081, 2087, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100, 2101, 2102, 2103, 2104, 2105, 2106, 2107, 2108, 2109, 2110, 2111, 2112, 2113, 2114, 2115, 2116, 2117, 2118, 2119, 2120, 2121, 2122, 2130, 2131, 2137, 2140, 2141, 2142, 2143, 2144, 2145, 2146, 2147, 2148, 2149, 2150, 2151, 2152, 2153, 2154, 2155, 2156, 2157, 2158, 2159, 2160, 2161, 2162, 2163, 2164, 2165, 2166, 2167, 2168, 2169, 2170, 2171, 2172, 2180, 2181, 2187, 2190, 2191, 2192, 2193, 2194, 2195, 2196, 2197, 2198, 2199, 2200, 2201, 2202, 2203, 2204, 2205, 2206, 2207, 2208, 2209, 2210, 2211, 2212, 2213, 2214, 2215, 2216, 2217, 2218, 2219, 2220, 2221, 2222, 2230, 2231, 2237, 2240, 2241, 2242, 2243, 2244, 2245, 2246, 2247, 2248, 2249, 2250, 2251, 2252, 2253, 2254, 2255, 2256, 2257, 2258, 2259, 2260, 2261, 2262, 2263, 2264, 2265, 2266, 2267, 2268, 2269, 2270, 2271, 2272, 2281, 2282, 2287, 2290, 2291, 2292, 2293, 2294, 2295, 2296, 2297, 2298, 2299, 2300,  ...
# Sample ID 1086: Execution at indices [23, 305, 446, 551, 602, 639, 646, 647, 648, 653, 697, 698, 699, 700, 704, 755, 806, 857, 908, 959, 996, 1003, 1004, 1005, 1010, 1061, 1112, 1163, 1200, 1207, 1214, 1265, 1302, 1309, 1316, 1367, 1404, 1411, 1412, 1413, 1418, 1469, 1520, 1757, 1764, 1807, 1814, 2057, 2207, 2214, 2257, 2264]
# Sample ID 1141: Execution at indices [122, 287, 288, 289, 342, 343, 344, 345, 537, 551, 602, 653, 690, 697, 698, 699, 704, 741, 748, 749, 750, 755, 806, 843, 850, 851, 852, 857, 908, 959, 1010, 1061, 1098, 1105, 1106, 1107, 1112, 1163, 1214, 1258, 1259, 1260, 1265, 1316, 1353, 1360, 1367, 1418, 1469, 1520, 1564, 1565, 1566, 1567, 1614, 1615, 1616, 1849, 1850, 1851, 1857, 1864, 1865, 1866, 2007, 2014, 2015, 2016, 2064, 2065, 2066, 2157, 2164, 2165, 2166, 2207, 2214, 2364, 2365, 2366, 2399, 2400, 2401, 2407, 2414, 2415, 2416, 2464, 2465, 2466, 2514, 2515, 2516, 2517, 2607, 2657, 2664, 2707, 2807, 2814, 3007, 3014, 3015, 3016]
# ...
# Sample ID 6629: Execution at indices [22, 23, 57, 75, 76, 77, 104, 161, 162, 184, 185, 186, 191, 202, 214, 215, 216, 225, 227, 267, 268, 284, 291, 551, 602, 653, 704, 726, 727, 728, 729, 755, 806, 857, 908, 959, 1010, 1061, 1112, 1163, 1214, 1265, 1316, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1592, 1593, 1594, 1595, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895, 1942, 1943, 1944, 1945, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2192, 2193, 2194, 2195, 2242, 2243, 2244, 2245, 2292, 2293, 2294, 2295, 2342, 2343, 2344, 2345, 2392, 2393, 2394, 2395, 2442, 2443, 2444, 2445, 2492, 2493, 2494, 2495, 2542, 2543, 2544, 2545, 2592, 2593, 2594, 2595, 2642, 2643, 2644, 2645, 2692, 2693, 2694, 2695, 2742, 2743, 2744, 2745, 2792, 2793, 2794, 2795, 2842, 2843, 2844, 2845, 2892, 2893, 2894, 2895, 2942, 2943, 2944, 2945, 2992, 2993, 2994, 2995]
# Sample ID 6681: Execution at indices [172, 260, 261, 278, 341, 342, 411, 412, 551, 602, 653, 703, 704, 754, 755, 760, 761, 773, 805, 806, 811, 812, 824, 856, 857, 862, 863, 875, 907, 908, 958, 959, 1010, 1060, 1061, 1066, 1067, 1079, 1112, 1163, 1214, 1265, 1316, 1367, 1418, 1469, 1520, 1620, 1670, 1675, 1676, 1720, 1770]
# Sample ID 6698: Execution at indices [78, 79, 80, 81, 128, 132, 133, 134, 135, 136, 199, 200, 257, 350, 551, 601, 602, 653, 703, 704, 754, 755, 806, 857, 908, 958, 959, 964, 965, 1009, 1010, 1015, 1016, 1028, 1060, 1061, 1111, 1112, 1163, 1213, 1214, 1264, 1265, 1270, 1271, 1316, 1366, 1367, 1372, 1373, 1385, 1417, 1418, 1423, 1424, 1436, 1468, 1469, 1474, 1475, 1487, 1519, 1520, 1525, 1526, 1538, 1570, 1575, 1576, 1588, 1620, 1970, 2120, 2570, 2620, 2638, 2670, 2688, 2720, 2770, 2970]
# Sample ID 6842: Execution at indices [269, 270, 551, 602, 653, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1032, 1033, 1034, 1035, 1061, 1083, 1084, 1085, 1086, 1112, 1134, 1135, 1136, 1137, 1163, 1185, 1186, 1187, 1188, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1394, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1592, 1593, 1594, 1595, 1642, 1643, 1644, 1645, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1942, 1943, 1944, 1945, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2242, 2243, 2244, 2245, 2292, 2293, 2294, 2295, 2342, 2343, 2344, 2345, 2442, 2443, 2444, 2445, 2492, 2493, 2494, 2495, 2592, 2593, 2594, 2595, 2642, 2643, 2644, 2645, 2692, 2693, 2694, 2695, 2792, 2793, 2794, 2795, 2842, 2843, 2844, 2845, 2892, 2893, 2894, 2895, 2992, 2993, 2994, 2995]
# Sample ID 6865: Execution at indices [12, 14, 23, 32, 42, 43, 44, 45, 67, 68, 87, 89, 90, 91, 93, 94, 119, 120, 121, 122, 150, 151, 152, 170, 177, 179, 180, 182, 201, 202, 203, 204, 206, 250, 251, 252, 253, 271, 272, 273, 274, 275, 276, 278, 279, 280, 281, 282, 303, 312, 313, 314, 315, 316, 317, 325, 326, 333, 334, 346, 347, 348, 389, 390, 391, 392, 393, 394, 409, 421, 422, 443, 444, 445, 446, 447, 459, 460, 469, 470, 471, 478, 495, 496, 522, 523, 524, 525, 551, 573, 574, 575, 576, 602, 624, 625, 626, 627, 653, 675, 676, 677, 678, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1061, 1083, 1084, 1085, 1086, 1112, 1134, 1135, 1136, 1137, 1163, 1185, 1186, 1187, 1188, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1592, 1593, 1594, 1595, 1642, 1643, 1644, 1645, 1742, 1743, 1744, 1745, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895]
# Sample ID 6866: Execution at indices [72, 73, 74, 75, 76, 77, 78, 87, 93, 98, 99, 107, 108, 115, 116, 120, 121, 130, 138, 139, 140, 152, 153, 155, 190, 201, 212, 213, 214, 215, 216, 217, 218, 267, 268, 269, 270, 287, 326, 327, 328, 329, 330, 331, 339, 341, 361, 380, 395, 396, 397, 398, 399, 418, 419, 420, 428, 429, 430, 437, 438, 439, 452, 453, 477, 483, 488, 489, 490, 491, 511, 517, 520, 522, 524, 525, 527, 532, 551, 552, 573, 575, 576, 578, 583, 602, 603, 613, 619, 624, 626, 627, 629, 634, 636, 645, 646, 647, 648, 649, 653, 654, 664, 670, 673, 675, 677, 678, 680, 685, 696, 697, 698, 699, 700, 704, 705, 721, 726, 728, 729, 731, 736, 738, 747, 748, 749, 750, 751, 755, 756, 766, 772, 775, 777, 779, 780, 782, 787, 806, 807, 817, 823, 826, 828, 830, 831, 833, 838, 849, 850, 851, 852, 853, 857, 858, 868, 874, 877, 879, 881, 882, 884, 889, 900, 901, 902, 904, 908, 909, 925, 930, 932, 933, 935, 940, 951, 952, 953, 955, 959, 960, 970, 976, 979, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1005, 1006, 1010, 1011, 1021, 1027, 1030, 1032, 1034, 1035, 1037, 1042, 1053, 1054, 1055, 1057, 1061, 1062, 1072, 1078, 1083, 1085, 1086, 1088, 1093, 1104, 1105, 1106, 1108, 1112, 1113, 1123, 1129, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1159, 1163, 1164, 1174, 1180, 1185, 1187, 1188, 1190, 1195, 1197, 1206, 1207, 1208, 1210, 1214, 1215, 1225, 1231, 1236, 1238, 1239, 1241, 1246, 1257, 1258, 1259, 1261, 1265, 1266, 1276, 1282, 1287, 1289, 1290, 1292, 1297, 1299, 1308, 1309, 1310, 1312, 1316, 1317, 1327, 1333, 1338, 1340, 1341, 1343, 1348, 1350, 1352, 1359, 1360, 1361, 1362, 1363, 1367, 1368, 1378, 1384, 1387, 1389, 1391, 1392, 1394, 1399, 1410, 1411, 1412, 1414, 1418, 1419, 1429, 1435, 1440, 1442, 1443, 1445, 1450, 1461, 1462, 1463, 1465, 1469, 1470, 1480, 1486, 1491, 1493, 1494, 1496, 1501, 1512, 1513, 1514, 1515, 1516, 1520, 1521, 1531, 1537, 1542, 1544, 1545, 1547, 1552, 1554, 1556, 1563, 1564, 1565, 1567, 1581, 1587, 1592, 1594, 1595, 1597, 1602, 1604, 1613, 1614, 1615, 1617, 1631, 1637, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1666, 1667, 1681, 1687, 1692, 1694, 1695, 1697, 1702, 1713, 1714, 1715, 1717, 1731, 1737, 1742, 1744, 1745, 1747, 1752, 1763, 1764, 1765, 1766, 1767, 1781, 1787, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1816, 1817, 1831, 1837, 1842, 1844, 1845, 1847, 1852, 1863, 1864, 1865, 1867, 1881, 1887, 1892, 1894, 1895, 1897, 1902, 1904, 1913, 1914, 1915, 1916, 1917, 1931, 1937, 1942, 1944, 1945, 1947, 1952, 1963, 1964, 1965, 1966, 1967, 1981, 1987, 1992, 1994, 1995, 1997, 2002, 2013, 2014, 2015, 2016, 2017, 2037, 2040, 2041, 2042, 2043, 2044, 2045, 2046, 2047, 2052, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 2071, 2072, 2081, 2087, 2090, 2091, 2092, 2093, 2094, 2095, 2096, 2097, 2098, 2099, 2100, 2101, 2102, 2103, 2104, 2105, 2106, 2107, 2108, 2109, 2110, 2111, 2112, 2113, 2114, 2115, 2116, 2117, 2118, 2119, 2120, 2121, 2122, 2126, 2130, 2131, 2137, 2140, 2141, 2142, 2143, 2144, 2145, 2146, 2147, 2148, 2149, 2150, 2151, 2152, 2153, 2154, 2155, 2156, 2157, 2158, 2159, 2160, 2161, 2162, 2163, 2164, 2165, 2166, 2167, 2168, 2169, 2170, 2171, 2172, 2176, 2180, 2181, 2187, 2190, 2191, 2192, 2193, 2194, 2195, 2196, 2197, 2198, 2199, 2200, 2201, 2202, 2203, 2204, 2205, 2206, 2207, 2208, 2209, 2210, 2211, 2212, 2213, 2214, 2215, 2216, 2217, 2218, 2219, 2220, 2221, 2222, 2230, 2231, 2237, 2240, 2241, 2242, 2243, 2244, 2245, 2246, 2247, 2248, 2249, 2250, 2251, 2252, 2253, 2254, 2255, 2256, 2257, 2258, 2259, 2260, 2261, 2262, 2263, 2264, 2265, 2266, 2267, 2268, 2269, 2270, 2271, 2272, 2280, 2281, 2287, 2288, 2290, 2291, 2292, 2293, 2294, 2295, 2296, 2297, 2298, 2299, 2300, 2301, 2302, 2303, 2304, 2305, 2306, 2307, 2308, 2309, 2310, 2311, 2312, 2313, 2314, 2315, 2316, 2317, 2318, 2319, 2320, 2321, 2322, 2326, 2330, 2331, 2332, 2337, 2340, 2341, 2342, 2343, 2344, 2345, 2346, 2347, 2348, 2349, 2350, 2351, 2352, 2353, 2354, 2355, 2356, 2357, 2358, 2359, 2360, 2361, 2362, 2363, 2364, 2365, 2366, 2367, 2368, 2369, 2370, 2371, ...
# Sample ID 6920: Execution at indices [110, 111, 112, 324, 325, 326, 327, 522, 523, 524, 525, 551, 602, 653, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 959, 981, 982, 983, 984, 1010, 1032, 1033, 1034, 1035, 1061, 1112, 1163, 1185, 1186, 1187, 1188, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1520, 1592, 1593, 1594, 1595, 1642, 1643, 1644, 1645, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2192, 2193, 2194, 2195, 2242, 2243, 2244, 2245, 2292, 2293, 2294, 2295, 2342, 2343, 2344, 2345, 2392, 2393, 2394, 2395, 2442, 2443, 2444, 2445, 2492, 2493, 2494, 2495, 2542, 2543, 2544, 2545, 2592, 2593, 2594, 2595, 2642, 2643, 2644, 2645, 2692, 2693, 2694, 2695, 2742, 2743, 2744, 2745, 2792, 2793, 2794, 2795, 2842, 2843, 2844, 2845, 2892, 2893, 2894, 2895, 2942, 2943, 2944, 2945, 2992, 2993, 2994, 2995]
# Sample ID 6931: Execution at indices [15, 522, 524, 525, 527, 551, 552, 573, 575, 576, 578, 602, 603, 613, 619, 624, 626, 627, 629, 634, 653, 654, 670, 675, 677, 678, 680, 704, 705, 726, 728, 729, 731, 736, 755, 756, 766, 772, 777, 779, 780, 782, 787, 806, 807, 823, 828, 830, 831, 833, 857, 858, 868, 874, 879, 881, 882, 884, 889, 900, 901, 902, 904, 908, 909, 925, 930, 932, 933, 935, 940, 951, 952, 953, 954, 955, 959, 960, 970, 976, 981, 983, 984, 986, 991, 1002, 1003, 1004, 1006, 1010, 1011, 1021, 1027, 1032, 1034, 1035, 1037, 1042, 1053, 1054, 1055, 1056, 1057, 1061, 1062, 1072, 1078, 1083, 1085, 1086, 1088, 1093, 1104, 1105, 1106, 1108, 1112, 1113, 1123, 1129, 1134, 1136, 1137, 1139, 1144, 1155, 1156, 1157, 1158, 1159, 1163, 1164, 1174, 1180, 1183, 1185, 1187, 1188, 1190, 1195, 1206, 1207, 1208, 1209, 1210, 1214, 1215, 1225, 1231, 1236, 1238, 1239, 1241, 1246, 1257, 1258, 1259, 1260, 1261, 1265, 1266, 1276, 1282, 1287, 1289, 1290, 1292, 1297, 1308, 1309, 1310, 1311, 1312, 1316, 1317, 1327, 1333, 1338, 1340, 1341, 1343, 1348, 1350, 1359, 1360, 1361, 1362, 1363, 1367, 1368, 1378, 1384, 1389, 1391, 1392, 1394, 1399, 1401, 1410, 1411, 1412, 1413, 1414, 1418, 1419, 1429, 1435, 1440, 1442, 1443, 1445, 1450, 1461, 1462, 1463, 1464, 1465, 1469, 1470, 1480, 1486, 1491, 1493, 1494, 1496, 1501, 1503, 1512, 1513, 1514, 1516, 1520, 1521, 1531, 1537, 1542, 1544, 1545, 1547, 1552, 1554, 1563, 1564, 1565, 1567, 1581, 1587, 1592, 1594, 1595, 1597, 1602, 1613, 1614, 1615, 1616, 1617, 1631, 1637, 1640, 1642, 1644, 1645, 1647, 1652, 1663, 1664, 1665, 1667, 1681, 1687, 1692, 1694, 1695, 1702, 1713, 1714, 1715, 1717, 1731, 1737, 1740, 1742, 1744, 1745, 1747, 1752, 1763, 1764, 1765, 1767, 1787, 1792, 1794, 1795, 1797, 1802, 1813, 1814, 1815, 1817, 1837, 1842, 1844, 1845, 1847, 1852, 1863, 1864, 1865, 1867, 1892, 1894, 1895, 1897, 1902, 1913, 1914, 1915, 1917, 1931, 1937, 1942, 1944, 1945, 1947, 1952, 1963, 1964, 1965, 1966, 1967, 1987, 1992, 1994, 1995, 1997, 2002, 2013, 2014, 2015, 2017, 2031, 2037, 2042, 2044, 2045, 2047, 2052, 2063, 2064, 2065, 2067, 2087, 2092, 2094, 2095, 2097, 2102, 2113, 2114, 2115, 2117, 2137, 2142, 2144, 2145, 2147, 2152, 2163, 2164, 2165, 2167, 2187, 2192, 2194, 2195, 2197, 2202, 2213, 2214, 2215, 2217, 2237, 2242, 2244, 2245, 2247, 2252, 2263, 2264, 2265, 2267, 2287, 2292, 2294, 2295, 2297, 2302, 2313, 2314, 2315, 2317, 2342, 2344, 2345, 2347, 2352, 2363, 2364, 2365, 2366, 2367, 2381, 2387, 2392, 2394, 2395, 2397, 2402, 2413, 2414, 2415, 2417, 2437, 2442, 2444, 2445, 2447, 2452, 2463, 2464, 2465, 2467, 2487, 2492, 2494, 2495, 2497, 2502, 2513, 2514, 2515, 2517, 2537, 2542, 2544, 2545, 2547, 2552, 2563, 2564, 2565, 2567, 2587, 2592, 2594, 2595, 2597, 2602, 2613, 2614, 2615, 2617, 2631, 2637, 2642, 2644, 2645, 2647, 2652, 2663, 2664, 2665, 2667, 2681, 2687, 2692, 2694, 2695, 2697, 2702, 2713, 2714, 2715, 2717, 2731, 2737, 2742, 2744, 2745, 2747, 2752, 2763, 2764, 2765, 2767, 2787, 2792, 2794, 2795, 2797, 2802, 2813, 2814, 2815, 2817, 2831, 2837, 2842, 2844, 2845, 2847, 2852, 2863, 2864, 2865, 2867, 2881, 2887, 2892, 2894, 2895, 2897, 2902, 2913, 2914, 2915, 2917, 2931, 2937, 2942, 2944, 2945, 2947, 2952, 2963, 2964, 2965, 2967, 2981, 2987, 2992, 2994, 2995, 2997, 3002, 3013, 3014, 3015, 3017]
# Sample ID 6936: Execution at indices [28, 29, 30, 156, 157, 413, 551, 602, 653, 704, 726, 727, 728, 729, 755, 806, 828, 829, 830, 831, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1032, 1033, 1034, 1035, 1061, 1083, 1084, 1085, 1086, 1112, 1134, 1135, 1136, 1137, 1163, 1185, 1186, 1187, 1188, 1214, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1592, 1593, 1594, 1595, 1642, 1643, 1644, 1645, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1942, 1943, 1944, 1945, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2192, 2193, 2194, 2195, 2242, 2243, 2244, 2245, 2342, 2343, 2344, 2345, 2442, 2443, 2444, 2445, 2492, 2493, 2494, 2495, 2542, 2543, 2544, 2545, 2592, 2593, 2594, 2595, 2642, 2643, 2644, 2645, 2692, 2693, 2694, 2695, 2742, 2743, 2744, 2745, 2792, 2793, 2794, 2795, 2842, 2843, 2844, 2845, 2892, 2893, 2894, 2895, 2942, 2943, 2944, 2945, 2992, 2993, 2994, 2995]
# Sample ID 6991: Execution at indices [8, 202, 287, 288, 289, 432, 551, 602, 653, 704, 755, 806, 828, 829, 830, 831, 857, 908, 930, 931, 932, 933, 959, 1010, 1061, 1112, 1163, 1214, 1265, 1316, 1367, 1418, 1469, 1520, 1592, 1593, 1594, 1595, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895, 1942, 1943, 1944, 1945, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2692, 2693, 2694, 2695]
# Sample ID 7009: Execution at indices [43, 47, 48, 149, 150, 151, 176, 407, 408, 409, 440, 441, 537, 544, 545, 546, 551, 602, 639, 646, 647, 648, 653, 704, 755, 806, 857, 894, 901, 902, 903, 908, 945, 952, 953, 954, 959, 996, 1003, 1004, 1005, 1010, 1061, 1098, 1105, 1106, 1107, 1112, 1156, 1157, 1158, 1163, 1200, 1207, 1208, 1209, 1214, 1258, 1259, 1260, 1265, 1302, 1309, 1310, 1311, 1316, 1367, 1418, 1469, 1520, 2364, 2365, 2366, 2367, 2414, 2415, 2416]
# Sample ID 7098: Execution at indices [1, 2, 3, 4, 5, 140, 141, 142, 183, 184, 297, 311, 312, 313, 314, 340, 341, 342, 343, 369, 452, 537, 544, 545, 546, 551, 602, 653, 704, 755, 806, 857, 908, 959, 1010, 1061, 1098, 1105, 1112, 1163, 1200, 1207, 1214, 1265, 1316, 1367, 1418, 1469, 1513, 1514, 1515, 1520, 1607, 1614, 1615, 1616, 1664, 1665, 1666, 1807, 1814, 1815, 1816, 1907, 1957, 1964, 2057, 2107, 2164, 2165, 2166, 2167, 2414, 2415, 2416, 2417, 2507, 2514, 2657, 2664, 2707, 2714, 2907, 2914, 2957, 2964, 3007, 3014]
# Sample ID 7187: Execution at indices [16, 551, 602, 653, 704, 726, 727, 728, 729, 755, 777, 778, 779, 780, 806, 857, 879, 880, 881, 882, 908, 930, 931, 932, 933, 959, 981, 982, 983, 984, 1010, 1032, 1033, 1034, 1035, 1061, 1083, 1084, 1085, 1086, 1112, 1163, 1185, 1186, 1187, 1188, 1214, 1236, 1237, 1238, 1239, 1265, 1287, 1288, 1289, 1290, 1316, 1338, 1339, 1340, 1341, 1367, 1389, 1390, 1391, 1392, 1418, 1440, 1441, 1442, 1443, 1469, 1491, 1492, 1493, 1494, 1520, 1542, 1543, 1544, 1545, 1592, 1593, 1594, 1595, 1642, 1643, 1644, 1645, 1692, 1693, 1694, 1695, 1742, 1743, 1744, 1745, 1792, 1793, 1794, 1795, 1842, 1843, 1844, 1845, 1892, 1893, 1894, 1895, 1942, 1943, 1944, 1945, 1992, 1993, 1994, 1995, 2042, 2043, 2044, 2045, 2092, 2093, 2094, 2095, 2142, 2143, 2144, 2145, 2192, 2193, 2194, 2195, 2242, 2243, 2244, 2245, 2292, 2293, 2294, 2295, 2392, 2393, 2394, 2395, 2442, 2443, 2444, 2445, 2692, 2693, 2694, 2695, 2742, 2743, 2744, 2745, 2842, 2843, 2844, 2845]

# %% [markdown]
# # Market Impact graph

# %%
from IPython.display import display
from sklearn.linear_model import LinearRegression
import numpy as np
import pandas as pd
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import ipywidgets as widgets

def interactive_market_impact_plot(b_seq_inp, msg_seq_raw, all_series, x,
                                   hist_steps=550, gen_block=50, num_insertions=20):
    if isinstance(b_seq_inp, pd.DataFrame):
        b_seq_inp = {int(r.id): np.array(r.merged_data) for _, r in b_seq_inp.iterrows()}
    if isinstance(msg_seq_raw, pd.DataFrame):
        msg_seq_raw = {int(r.id): np.array(r.merged_data) for _, r in msg_seq_raw.iterrows()}

    id_dd       = widgets.Dropdown(options=sorted(b_seq_inp.keys()), description="Sample ID:")
    time_slider = widgets.IntSlider(min=1, max=1, step=1, description="t:")
    btn_prev    = widgets.Button(description="←")
    btn_next    = widgets.Button(description="→")
    msg_box     = widgets.HTML()
    coeff_box   = widgets.HTML()

    if 79 in b_seq_inp:
        id_dd.value = 79

    fig = make_subplots(rows=1, cols=3, subplot_titles=["Book state", "Midprice evolution", "Market Impact (log-log)"])
    fig.update_layout(width=1400, height=500, showlegend=False, template='plotly_white')
    fig_widget = go.FigureWidget(fig)

    def update_slider_range(*_):
        arr = b_seq_inp[id_dd.value]
        time_slider.min = 1
        time_slider.max = arr.shape[0] - 1
        time_slider.value = 551

    def update_plot(*_):
        sample_id = id_dd.value
        t = time_slider.value
        book_array = b_seq_inp[sample_id]
        messages = msg_seq_raw[sample_id]

        book_prev = book_array[t-1, 240:263]
        book_now = book_array[t, 240:263]
        book_diff = abs(book_now) - abs(book_prev)
        x_levels = np.arange(len(book_prev)) - len(book_prev) // 2
        book_colors = ['orange' if abs(d) < 1e-8 else ('red' if d > 0 else 'blue') for d in book_diff]

        arr_idx = list(b_seq_inp.keys()).index(sample_id)
        midprice_series = all_series[arr_idx]

        insertion_positions = hist_steps + np.arange(1, num_insertions + 1) * gen_block
        valid_insertions = [pos for pos in insertion_positions if pos < len(messages)]

        reference_price_ticks = float(messages[valid_insertions[0], 3])
        daily_volume_estimate = 250_000

        log_qv = []
        log_impact = []
        cum_order_volume = 0.0
        cum_order_notional_ticks = 0.0

        for idx in valid_insertions:
            order_size = float(messages[idx, 5])
            order_price_ticks = float(messages[idx, 3])
            cum_order_volume += order_size
            cum_order_notional_ticks += order_size * order_price_ticks

            if cum_order_volume == 0:
                continue

            vwap_ticks = cum_order_notional_ticks / cum_order_volume
            impact_ticks = abs(vwap_ticks - reference_price_ticks)
            rel_size = cum_order_volume / daily_volume_estimate

            if impact_ticks <= 0 or rel_size <= 0:
                continue

            log_qv.append(np.log(rel_size))
            log_impact.append(np.log(impact_ticks))

        # === Linear regression ===
        X = np.array(log_qv).reshape(-1, 1)
        y = np.array(log_impact)
        reg = LinearRegression().fit(X, y)
        delta = reg.coef_[0]
        log_lambda_est = reg.intercept_

        # === Theoretical: same intercept, β = 0.5 ===
        beta_theoretical = 0.5
        log_lambda_theory = log_lambda_est

        # === Equation text box ===
        coeff_box.value = f"""
        <div style="padding-left:20px; font-family:monospace">
            <h4 style="margin:0; padding:0;">Market Impact Models</h4>
            <p style="margin:0;"><b>Estimated:</b> log(Impact) = <b>{log_lambda_est:.4f}</b> + <b>{delta:.4f}</b> · log(Q / V)</p>
            <p style="margin:0;"><b>Theoretical:</b> log(Impact) = <b>{log_lambda_theory:.4f}</b> + <b>{beta_theoretical:.2f}</b> · log(Q / V)</p>
            <hr>
            <p style="font-size:13px; line-height:1.5;">
                • <b>Impact</b>: absolute difference between VWAP of inserted orders and reference midprice (in ticks)<br>
                • <b>Q</b>: cumulative inserted order volume<br>
                • <b>V</b>: estimated daily execution volume (here: 250,000)<br><br>
                • <b>log(λ)</b>: vertical intercept, reflects baseline impact scale (e.g. market liquidity)<br>
                • <b>β</b> (delta): slope, shows how sensitive price impact is to trade size<br>
                &nbsp;&nbsp;• β ≈ 0.5 implies square-root law (concave impact)<br>
                &nbsp;&nbsp;• β > 1 suggests highly sensitive/liquid market<br>
                &nbsp;&nbsp;• β < 0.5 suggests very deep or buffered markets
            </p>
        </div>
        """

        ref_line_x = np.linspace(min(log_qv), max(log_qv), 100)
        ref_line_y = log_lambda_est + delta * ref_line_x
        theory_line_y = log_lambda_theory + beta_theoretical * ref_line_x

        with fig_widget.batch_update():
            fig_widget.data = []
            fig_widget.layout.shapes = []

            # Plot L2 book
            fig_widget.add_bar(x=x_levels, y=book_prev, row=1, col=1, marker_color='orange')
            fig_widget.add_bar(x=x_levels, y=book_now, row=1, col=1, marker_color=book_colors)

            # Plot midprice series
            fig_widget.add_scatter(x=x, y=midprice_series, mode='lines', row=1, col=2, line=dict(width=1))
            fig_widget.add_shape(
                type="line", x0=t, x1=t, y0=min(midprice_series), y1=max(midprice_series),
                line=dict(color="green", width=2), xref="x2", yref="y2"
            )

            # Midprice insert dots
            insert_dots_x, insert_dots_y = [], []
            for pos in valid_insertions:
                if pos < len(midprice_series):
                    insert_dots_x.append(pos)
                    insert_dots_y.append(midprice_series[pos])
            fig_widget.add_scatter(
                x=insert_dots_x, y=insert_dots_y, mode='markers',
                marker=dict(color='red', size=5, symbol='circle'),
                row=1, col=2
            )

            # Market impact dots
            fig_widget.add_scatter(
                x=log_qv, y=log_impact,
                mode='markers',
                row=1, col=3,
                marker=dict(size=8, color='orange')
            )

            # Estimated regression line
            fig_widget.add_scatter(
                x=ref_line_x, y=ref_line_y,
                mode='lines',
                line=dict(color='black', dash='dot', width=2),
                row=1, col=3,
                name='Estimated'
            )

            # Theoretical β = 0.5 line
            fig_widget.add_scatter(
                x=ref_line_x, y=theory_line_y,
                mode='lines',
                line=dict(color='green', dash='dash', width=2),
                row=1, col=3,
                name='Theoretical β=0.5'
            )

            if t in valid_insertions:
                idx = valid_insertions.index(t)
                if idx < len(log_qv):
                    fig_widget.add_scatter(
                        x=[log_qv[idx]], y=[log_impact[idx]],
                        mode='markers',
                        marker=dict(color='red', size=12),
                        row=1, col=3
                    )

            fig_widget.update_xaxes(type="linear", row=1, col=3, title="log(Q / V)")
            fig_widget.update_yaxes(type="linear", row=1, col=3, title="log(Impact)")

        # Raw message info
        m = messages[t].astype(int)
        event_type, direction, abs_price, rel_price, size = m[1], m[2], m[3], m[4], m[5]
        event_map = {1: "Limit", 2: "PartialCancel", 3: "Delete", 4: "Execution"}
        direction_map = {1: "Buy", 0: "Sell"}
        msg_box.value = (
            f"<b>{event_map.get(event_type, '?')} • {direction_map.get(direction, '?')} "
            f"• abs={abs_price} • rel={rel_price} • size={size}</b><br>raw: {m.tolist()}"
        )

    def on_prev(_):
        if time_slider.value > time_slider.min:
            time_slider.value -= 1

    def on_next(_):
        if time_slider.value < time_slider.max:
            time_slider.value += 1

    id_dd.observe(lambda _: update_slider_range(), names='value')
    time_slider.observe(lambda _: update_plot(), names='value')
    btn_prev.on_click(on_prev)
    btn_next.on_click(on_next)

    update_slider_range()
    update_plot()

    display(widgets.HBox([id_dd, btn_prev, btn_next, time_slider]))
    display(widgets.HBox([fig_widget, coeff_box]))
    display(msg_box)

# %%
# interactive_market_impact_plot(b_dict, m_dict, all_series, x)

all_betas = interactive_market_impact_plot(b_dict, m_dict, all_series, x, hist_steps, gen_block, num_insertions)
# Out:
# HBox(children=(Dropdown(description='Sample ID:', options=(69, 97, 140, 220, 275, 339, 346, 410, 414, 453, 461…
# HBox(children=(FigureWidget({
#     'data': [{'marker': {'color': 'orange'},
#               'type': 'bar',
#       …
# HTML(value='<b>Execution • Sell • abs=898900 • rel=1 • size=75</b><br>raw: [77777777, 4, 0, 898900, 1, 75, 0, …

# %% [markdown]
# # Averaged market impact curve

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression
import plotly.colors

def plot_market_impact_loglog_regression(
    merged,
    msg_dict,
    hist_steps,
    gen_block,
    num_insertions,
    n_gen_msgs,
    midprice_step_size,
    daily_volume_estimate=250_000,
    height=800,
    width=1200,
):
    insert_positions = hist_steps + np.arange(1, num_insertions + 1) * gen_block

    log_qv_series = []
    log_impact_series = []

    for row in merged.itertuples(False):
        sid = int(row.id)
        if sid not in msg_dict:
            continue
        msgs = np.array(msg_dict[sid])
        valid_positions = [pos for pos in insert_positions if pos < len(msgs)]
        if len(valid_positions) == 0:
            continue

        reference_price_ticks = float(msgs[valid_positions[0], 3])
        cum_order_volume = 0.0
        cum_order_notional_ticks = 0.0

        log_qv, log_impact = [], []

        for pos in valid_positions:
            order_size = float(msgs[pos, 5])
            order_price_ticks = float(msgs[pos, 3])
            cum_order_volume += order_size
            cum_order_notional_ticks += order_size * order_price_ticks

            if cum_order_volume == 0:
                continue

            vwap_ticks = cum_order_notional_ticks / cum_order_volume
            impact_ticks = abs(vwap_ticks - reference_price_ticks)
            rel_size = cum_order_volume / daily_volume_estimate

            if impact_ticks <= 0 or rel_size <= 0:
                continue

            log_qv.append(np.log(rel_size))
            log_impact.append(np.log(impact_ticks))

        if len(log_qv) > 0:
            log_qv_series.append(log_qv)
            log_impact_series.append(log_impact)

    # Align by padding
    max_len = max(len(s) for s in log_qv_series)
    log_qv_matrix = np.vstack([
        np.pad(s, (0, max_len - len(s)), constant_values=np.nan)
        for s in log_qv_series
    ])
    log_impact_matrix = np.vstack([
        np.pad(s, (0, max_len - len(s)), constant_values=np.nan)
        for s in log_impact_series
    ])

    x_vals = np.nanmean(log_qv_matrix, axis=0)
    y_mean = np.nanmean(log_impact_matrix, axis=0)
    y_std = np.nanstd(log_impact_matrix, axis=0)

    # Linear regression on all aggregated points
    flat_x = np.concatenate(log_qv_series)
    flat_y = np.concatenate(log_impact_series)
    reg = LinearRegression().fit(flat_x.reshape(-1, 1), flat_y)
    beta_hat = reg.coef_[0]
    log_lambda_hat = reg.intercept_

    # Theoretical: same intercept, β = 0.5
    beta_theoretical = 0.5
    ref_line_x = np.linspace(min(flat_x), max(flat_x), 100)
    ref_line_y_est = log_lambda_hat + beta_hat * ref_line_x
    ref_line_y_theory = log_lambda_hat + beta_theoretical * ref_line_x

    # Plotting
    fig = go.Figure()

    # 🔹 Color palette
    palette = plotly.colors.qualitative.Plotly
    palette_len = len(palette)

    # 🔹 Add each individual trace with different color
    for idx, (x, y) in enumerate(zip(log_qv_series, log_impact_series)):
        color = palette[idx % palette_len]
        fig.add_trace(go.Scatter(
            x=x, y=y,
            mode='lines+markers',
            line=dict(width=2, color=color),
            marker=dict(size=4),
            name=f"Sample {idx+1}",
            showlegend=False  # Change to True if you want legend per series
        ))

    # 🔹 Add shaded std band
    fig.add_trace(go.Scatter(
        x=np.concatenate([x_vals, x_vals[::-1]]),
        y=np.concatenate([y_mean + y_std, (y_mean - y_std)[::-1]]),
        fill='toself', fillcolor='rgba(0,0,0,0.2)',
        line=dict(color='rgba(0,0,0,0)'), hoverinfo='skip',
        showlegend=True, name='±1 std'
    ))

    # 🔹 Add mean line
    fig.add_trace(go.Scatter(
        x=x_vals, y=y_mean,
        mode='lines+markers', name='Mean Impact',
        line=dict(color='black', width=3)
    ))

    # 🔹 Add regression line
    fig.add_trace(go.Scatter(
        x=ref_line_x, y=ref_line_y_est,
        mode='lines',
        name=f'Estimated β = {beta_hat:.2f}',
        line=dict(color='black', dash='dot')
    ))

    # 🔹 Add theoretical line
    fig.add_trace(go.Scatter(
        x=ref_line_x, y=ref_line_y_theory,
        mode='lines',
        name=f'Theoretical β = 0.5',
        line=dict(color='green', dash='dash')
    ))

    fig.update_layout(
        title="NOT CORRECT BECAUSE OF NOT-FIXED X. Market Impact (log-log) for Each Sample",
        xaxis_title="log(Q / V)",
        yaxis_title="log(Impact)",
        height=height,
        width=width,
        template="plotly_white",
    )

    return fig, ref_line_x, y_mean, y_std, beta_hat, log_lambda_hat

# %%
fig, ref_line_x, y_mean, y_std, beta_hat, log_lambda_hat = plot_market_impact_loglog_regression(
    merged=merged,
    msg_dict=m_dict,
    hist_steps=hist_steps,
    gen_block=gen_block,
    num_insertions=num_insertions,
    n_gen_msgs=n_gen_msgs,
    midprice_step_size=midprice_step_size,
)
fig.show()

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

def calculate_betas_across_samples(
    b_dict,          # dict[int → np.ndarray]
    m_dict,          # dict[int → np.ndarray]
    all_series,      # list[np.ndarray]
    x,               # shared x-axis, not needed here but kept for interface consistency
    hist_steps=550,
    gen_block=50,
    num_insertions=20,
    daily_volume_estimate=250_000
):
    all_betas = []

    for sample_id in sorted(b_dict.keys()):
        if sample_id not in m_dict:
            continue

        book_array = b_dict[sample_id]
        messages = m_dict[sample_id]

        insertion_positions = hist_steps + np.arange(1, num_insertions + 1) * gen_block
        valid_insertions = [pos for pos in insertion_positions if pos < len(messages)]

        if len(valid_insertions) < 2:
            continue

        reference_price_ticks = float(messages[valid_insertions[0], 3])
        cum_order_volume = 0.0
        cum_order_notional_ticks = 0.0

        log_qv = []
        log_impact = []

        for idx in valid_insertions:
            order_size = float(messages[idx, 5])
            order_price_ticks = float(messages[idx, 3])
            cum_order_volume += order_size
            cum_order_notional_ticks += order_size * order_price_ticks

            if cum_order_volume == 0:
                continue

            vwap_ticks = cum_order_notional_ticks / cum_order_volume
            impact_ticks = abs(vwap_ticks - reference_price_ticks)
            rel_size = cum_order_volume / daily_volume_estimate

            if impact_ticks <= 0 or rel_size <= 0:
                continue

            log_qv.append(np.log(rel_size))
            log_impact.append(np.log(impact_ticks))

        if len(log_qv) > 1:
            X = np.array(log_qv).reshape(-1, 1)
            y = np.array(log_impact)
            reg = LinearRegression().fit(X, y)
            beta = reg.coef_[0]
            all_betas.append(beta)

    return all_betas

# %%
betas = calculate_betas_across_samples(b_dict, m_dict, all_series, x)


import matplotlib.pyplot as plt

# Построить распределение
plt.hist(betas, bins=30, alpha=0.7)
plt.axvline(np.mean(betas), color='red', linestyle='--', label=f"Mean β = {np.mean(betas):.4f}")
plt.axvline(0.5, color='green', linestyle=':', label="β = 0.5 (theoretical)")
plt.title("Distribution of Estimated Market Impact Slopes (β)")
plt.xlabel("β")
plt.ylabel("Frequency")
plt.legend()
plt.show()
