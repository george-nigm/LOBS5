# %%
# %cd /app
# Out:
# /app

# %%
import argparse
import os
import sys

os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

import torch
torch.multiprocessing.set_start_method('spawn')

import jax
from lob.encoding import Vocab, Message_Tokenizer

from lob import inference_no_errcorr as inference
from lob.init_train import init_train_state, load_checkpoint, load_metadata, load_args_from_checkpoint

from lob import inference_no_errcorr as inference
import lob.encoding as encoding
import preproc as preproc

import jax.numpy as jnp
import numpy as onp

from pathlib import Path
import os

import pandas as pd
# Out:
# 2025-04-29 21:32:24.615661: W external/xla/xla/service/gpu/nvptx_compiler.cc:718] The NVIDIA driver's CUDA version is 12.6 which is older than the ptxas CUDA version (12.8.93). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# WARNING:absl:Type handler registry overriding type "<class 'float'>" collision on scalar
# WARNING:absl:Type handler registry overriding type "<class 'bytes'>" collision on scalar
# WARNING:absl:Type handler registry overriding type "<class 'numpy.number'>" collision on scalar
# 2025-04-29 21:32:27.642879: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os
from pathlib import Path
from datetime import datetime

def create_next_experiment_folder(save_folder: str) -> Path:
    """
    Сканирует save_folder, находит папки вида 'exp_<число>_*',
    определяет максимальный <число>, создаёт новую папку
    'exp_<max+1>_YYYYMMDD_HHMMSS' и возвращает её Path.
    """
    base = Path(save_folder)
    # Не создаём автоматически base — предполагаем, что папка есть или
    # что запись идёт в текущую директорию.
    if not base.exists():
        raise FileNotFoundError(f"Каталога {save_folder!r} не существует")

    max_idx = 0
    for entry in base.iterdir():
        if entry.is_dir() and entry.name.startswith("exp_"):
            parts = entry.name.split("_")
            if len(parts) >= 2 and parts[1].isdigit():
                idx = int(parts[1])
                max_idx = max(max_idx, idx)

    next_idx = max_idx + 1
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    new_folder_name = f"exp_{next_idx}_{timestamp}"
    new_folder = base / new_folder_name
    new_folder.mkdir()
    return new_folder

# %%
# == Parameters for Config == #

save_folder = 'data_saved/' # - need to scan folders in this folder and create next folder 2,3,...,99

batch_size = 4
n_samples = 20

n_gen_msgs = 50 # how many messages to generate into the future
midprice_step_size = 1

num_insertions = 20
num_coolings = 20

EVENT_TYPE_i = 4
DIRECTION_i = 0
order_volume = 75

# ======== #

# scale down to single GPU, single sample inference
bsz = 1 #1, 10
num_devices = 1

n_messages = 500  # length of input sequence to model
book_dim = 501 #b_enc.shape[1] 500+1=501
n_vol_series = 500
sample_top_n = -1

model_size = 'large'
data_dir ='data/test_set/'
sample_all = False # action='store_true'
stock = 'GOOG'  # 'GOOG', 'INTC'

tick_size = 100
sample_all = False
rng_seed = 42


# ======== #

v = Vocab()
n_classes = len(v)
seq_len = n_messages * Message_Tokenizer.MSG_LEN
book_seq_len = n_messages

n_eval_messages = n_gen_msgs
eval_seq_len = n_eval_messages * Message_Tokenizer.MSG_LEN

rng = jax.random.key(rng_seed)
rng, rng_ = jax.random.split(rng)

# %%
save_folder = create_next_experiment_folder(save_folder)
print("Created new experiment directory:", save_folder)
# Out:
# Created new experiment directory: data_saved/exp_3_20250429_213228

# %%
if stock == 'GOOG':
    # ckpt_path = './checkpoints/treasured-leaf-149_84yhvzjt/' # 0.5 y GOOG, (full model)
    ckpt_path = './checkpoints/denim-elevator-754_czg1ss71/' # large model
    # ckpt_path = './checkpoints/stilted-deluge-759_8g3vqor4'  # small model
elif stock == 'INTC':
    # ckpt_path = './checkpoints/pleasant-cherry-152_i6h5n74c/' # 0.5 y INTC, (full model)
    ckpt_path = './checkpoints/eager-sea-755_2rw1ofs3/'  # large model
else:
    raise ValueError(f'stock {stock} not recognized')

print('Loading metadata:', ckpt_path)
args_ckpt = load_metadata(ckpt_path)
# Out:
# Loading metadata: ./checkpoints/denim-elevator-754_czg1ss71/

# %%
# load train state from disk

print('Initializing model...')
new_train_state, model_cls = init_train_state(
    args_ckpt,
    n_classes=n_classes,
    seq_len=seq_len,
    book_dim=book_dim,
    book_seq_len=book_seq_len,
)

print('\nLoading model checkpoint...')
ckpt = load_checkpoint(
    new_train_state,
    ckpt_path,
    train=False,
)
state = ckpt['model']

model = model_cls(training=False, step_rescale=1.0)

param_count = sum(x.size for x in jax.tree_leaves(state.params))
print('param count:', param_count)
# Out:
# Initializing model...
# configuring standard optimization setup
# [*] Trainable Parameters: 35776312
#
# Loading model checkpoint...
# param count: 35776312
# /tmp/ipykernel_317408/2594640255.py:22: DeprecationWarning:
#
# jax.tree_leaves is deprecated: use jax.tree.leaves (jax v0.4.25 or newer) or jax.tree_util.tree_leaves (any JAX version).

# %%
# scale down to single GPU, single sample inference
args_ckpt.bsz = bsz #1, 10
args_ckpt.num_devices = num_devices

batchnorm = args_ckpt.batchnorm

data_dir = data_dir + stock
print(f"Directory Path: {data_dir}")
# Out:
# Directory Path: data/test_set/GOOG

# %%
data_dir = Path(data_dir)
Path(data_dir).mkdir(parents=True, exist_ok=True)
folder_path = Path(data_dir)
file_count = len([f for f in folder_path.iterdir() if f.is_file()])
print(f"There are {file_count} files in the folder {str(data_dir)}.")
# Out:
# There are 36 files in the folder data/test_set/GOOG.

# %%
print(n_messages, n_eval_messages)
# Out:
# 500 50

# %%
from pathlib import Path
import os

# Print current working directory to help verify the path
print(f"Current working directory: {os.getcwd()}")

# Use relative path to data/test_set/GOOG
data_dir = Path("data/test_set/GOOG")

try:
    Path(data_dir).mkdir(parents=True, exist_ok=True)
    print(f"Successfully created or verified directory: {data_dir}")
    
    file_count = len([f for f in Path(data_dir).iterdir() if f.is_file()])
    print(f"There are {file_count} files in the folder {data_dir}.")
except Exception as e:
    print(f"Error: {str(e)}")

ds = inference.get_dataset(data_dir, n_messages, n_eval_messages)
# Out:
# Current working directory: /app
# Successfully created or verified directory: data/test_set/GOOG
# There are 36 files in the folder data/test_set/GOOG.

# %% [markdown]
# # check 1 by 1

# %%
print(save_folder)
# Out:
# data_saved/exp_3_20250429_213228

# %%
inference.run_generation_scenario(
    n_samples, 
    batch_size,
    ds,
    rng,
    seq_len,
    n_messages,
    n_gen_msgs,
    state,
    model,
    batchnorm,
    v.ENCODING,
    stock,
    n_vol_series,
    save_folder,
    tick_size,
    sample_top_n,
    sample_all,
    num_insertions,
    num_coolings,
    midprice_step_size,
    EVENT_TYPE_i, 
    DIRECTION_i, 
    order_volume
    )
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# BATCH [7694, 15801, 3956, 30284]
#
# ITERATION  1
# Im using m_seq_raw_inp[:, :1, :]
# midprice after processing -499 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :2, :]
# midprice after processing -498 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :3, :]
# midprice after processing -497 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :4, :]
# midprice after processing -496 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :5, :]
# midprice after processing -495 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :6, :]
# midprice after processing -494 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :7, :]
# midprice after processing -493 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :8, :]
# midprice after processing -492 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :9, :]
# midprice after processing -491 messages = [888600 870400 901500 925000]
# Im using m_seq_raw_inp[:, :10, :]
# midprice after processing -490 messages = [888600 870400 901500 925000]
# Im using m_seq_raw_inp[:, :11, :]
# midprice after processing -489 messages = [888600 870400 901500 925000]
# Im using m_seq_raw_inp[:, :12, :]
# midprice after processing -488 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :13, :]
# midprice after processing -487 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :14, :]
# midprice after processing -486 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :15, :]
# midprice after processing -485 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :16, :]
# midprice after processing -484 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :17, :]
# midprice after processing -483 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :18, :]
# midprice after processing -482 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :19, :]
# midprice after processing -481 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :20, :]
# midprice after processing -480 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :21, :]
# midprice after processing -479 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :22, :]
# midprice after processing -478 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :23, :]
# midprice after processing -477 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :24, :]
# midprice after processing -476 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :25, :]
# midprice after processing -475 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :26, :]
# midprice after processing -474 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :27, :]
# midprice after processing -473 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :28, :]
# midprice after processing -472 messages = [888600 870400 901400 925100]
# Im using m_seq_raw_inp[:, :29, :]
# midprice after processing -471 messages = [888600 870400 901400 925100]
# Im using m_seq_raw_inp[:, :30, :]
# midprice after processing -470 messages = [888600 870400 901400 925100]
# Im using m_seq_raw_inp[:, :31, :]
# midprice after processing -469 messages = [888600 870400 901400 925100]
# Im using m_seq_raw_inp[:, :32, :]
# midprice after processing -468 messages = [888600 870400 901400 925100]
# Im using m_seq_raw_inp[:, :33, :]
# midprice after processing -467 messages = [888600 870400 901400 925100]
# Im using m_seq_raw_inp[:, :34, :]
# midprice after processing -466 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :35, :]
# midprice after processing -465 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :36, :]
# midprice after processing -464 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :37, :]
# midprice after processing -463 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :38, :]
# midprice after processing -462 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :39, :]
# midprice after processing -461 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :40, :]
# midprice after processing -460 messages = [888600 870400 901500 925100]
# Im using m_seq_raw_inp[:, :41, :]
# midprice after processing -459 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :42, :]
# midprice after processing -458 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :43, :]
# midprice after processing -457 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :44, :]
# midprice after processing -456 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :45, :]
# midprice after processing -455 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :46, :]
# midprice after processing -454 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :47, :]
# midprice after processing -453 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :48, :]
# midprice after processing -452 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :49, :]
# midprice after processing -451 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :50, :]
# midprice after processing -450 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :51, :]
# midprice after processing -449 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :52, :]
# midprice after processing -448 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :53, :]
# midprice after processing -447 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :54, :]
# midprice after processing -446 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :55, :]
# midprice after processing -445 messages = [888700 870400 901500 925200]
# Im using m_seq_raw_inp[:, :56, :]
# midprice after processing -444 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :57, :]
# midprice after processing -443 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :58, :]
# midprice after processing -442 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :59, :]
# midprice after processing -441 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :60, :]
# midprice after processing -440 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :61, :]
# midprice after processing -439 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :62, :]
# midprice after processing -438 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :63, :]
# midprice after processing -437 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :64, :]
# midprice after processing -436 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :65, :]
# midprice after processing -435 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :66, :]
# midprice after processing -434 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :67, :]
# midprice after processing -433 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :68, :]
# midprice after processing -432 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :69, :]
# midprice after processing -431 messages = [888600 870400 901500 925200]
# Im using m_seq_raw_inp[:, :70, :]
# midprice after processing -430 messages = [888600 870400 901400 925200]
# Im using m_seq_raw_inp[:, :71, :]
# midprice after processing -429 messages = [888600 870400 901400 925200]
# Im using m_seq_raw_inp[:, :72, :]
# midprice after processing -428 messages = [888600 870400 901400 925200]
# Im using m_seq_raw_inp[:, :73, :]
# midprice after processing -427 messages = [888600 870400 901400 925200]
# Im using m_seq_raw_inp[:, :74, :]
# midprice after processing -426 messages = [888600 870400 901400 925200]
# Im using m_seq_raw_inp[:, :75, :]
# midprice after processing -425 messages = [888600 870400 901400 925200]
# Im using m_seq_raw_inp[:, :76, :]
# midprice after processing -424 messages = [888600 870400 901400 925200]
# Im using m_seq_raw_inp[:, :77, :]
# midprice after processing -423 messages = [888600 870400 901400 925200]
# Im using m_seq_raw_inp[:, :78, :]
# midprice after processing -422 messages = [888500 870400 901400 925200]
# Im using m_seq_raw_inp[:, :79, :]
# midprice after processing -421 messages = [888500 870400 901400 925200]
# Im using m_seq_raw_inp[:, :80, :]
# midprice after processing -420 messages = [888500 870400 901400 925200]
# Im using m_seq_raw_inp[:, :81, :]
# midprice after processing -419 messages = [888500 870400 901400 925200]
# Im using m_seq_raw_inp[:, :82, :]
# midprice after processing -418 messages = [888500 870400 901400 925200]
# Im using m_seq_raw_inp[:, :83, :]
# midprice after processing -417 messages = [888500 870400 901400 925200]
# Im using m_seq_raw_inp[:, :84, :]
# midprice after processing -416 messages = [888500 870400 901400 925200]
# Im using m_seq_raw_inp[:, :85, :]
# midprice after processing -415 messages = [888500 870400 901400 925200]
# Im using m_seq_raw_inp[:, :86, :]
# midprice after processing -414 messages = [888500 870400 901500 925200]
# Im using m_seq_raw_inp[:, :87, :]
# midprice after processing -413 messages = [888500 870400 901500 925200]
# Im using m_seq_raw_inp[:, :88, :]
# midprice after processing -412 messages = [888500 870400 901500 925200]
# Im using m_seq_raw_inp[:, :89, :]
# midprice after processing -411 messages = [888500 870400 901500 925200]
# Im using m_seq_raw_inp[:, :90, :]
# midprice after processing -410 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :91, :]
# midprice after processing -409 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :92, :]
# midprice after processing -408 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :93, :]
# midprice after processing -407 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :94, :]
# midprice after processing -406 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :95, :]
# midprice after processing -405 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :96, :]
# midprice after processing -404 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :97, :]
# midprice after processing -403 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :98, :]
# midprice after processing -402 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :99, :]
# midprice after processing -401 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :100, :]
# midprice after processing -400 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :101, :]
# midprice after processing -399 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :102, :]
# midprice after processing -398 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :103, :]
# midprice after processing -397 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :104, :]
# midprice after processing -396 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :105, :]
# midprice after processing -395 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :106, :]
# midprice after processing -394 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :107, :]
# midprice after processing -393 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :108, :]
# midprice after processing -392 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :109, :]
# midprice after processing -391 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :110, :]
# midprice after processing -390 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :111, :]
# midprice after processing -389 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :112, :]
# midprice after processing -388 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :113, :]
# midprice after processing -387 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :114, :]
# midprice after processing -386 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :115, :]
# midprice after processing -385 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :116, :]
# midprice after processing -384 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :117, :]
# midprice after processing -383 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :118, :]
# midprice after processing -382 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :119, :]
# midprice after processing -381 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :120, :]
# midprice after processing -380 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :121, :]
# midprice after processing -379 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :122, :]
# midprice after processing -378 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :123, :]
# midprice after processing -377 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :124, :]
# midprice after processing -376 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :125, :]
# midprice after processing -375 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :126, :]
# midprice after processing -374 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :127, :]
# midprice after processing -373 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :128, :]
# midprice after processing -372 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :129, :]
# midprice after processing -371 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :130, :]
# midprice after processing -370 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :131, :]
# midprice after processing -369 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :132, :]
# midprice after processing -368 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :133, :]
# midprice after processing -367 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :134, :]
# midprice after processing -366 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :135, :]
# midprice after processing -365 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :136, :]
# midprice after processing -364 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :137, :]
# midprice after processing -363 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :138, :]
# midprice after processing -362 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :139, :]
# midprice after processing -361 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :140, :]
# midprice after processing -360 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :141, :]
# midprice after processing -359 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :142, :]
# midprice after processing -358 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :143, :]
# midprice after processing -357 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :144, :]
# midprice after processing -356 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :145, :]
# midprice after processing -355 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :146, :]
# midprice after processing -354 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :147, :]
# midprice after processing -353 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :148, :]
# midprice after processing -352 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :149, :]
# midprice after processing -351 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :150, :]
# midprice after processing -350 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :151, :]
# midprice after processing -349 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :152, :]
# midprice after processing -348 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :153, :]
# midprice after processing -347 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :154, :]
# midprice after processing -346 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :155, :]
# midprice after processing -345 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :156, :]
# midprice after processing -344 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :157, :]
# midprice after processing -343 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :158, :]
# midprice after processing -342 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :159, :]
# midprice after processing -341 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :160, :]
# midprice after processing -340 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :161, :]
# midprice after processing -339 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :162, :]
# midprice after processing -338 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :163, :]
# midprice after processing -337 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :164, :]
# midprice after processing -336 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :165, :]
# midprice after processing -335 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :166, :]
# midprice after processing -334 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :167, :]
# midprice after processing -333 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :168, :]
# midprice after processing -332 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :169, :]
# midprice after processing -331 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :170, :]
# midprice after processing -330 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :171, :]
# midprice after processing -329 messages = [888400 870400 901400 925200]
# Im using m_seq_raw_inp[:, :172, :]
# midprice after processing -328 messages = [888300 870400 901400 925200]
# Im using m_seq_raw_inp[:, :173, :]
# midprice after processing -327 messages = [888300 870400 901400 925200]
# Im using m_seq_raw_inp[:, :174, :]
# midprice after processing -326 messages = [888300 870400 901400 925200]
# Im using m_seq_raw_inp[:, :175, :]
# midprice after processing -325 messages = [888300 870400 901400 925200]
# Im using m_seq_raw_inp[:, :176, :]
# midprice after processing -324 messages = [888300 870400 901400 925200]
# Im using m_seq_raw_inp[:, :177, :]
# midprice after processing -323 messages = [888300 870400 901400 925200]
# Im using m_seq_raw_inp[:, :178, :]
# midprice after processing -322 messages = [888300 870400 901400 925200]
# Im using m_seq_raw_inp[:, :179, :]
# midprice after processing -321 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :180, :]
# midprice after processing -320 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :181, :]
# midprice after processing -319 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :182, :]
# midprice after processing -318 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :183, :]
# midprice after processing -317 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :184, :]
# midprice after processing -316 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :185, :]
# midprice after processing -315 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :186, :]
# midprice after processing -314 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :187, :]
# midprice after processing -313 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :188, :]
# midprice after processing -312 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :189, :]
# midprice after processing -311 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :190, :]
# midprice after processing -310 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :191, :]
# midprice after processing -309 messages = [888300 870400 901500 925200]
# Im using m_seq_raw_inp[:, :192, :]
# midprice after processing -308 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :193, :]
# midprice after processing -307 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :194, :]
# midprice after processing -306 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :195, :]
# midprice after processing -305 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :196, :]
# midprice after processing -304 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :197, :]
# midprice after processing -303 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :198, :]
# midprice after processing -302 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :199, :]
# midprice after processing -301 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :200, :]
# midprice after processing -300 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :201, :]
# midprice after processing -299 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :202, :]
# midprice after processing -298 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :203, :]
# midprice after processing -297 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :204, :]
# midprice after processing -296 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :205, :]
# midprice after processing -295 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :206, :]
# midprice after processing -294 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :207, :]
# midprice after processing -293 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :208, :]
# midprice after processing -292 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :209, :]
# midprice after processing -291 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :210, :]
# midprice after processing -290 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :211, :]
# midprice after processing -289 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :212, :]
# midprice after processing -288 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :213, :]
# midprice after processing -287 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :214, :]
# midprice after processing -286 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :215, :]
# midprice after processing -285 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :216, :]
# midprice after processing -284 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :217, :]
# midprice after processing -283 messages = [888400 870400 901500 925200]
# Im using m_seq_raw_inp[:, :218, :]
# midprice after processing -282 messages = [888400 870400 901500 925300]
# Im using m_seq_raw_inp[:, :219, :]
# midprice after processing -281 messages = [888400 870400 901500 925300]
# Im using m_seq_raw_inp[:, :220, :]
# midprice after processing -280 messages = [888400 870400 901500 925300]
# Im using m_seq_raw_inp[:, :221, :]
# midprice after processing -279 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :222, :]
# midprice after processing -278 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :223, :]
# midprice after processing -277 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :224, :]
# midprice after processing -276 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :225, :]
# midprice after processing -275 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :226, :]
# midprice after processing -274 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :227, :]
# midprice after processing -273 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :228, :]
# midprice after processing -272 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :229, :]
# midprice after processing -271 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :230, :]
# midprice after processing -270 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :231, :]
# midprice after processing -269 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :232, :]
# midprice after processing -268 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :233, :]
# midprice after processing -267 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :234, :]
# midprice after processing -266 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :235, :]
# midprice after processing -265 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :236, :]
# midprice after processing -264 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :237, :]
# midprice after processing -263 messages = [888300 870400 901500 925300]
# Im using m_seq_raw_inp[:, :238, :]
# midprice after processing -262 messages = [888300 870400 901500 925400]
# Im using m_seq_raw_inp[:, :239, :]
# midprice after processing -261 messages = [888300 870400 901500 925400]
# Im using m_seq_raw_inp[:, :240, :]
# midprice after processing -260 messages = [888300 870400 901500 925400]
# Im using m_seq_raw_inp[:, :241, :]
# midprice after processing -259 messages = [888300 870400 901500 925400]
# Im using m_seq_raw_inp[:, :242, :]
# midprice after processing -258 messages = [888300 870400 901500 925400]
# Im using m_seq_raw_inp[:, :243, :]
# midprice after processing -257 messages = [888300 870400 901500 925400]
# Im using m_seq_raw_inp[:, :244, :]
# midprice after processing -256 messages = [888300 870400 901500 925400]
# Im using m_seq_raw_inp[:, :245, :]
# midprice after processing -255 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :246, :]
# midprice after processing -254 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :247, :]
# midprice after processing -253 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :248, :]
# midprice after processing -252 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :249, :]
# midprice after processing -251 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :250, :]
# midprice after processing -250 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :251, :]
# midprice after processing -249 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :252, :]
# midprice after processing -248 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :253, :]
# midprice after processing -247 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :254, :]
# midprice after processing -246 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :255, :]
# midprice after processing -245 messages = [888300 870300 901500 925400]
# Im using m_seq_raw_inp[:, :256, :]
# midprice after processing -244 messages = [888300 870300 901500 925500]
# Im using m_seq_raw_inp[:, :257, :]
# midprice after processing -243 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :258, :]
# midprice after processing -242 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :259, :]
# midprice after processing -241 messages = [888400 870300 901400 925500]
# Im using m_seq_raw_inp[:, :260, :]
# midprice after processing -240 messages = [888400 870300 901400 925500]
# Im using m_seq_raw_inp[:, :261, :]
# midprice after processing -239 messages = [888400 870300 901400 925500]
# Im using m_seq_raw_inp[:, :262, :]
# midprice after processing -238 messages = [888400 870300 901400 925500]
# Im using m_seq_raw_inp[:, :263, :]
# midprice after processing -237 messages = [888400 870300 901400 925500]
# Im using m_seq_raw_inp[:, :264, :]
# midprice after processing -236 messages = [888400 870300 901400 925500]
# Im using m_seq_raw_inp[:, :265, :]
# midprice after processing -235 messages = [888400 870300 901400 925500]
# Im using m_seq_raw_inp[:, :266, :]
# midprice after processing -234 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :267, :]
# midprice after processing -233 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :268, :]
# midprice after processing -232 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :269, :]
# midprice after processing -231 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :270, :]
# midprice after processing -230 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :271, :]
# midprice after processing -229 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :272, :]
# midprice after processing -228 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :273, :]
# midprice after processing -227 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :274, :]
# midprice after processing -226 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :275, :]
# midprice after processing -225 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :276, :]
# midprice after processing -224 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :277, :]
# midprice after processing -223 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :278, :]
# midprice after processing -222 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :279, :]
# midprice after processing -221 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :280, :]
# midprice after processing -220 messages = [888300 870300 901400 925500]
# Im using m_seq_raw_inp[:, :281, :]
# midprice after processing -219 messages = [888200 870300 901400 925500]
# Im using m_seq_raw_inp[:, :282, :]
# midprice after processing -218 messages = [888200 870300 901400 925500]
# Im using m_seq_raw_inp[:, :283, :]
# midprice after processing -217 messages = [888200 870300 901400 925500]
# Im using m_seq_raw_inp[:, :284, :]
# midprice after processing -216 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :285, :]
# midprice after processing -215 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :286, :]
# midprice after processing -214 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :287, :]
# midprice after processing -213 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :288, :]
# midprice after processing -212 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :289, :]
# midprice after processing -211 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :290, :]
# midprice after processing -210 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :291, :]
# midprice after processing -209 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :292, :]
# midprice after processing -208 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :293, :]
# midprice after processing -207 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :294, :]
# midprice after processing -206 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :295, :]
# midprice after processing -205 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :296, :]
# midprice after processing -204 messages = [888200 870400 901400 925500]
# Im using m_seq_raw_inp[:, :297, :]
# midprice after processing -203 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :298, :]
# midprice after processing -202 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :299, :]
# midprice after processing -201 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :300, :]
# midprice after processing -200 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :301, :]
# midprice after processing -199 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :302, :]
# midprice after processing -198 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :303, :]
# midprice after processing -197 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :304, :]
# midprice after processing -196 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :305, :]
# midprice after processing -195 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :306, :]
# midprice after processing -194 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :307, :]
# midprice after processing -193 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :308, :]
# midprice after processing -192 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :309, :]
# midprice after processing -191 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :310, :]
# midprice after processing -190 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :311, :]
# midprice after processing -189 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :312, :]
# midprice after processing -188 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :313, :]
# midprice after processing -187 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :314, :]
# midprice after processing -186 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :315, :]
# midprice after processing -185 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :316, :]
# midprice after processing -184 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :317, :]
# midprice after processing -183 messages = [888300 870400 901400 925500]
# Im using m_seq_raw_inp[:, :318, :]
# midprice after processing -182 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :319, :]
# midprice after processing -181 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :320, :]
# midprice after processing -180 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :321, :]
# midprice after processing -179 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :322, :]
# midprice after processing -178 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :323, :]
# midprice after processing -177 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :324, :]
# midprice after processing -176 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :325, :]
# midprice after processing -175 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :326, :]
# midprice after processing -174 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :327, :]
# midprice after processing -173 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :328, :]
# midprice after processing -172 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :329, :]
# midprice after processing -171 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :330, :]
# midprice after processing -170 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :331, :]
# midprice after processing -169 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :332, :]
# midprice after processing -168 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :333, :]
# midprice after processing -167 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :334, :]
# midprice after processing -166 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :335, :]
# midprice after processing -165 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :336, :]
# midprice after processing -164 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :337, :]
# midprice after processing -163 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :338, :]
# midprice after processing -162 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :339, :]
# midprice after processing -161 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :340, :]
# midprice after processing -160 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :341, :]
# midprice after processing -159 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :342, :]
# midprice after processing -158 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :343, :]
# midprice after processing -157 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :344, :]
# midprice after processing -156 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :345, :]
# midprice after processing -155 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :346, :]
# midprice after processing -154 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :347, :]
# midprice after processing -153 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :348, :]
# midprice after processing -152 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :349, :]
# midprice after processing -151 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :350, :]
# midprice after processing -150 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :351, :]
# midprice after processing -149 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :352, :]
# midprice after processing -148 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :353, :]
# midprice after processing -147 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :354, :]
# midprice after processing -146 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :355, :]
# midprice after processing -145 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :356, :]
# midprice after processing -144 messages = [888400 870400 901400 925500]
# Im using m_seq_raw_inp[:, :357, :]
# midprice after processing -143 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :358, :]
# midprice after processing -142 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :359, :]
# midprice after processing -141 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :360, :]
# midprice after processing -140 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :361, :]
# midprice after processing -139 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :362, :]
# midprice after processing -138 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :363, :]
# midprice after processing -137 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :364, :]
# midprice after processing -136 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :365, :]
# midprice after processing -135 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :366, :]
# midprice after processing -134 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :367, :]
# midprice after processing -133 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :368, :]
# midprice after processing -132 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :369, :]
# midprice after processing -131 messages = [888400 870400 901300 925500]
# Im using m_seq_raw_inp[:, :370, :]
# midprice after processing -130 messages = [888400 870500 901300 925500]
# Im using m_seq_raw_inp[:, :371, :]
# midprice after processing -129 messages = [888400 870500 901200 925500]
# Im using m_seq_raw_inp[:, :372, :]
# midprice after processing -128 messages = [888400 870500 901200 925500]
# Im using m_seq_raw_inp[:, :373, :]
# midprice after processing -127 messages = [888400 870500 901200 925500]
# Im using m_seq_raw_inp[:, :374, :]
# midprice after processing -126 messages = [888400 870500 901200 925500]
# Im using m_seq_raw_inp[:, :375, :]
# midprice after processing -125 messages = [888400 870500 901200 925400]
# Im using m_seq_raw_inp[:, :376, :]
# midprice after processing -124 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :377, :]
# midprice after processing -123 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :378, :]
# midprice after processing -122 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :379, :]
# midprice after processing -121 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :380, :]
# midprice after processing -120 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :381, :]
# midprice after processing -119 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :382, :]
# midprice after processing -118 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :383, :]
# midprice after processing -117 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :384, :]
# midprice after processing -116 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :385, :]
# midprice after processing -115 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :386, :]
# midprice after processing -114 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :387, :]
# midprice after processing -113 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :388, :]
# midprice after processing -112 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :389, :]
# midprice after processing -111 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :390, :]
# midprice after processing -110 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :391, :]
# midprice after processing -109 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :392, :]
# midprice after processing -108 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :393, :]
# midprice after processing -107 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :394, :]
# midprice after processing -106 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :395, :]
# midprice after processing -105 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :396, :]
# midprice after processing -104 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :397, :]
# midprice after processing -103 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :398, :]
# midprice after processing -102 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :399, :]
# midprice after processing -101 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :400, :]
# midprice after processing -100 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :401, :]
# midprice after processing -99 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :402, :]
# midprice after processing -98 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :403, :]
# midprice after processing -97 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :404, :]
# midprice after processing -96 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :405, :]
# midprice after processing -95 messages = [888300 870400 901200 925500]
# Im using m_seq_raw_inp[:, :406, :]
# midprice after processing -94 messages = [888300 870400 901200 925500]
# Im using m_seq_raw_inp[:, :407, :]
# midprice after processing -93 messages = [888300 870400 901200 925500]
# Im using m_seq_raw_inp[:, :408, :]
# midprice after processing -92 messages = [888300 870400 901200 925400]
# Im using m_seq_raw_inp[:, :409, :]
# midprice after processing -91 messages = [888300 870400 901200 925400]
# Im using m_seq_raw_inp[:, :410, :]
# midprice after processing -90 messages = [888300 870400 901200 925400]
# Im using m_seq_raw_inp[:, :411, :]
# midprice after processing -89 messages = [888300 870400 901200 925400]
# Im using m_seq_raw_inp[:, :412, :]
# midprice after processing -88 messages = [888300 870400 901200 925400]
# Im using m_seq_raw_inp[:, :413, :]
# midprice after processing -87 messages = [888300 870400 901200 925400]
# Im using m_seq_raw_inp[:, :414, :]
# midprice after processing -86 messages = [888300 870400 901200 925500]
# Im using m_seq_raw_inp[:, :415, :]
# midprice after processing -85 messages = [888300 870400 901200 925500]
# Im using m_seq_raw_inp[:, :416, :]
# midprice after processing -84 messages = [888300 870400 901200 925500]
# Im using m_seq_raw_inp[:, :417, :]
# midprice after processing -83 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :418, :]
# midprice after processing -82 messages = [888300 870500 901200 925500]
# Im using m_seq_raw_inp[:, :419, :]
# midprice after processing -81 messages = [888300 870500 901300 925400]
# Im using m_seq_raw_inp[:, :420, :]
# midprice after processing -80 messages = [888300 870500 901300 925500]
# Im using m_seq_raw_inp[:, :421, :]
# midprice after processing -79 messages = [888300 870500 901300 925500]
# Im using m_seq_raw_inp[:, :422, :]
# midprice after processing -78 messages = [888300 870500 901300 925500]
# Im using m_seq_raw_inp[:, :423, :]
# midprice after processing -77 messages = [888300 870500 901300 925500]
# Im using m_seq_raw_inp[:, :424, :]
# midprice after processing -76 messages = [888300 870500 901300 925500]
# Im using m_seq_raw_inp[:, :425, :]
# midprice after processing -75 messages = [888300 870500 901300 925500]
# Im using m_seq_raw_inp[:, :426, :]
# midprice after processing -74 messages = [888300 870500 901300 925500]
# Im using m_seq_raw_inp[:, :427, :]
# midprice after processing -73 messages = [888400 870500 901300 925500]
# Im using m_seq_raw_inp[:, :428, :]
# midprice after processing -72 messages = [888400 870500 901300 925500]
# Im using m_seq_raw_inp[:, :429, :]
# midprice after processing -71 messages = [888400 870500 901300 925500]
# Im using m_seq_raw_inp[:, :430, :]
# midprice after processing -70 messages = [888400 870500 901300 925400]
# Im using m_seq_raw_inp[:, :431, :]
# midprice after processing -69 messages = [888400 870500 901300 925400]
# Im using m_seq_raw_inp[:, :432, :]
# midprice after processing -68 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :433, :]
# midprice after processing -67 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :434, :]
# midprice after processing -66 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :435, :]
# midprice after processing -65 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :436, :]
# midprice after processing -64 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :437, :]
# midprice after processing -63 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :438, :]
# midprice after processing -62 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :439, :]
# midprice after processing -61 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :440, :]
# midprice after processing -60 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :441, :]
# midprice after processing -59 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :442, :]
# midprice after processing -58 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :443, :]
# midprice after processing -57 messages = [888400 870500 901300 925300]
# Im using m_seq_raw_inp[:, :444, :]
# midprice after processing -56 messages = [888400 870500 901300 925200]
# Im using m_seq_raw_inp[:, :445, :]
# midprice after processing -55 messages = [888400 870500 901300 925200]
# Im using m_seq_raw_inp[:, :446, :]
# midprice after processing -54 messages = [888400 870500 901200 925200]
# Im using m_seq_raw_inp[:, :447, :]
# midprice after processing -53 messages = [888400 870500 901200 925200]
# Im using m_seq_raw_inp[:, :448, :]
# midprice after processing -52 messages = [888400 870500 901200 925300]
# Im using m_seq_raw_inp[:, :449, :]
# midprice after processing -51 messages = [888400 870500 901200 925300]
# ...
# midprice after processing -476 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :25, :]
# midprice after processing -475 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :26, :]
# midprice after processing -474 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :27, :]
# midprice after processing -473 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :28, :]
# midprice after processing -472 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :29, :]
# midprice after processing -471 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :30, :]
# midprice after processing -470 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :31, :]
# midprice after processing -469 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :32, :]
# midprice after processing -468 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :33, :]
# midprice after processing -467 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :34, :]
# midprice after processing -466 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :35, :]
# midprice after processing -465 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :36, :]
# midprice after processing -464 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :37, :]
# midprice after processing -463 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :38, :]
# midprice after processing -462 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :39, :]
# midprice after processing -461 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :40, :]
# midprice after processing -460 messages = [906400 861000 894000 907600]
# Im using m_seq_raw_inp[:, :41, :]
# midprice after processing -459 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :42, :]
# midprice after processing -458 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :43, :]
# midprice after processing -457 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :44, :]
# midprice after processing -456 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :45, :]
# midprice after processing -455 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :46, :]
# midprice after processing -454 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :47, :]
# midprice after processing -453 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :48, :]
# midprice after processing -452 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :49, :]
# midprice after processing -451 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :50, :]
# midprice after processing -450 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :51, :]
# midprice after processing -449 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :52, :]
# midprice after processing -448 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :53, :]
# midprice after processing -447 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :54, :]
# midprice after processing -446 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :55, :]
# midprice after processing -445 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :56, :]
# midprice after processing -444 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :57, :]
# midprice after processing -443 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :58, :]
# midprice after processing -442 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :59, :]
# midprice after processing -441 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :60, :]
# midprice after processing -440 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :61, :]
# midprice after processing -439 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :62, :]
# midprice after processing -438 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :63, :]
# midprice after processing -437 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :64, :]
# midprice after processing -436 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :65, :]
# midprice after processing -435 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :66, :]
# midprice after processing -434 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :67, :]
# midprice after processing -433 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :68, :]
# midprice after processing -432 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :69, :]
# midprice after processing -431 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :70, :]
# midprice after processing -430 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :71, :]
# midprice after processing -429 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :72, :]
# midprice after processing -428 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :73, :]
# midprice after processing -427 messages = [906300 861000 894000 907600]
# Im using m_seq_raw_inp[:, :74, :]
# midprice after processing -426 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :75, :]
# midprice after processing -425 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :76, :]
# midprice after processing -424 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :77, :]
# midprice after processing -423 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :78, :]
# midprice after processing -422 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :79, :]
# midprice after processing -421 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :80, :]
# midprice after processing -420 messages = [906200 861000 894000 907700]
# Im using m_seq_raw_inp[:, :81, :]
# midprice after processing -419 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :82, :]
# midprice after processing -418 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :83, :]
# midprice after processing -417 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :84, :]
# midprice after processing -416 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :85, :]
# midprice after processing -415 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :86, :]
# midprice after processing -414 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :87, :]
# midprice after processing -413 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :88, :]
# midprice after processing -412 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :89, :]
# midprice after processing -411 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :90, :]
# midprice after processing -410 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :91, :]
# midprice after processing -409 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :92, :]
# midprice after processing -408 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :93, :]
# midprice after processing -407 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :94, :]
# midprice after processing -406 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :95, :]
# midprice after processing -405 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :96, :]
# midprice after processing -404 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :97, :]
# midprice after processing -403 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :98, :]
# midprice after processing -402 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :99, :]
# midprice after processing -401 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :100, :]
# midprice after processing -400 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :101, :]
# midprice after processing -399 messages = [906400 861000 894000 907700]
# Im using m_seq_raw_inp[:, :102, :]
# midprice after processing -398 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :103, :]
# midprice after processing -397 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :104, :]
# midprice after processing -396 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :105, :]
# midprice after processing -395 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :106, :]
# midprice after processing -394 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :107, :]
# midprice after processing -393 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :108, :]
# midprice after processing -392 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :109, :]
# midprice after processing -391 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :110, :]
# midprice after processing -390 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :111, :]
# midprice after processing -389 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :112, :]
# midprice after processing -388 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :113, :]
# midprice after processing -387 messages = [906300 861000 894000 907700]
# Im using m_seq_raw_inp[:, :114, :]
# midprice after processing -386 messages = [906200 861000 894000 907700]
# Im using m_seq_raw_inp[:, :115, :]
# midprice after processing -385 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :116, :]
# midprice after processing -384 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :117, :]
# midprice after processing -383 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :118, :]
# midprice after processing -382 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :119, :]
# midprice after processing -381 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :120, :]
# midprice after processing -380 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :121, :]
# midprice after processing -379 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :122, :]
# midprice after processing -378 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :123, :]
# midprice after processing -377 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :124, :]
# midprice after processing -376 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :125, :]
# midprice after processing -375 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :126, :]
# midprice after processing -374 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :127, :]
# midprice after processing -373 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :128, :]
# midprice after processing -372 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :129, :]
# midprice after processing -371 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :130, :]
# midprice after processing -370 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :131, :]
# midprice after processing -369 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :132, :]
# midprice after processing -368 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :133, :]
# midprice after processing -367 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :134, :]
# midprice after processing -366 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :135, :]
# midprice after processing -365 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :136, :]
# midprice after processing -364 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :137, :]
#  20%|██        | 1/5 [3:10:45<12:43:00, 11445.18s/it]E0430 00:46:08.042236  317408 pjrt_stream_executor_client.cc:2809] Execution of replica 0 failed: RESOURCE_EXHAUSTED: CUDA driver ran out of memory trying to instantiate CUDA graph with 36 nodes and 0 conditionals (total of 0 alive CUDA graphs in the process). You can try to (a) Give more memory to CUDA driver by reducing XLA_PYTHON_CLIENT_MEM_FRACTION (b) Disable CUDA graph with 'XLA_FLAGS=--xla_gpu_enable_command_buffer=' (empty set). Original error: Failed to instantiate CUDA graph:CUDA_ERROR_OUT_OF_MEMORY: out of memory
# midprice after processing -363 messages = [906200 861000 894000 907600]
# Im using m_seq_raw_inp[:, :138, :]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱  1 inference.run_generation_scenario(                                                          │
# │    2 │   n_samples,                                                                              │
# │    3 │   batch_size,                                                                             │
# │    4 │   ds,                                                                                     │
# │                                                                                                  │
# │ /app/lob/inference_no_errcorr.py:1425 in run_generation_scenario                                 │
# │                                                                                                  │
# │   1422 │   │   │   │                                                                             │
# │   1423 │   │   │   │   sim_init, sim_states_init = get_sims_vmap(book_l2_init, m_seq_raw_inp)    │
# │   1424 │   │   │   │                                                                             │
# │ ❱ 1425 │   │   │   │   midprices, proc_msgs_numb = track_midprices_during_messages(midprices, p  │
# │   1426 │   │   │                                                                                 │
# │   1427 │   │   │   else:                                                                         │
# │   1428 │   │   │   │   m_seq = m_seq_gen_doubled                                                 │
# │                                                                                                  │
# │ /app/lob/inference_no_errcorr.py:1228 in track_midprices_during_messages                         │
# │                                                                                                  │
# │   1225 │                                                                                         │
# │   1226 │   for idx, i in enumerate(range(step_size, m_seq_raw_inp.shape[1] + 1, step_size)):     │
# │   1227 │   │   print(f'Im using m_seq_raw_inp[:, :{i}, :]')                                      │
# │ ❱ 1228 │   │   sim_init, sim_states_init = get_sims_vmap(book_l2_init, m_seq_raw_inp[:, :i, :])  │
# │   1229 │   │   mid_price = batched_get_safe_mid_price(sim_init, sim_states_init, tick_size)      │
# │   1230 │   │   midprices.append(mid_price)                                                       │
# │   1231 │   │   print(f'midprice after processing {proc_msgs_numb+(idx+1)*step_size} messages ='  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: RESOURCE_EXHAUSTED: CUDA driver ran out of memory trying to instantiate CUDA graph with 36 nodes and 0
# conditionals (total of 0 alive CUDA graphs in the process). You can try to (a) Give more memory to CUDA driver by
# reducing XLA_PYTHON_CLIENT_MEM_FRACTION (b) Disable CUDA graph with 'XLA_FLAGS=--xla_gpu_enable_command_buffer='
# (empty set). Original error: Failed to instantiate CUDA graph:CUDA_ERROR_OUT_OF_MEMORY: out of memory
