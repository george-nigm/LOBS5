# %% [markdown]
# # 📖 Order-book player
#
# Pick a sample → watch the **mid-price**, step through messages with **◀ ▶** (or the slider /
# **→ Next Aggr**). Each step shows the book **было (t-1) | стало (t)** with the change coloured:
# **<span style="color:#C0392B">red = volume ↑ (added)</span>**,
# **<span style="color:#2F5DA3">blue = volume ↓ (executed/removed)</span>**.
# A removed/executed level is present in *было* and gone (gap) in *стало*. The badge ◆ AGGRESSIVE
# marks the injected metaorder steps.
#
# Run this in **JupyterLab with the `lobs5` kernel** (has plotly + ipywidgets).

# %%
# %matplotlib inline
import book_player as bp
from book_player import lob_player, discover, GRID

# what's available in the grid:
for exp, sides in discover(GRID).items():
    print(f'{exp:24s} sides: {list(sides)}')

# %%
# change exp / side as you like (e.g. 'NVDA-Mamba3-beta', 'AMD-Historic-beta', side='sell')
lob_player(GRID, exp='EA-Mamba3-beta', side='buy')
