# %%
# %cd /app
# Out:
# /app

# %%
import argparse
import os
import sys

os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

import torch
torch.multiprocessing.set_start_method('spawn')

import jax
from lob.encoding import Vocab, Message_Tokenizer

from lob import inference_no_errcorr as inference
from lob.init_train import init_train_state, load_checkpoint, load_metadata, load_args_from_checkpoint

from lob import inference_no_errcorr as inference
import lob.encoding as encoding
import preproc as preproc

import jax.numpy as jnp
import numpy as np

from pathlib import Path
import os

import pandas as pd
import plotly.graph_objs as go
import yaml

from filtration_utils import summary_table, build_zero_padded_series, plot_midprice_series_with_insertions, prepare_volatility_filtered_series, plot_midprice_series_with_mean_std

import os
import yaml
import numpy as np
import pandas as pd
from typing import Dict, Tuple, Any
from sklearn.linear_model import LinearRegression
# Out:
# 2025-08-21 20:14:08.405981: W external/xla/xla/service/gpu/nvptx_compiler.cc:718] The NVIDIA driver's CUDA version is 12.8 which is older than the ptxas CUDA version (12.9.41). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# WARNING:absl:Type handler registry overriding type "<class 'float'>" collision on scalar
# WARNING:absl:Type handler registry overriding type "<class 'bytes'>" collision on scalar
# WARNING:absl:Type handler registry overriding type "<class 'numpy.number'>" collision on scalar
# 2025-08-21 20:14:10.665503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# ======= CONFIGURATION =======
experiments = {
    "Plain": 'exp_21_20250804_215633_hist_plain_whole_352',
    "Heuristic": 'exp_22_20250804_215639_hist_heur_whole_360',
    "GenAI": 'exp_42_20250807_133402_gen_buy_whole_272',
}

DATA_ROOT = "/app/data_saved"  # base dir used in your plotting code

sample_day_map = pd.read_csv('/app/sample_day_map_42.csv')

# %%
import yaml
import numpy as np
import plotly.graph_objects as go

# Colors for each experiment
colors = {
    "Plain": 'black',
    "Heuristic": 'blue',
    "GenAI": 'red',
}

# Dash style per cutoff
dash_for_cutoff = {
    0.0: "solid",
    0.2: "dot",
    0.4: "dash",
    0.6: "longdash",
    0.8: "dashdot"
}

# Cutoffs to run
CUTOFFS = [0.0]

fig = go.Figure()

for label, exp_name in experiments.items():
    # === Load config ===
    CONFIG_PATH = f"{DATA_ROOT}/{exp_name}/used_config.yaml"
    with open(CONFIG_PATH, 'r') as f:
        config = yaml.safe_load(f)

    num_insertions      = config["num_insertions"]
    num_coolings        = config["num_coolings"]
    midprice_step_size  = config["midprice_step_size"]
    hist_msgs           = config["n_messages"]
    n_gen_msgs          = config["n_gen_msgs"]

    # Base merged for filtration
    merged = summary_table(exp_name)

    for cutoff in CUTOFFS:
        # Apply volatility filtration
        x_filt, all_series_filt, merged_filt, hist_steps_filt, gen_block_filt = prepare_volatility_filtered_series(
            merged, hist_msgs, n_gen_msgs, midprice_step_size, volatility_cutoff=cutoff
        )

        # === Mean & Std after filtration ===
        mean_series = all_series_filt.mean(axis=0)
        std_series  = all_series_filt.std(axis=0)

        # ±1 std band
        fig.add_trace(go.Scatter(
            x=np.concatenate([x_filt, x_filt[::-1]]),
            y=np.concatenate([mean_series + std_series, (mean_series - std_series)[::-1]]),
            fill='toself',
            fillcolor='rgba(0,0,0,0.05)',
            line=dict(color='rgba(0,0,0,0)'),
            hoverinfo='skip',
            showlegend=False
        ))

        # Mean line
        fig.add_trace(go.Scatter(
            x=x_filt, y=mean_series, mode='lines',
            name=f"{label} Mean (cutoff={cutoff})",
            line=dict(color=colors[label], width=3, dash=dash_for_cutoff.get(cutoff, "solid"))
        ))

# Add reference lines
fig.add_hline(y=0, line=dict(color='gray', dash='dash'), name="Zero line")

fig.update_layout(
    title="Midprice Mean ±1 Std — volatility cutoffs",
    xaxis_title="Steps (sampled midprice points)",
    yaxis_title="Price – first price",
    template="plotly_white",
    hovermode="x unified",
    height=800,
    width=800,
    legend=dict(x=0.01, y=0.99),
)
fig.show()
# Out:
# Before filtering: 352 samples
#
# After filtering: 352 samples
#
# Before filtering: 360 samples
#
# After filtering: 360 samples
#
# Before filtering: 272 samples
#
# After filtering: 272 samples

# %%
def calculate_impact(messages, valid_insertions, reference_price):
    """
    Calculate market impact for each insertion.
    
    Parameters
    ----------
    messages : np.array
        Message array with columns [EVENT_TYPE, DIRECTION, PRICE, REL, SIZE, ...]
    valid_insertions : list
        List of insertion indices
    reference_price : float
        Reference price at first insertion
        
    Returns
    -------
    impact : np.array
        Absolute impact for each insertion
    vwap_series : np.array
        VWAP series for each insertion
    Q_cum : np.array
        Cumulative quantity for each insertion
    log_imp : np.array
        Log of impact values for plotting
    """
    PRICE_COL = 3
    SIZE_COL = 5
    insert_sizes = messages[valid_insertions, SIZE_COL].astype(float)
    insert_prices = messages[valid_insertions, PRICE_COL].astype(float)
    Q_cum = np.cumsum(insert_sizes)
    notional = np.cumsum(insert_sizes * insert_prices)

    vwap_series = notional / np.maximum(Q_cum, 1e-12)
    # vwap_series = insert_prices
    
    impact = np.abs(vwap_series - reference_price) / reference_price
    
    # Calculate log impact for plotting (y-axis)
    eps = 1e-12
    log_imp = np.log(np.maximum(impact, eps))
    
    return impact, vwap_series, Q_cum, log_imp


def calculate_market_volume(messages, hist_steps, valid_insertions, execution_sum):
    """
    Calculate market execution volume V_exp for each insertion and return x-axis values for plotting.
    
    Parameters
    ----------
    messages : np.array
        Message array with columns [EVENT_TYPE, DIRECTION, PRICE, REL, SIZE, ...]
    hist_steps : int
        Starting index for market volume calculation
    valid_insertions : list
        List of insertion indices
    execution_sum : float
        Total execution sum for the day
        
    Returns
    -------
    V_exp : np.array
        Market volume from hist_steps to (idx-1) for each insertion
    log_qv : np.array
        Log of Q/V_exp ratio for plotting (x-axis)
    """
    EVENT_TYPE_COL = 1
    SIZE_COL = 5
    
    evt_types = messages[:, EVENT_TYPE_COL].astype(int)
    exec_sizes = np.where(evt_types == 4, messages[:, SIZE_COL].astype(float), 0.0)
    cum_exec_vol = np.cumsum(exec_sizes)
    
    V_exp = np.array([float(cum_exec_vol[idx-1] - cum_exec_vol[hist_steps-1] if (idx-1) >= hist_steps else 0.0)
                      for idx in valid_insertions])

    # Use execution_sum instead of fixed value
    V_exp = np.full_like(V_exp, execution_sum)
    
    # Calculate cumulative quantity for Q/V_exp ratio
    insert_sizes = messages[valid_insertions, SIZE_COL].astype(float)
    Q_cum = np.cumsum(insert_sizes)
    
    # Calculate log(Q/V_exp) for plotting (x-axis)
    eps = 1e-12
    rel_size = Q_cum / np.maximum(V_exp, eps)
    log_qv = np.log(np.maximum(rel_size, eps))

    return V_exp, log_qv

# %%
# ===== Tail-only β(a) with filtration @ cutoffs = {0.0} for all experiments =====
import os, yaml, glob, re
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# --- config / styles ---
CUTOFFS = [0.0, 0.1, 0.2]         # keep filtration pipeline; add 0.2 if you want
TAIL_ONLY = True        # clarity flag
colors = {"Plain": "black", "Heuristic": "blue", "GenAI": "red"}
dash_for_cutoff = {0.0: "solid", 0.1: "solid", 0.1: "solid"}  # style by cutoff
TICK_SIZE = 100         # ticks -> $ conversion used for H/L and message prices

# --- tiny utilities ---
def _safe_col(df, preferred, fallbacks):
    if preferred in df.columns: return preferred
    for c in fallbacks:
        if c in df.columns: return c
    return None

def build_and_merge(folder, batch_prefix, inp_prefix):
    files   = glob.glob(os.path.join(folder, "*.npy"))
    rx_iter = re.compile(rf"{re.escape(batch_prefix)}_\[(.+)\]_iter_(\d+)\.npy$")
    rx_inp  = re.compile(rf"{re.escape(inp_prefix)}_\[(.+)\]\.npy$")
    rec = []
    for f in files:
        nm = os.path.basename(f)
        m  = rx_iter.match(nm)
        if m:
            rng, itr = m.group(1).replace(" ", ""), int(m.group(2))
        else:
            m2 = rx_inp.match(nm)
            if not m2: 
                continue
            rng, itr = m2.group(1).replace(" ", ""), 0
        batch = np.load(f)  # (batch, time, feat)
        rec.append({"range": rng, "iteration": itr, "batch": batch})
    df = pd.DataFrame(rec).sort_values(["range","iteration"]).reset_index(drop=True)
    df["ids"] = df["range"].str.split(",").apply(lambda L: [int(x) for x in L])

    rows = []
    for _, r in df.iterrows():
        for idx, sample_id in enumerate(r["ids"]):
            single = r["batch"][idx]   # (time, feat)
            if r["iteration"] > 0:
                n_keep = 51 if r["iteration"] <= num_insertions else 50
                single = single[-n_keep:, :]
            rows.append({"id": int(sample_id), "iteration": int(r["iteration"]), "data": single})
    df_sorted = pd.DataFrame(rows).sort_values(["id","iteration"]).reset_index(drop=True)

    merged = []
    for id_val, grp in df_sorted.groupby("id", sort=True):
        arrs = [row.data for _, row in grp.iterrows()]
        big  = np.concatenate(arrs, axis=0)
        merged.append({"id": int(id_val), "merged_data": big})
    merged_df = pd.DataFrame(merged).sort_values("id").reset_index(drop=True)
    return df, df_sorted, merged_df

# === core: replicate dashboard x/y + α per sample (Parkinson), then tail β(a) with fixed intercept ===
def _compute_points_and_coeffs_like_dashboard(
    b_dict_local, m_dict_local, *, hist_steps, gen_block, num_insertions, sample_day_map, tick_size=100
):
    EVENT_TYPE_COL = 1
    PRICE_COL      = 3
    SIZE_COL       = 5
    eps = 1e-12
    tol = 1e-12

    sample_ids = sorted(set(b_dict_local.keys()) & set(m_dict_local.keys()))
    rows_points, coeff_rows = [], []

    for sid in sample_ids:
        messages_ticks = m_dict_local[sid]
        T = len(messages_ticks)

        # scheduled insertions
        insertion_positions = hist_steps + np.arange(1, num_insertions + 1) * gen_block
        valid_insertions = [pos for pos in insertion_positions if pos < T]
        if not valid_insertions:
            coeff_rows.append({"sample_id": sid, "alpha_hat": np.nan})
            continue

        # reference price at first insertion (ticks -> $)
        ref_idx = valid_insertions[0]
        reference_price = float(messages_ticks[ref_idx, PRICE_COL]) / tick_size

        # H, L, execution_sum from sample_day_map (fallback to window)
        try:
            day_row = sample_day_map[sample_day_map['sample_id'] == sid]
            if not day_row.empty:
                H_ticks = float(day_row.iloc[0]['highest_price'])
                L_ticks = float(day_row.iloc[0]['lowest_price'])
                execution_sum = float(day_row.iloc[0]['execution_sum'])
            else:
                H_ticks = float(np.max(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.max(messages_ticks[:, PRICE_COL]))
                L_ticks = float(np.min(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.min(messages_ticks[:, PRICE_COL]))
                exec_mask = (messages_ticks[:, EVENT_TYPE_COL].astype(int) == 4)
                execution_sum = float(np.sum(messages_ticks[exec_mask, SIZE_COL].astype(float)))
        except Exception:
            H_ticks = float(np.max(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.max(messages_ticks[:, PRICE_COL]))
            L_ticks = float(np.min(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.min(messages_ticks[:, PRICE_COL]))
            exec_mask = (messages_ticks[:, EVENT_TYPE_COL].astype(int) == 4)
            execution_sum = float(np.sum(messages_ticks[exec_mask, SIZE_COL].astype(float)))

        # Parkinson η_day and α = ln(η_day)
        H = float(H_ticks) / tick_size
        L = float(L_ticks) / tick_size
        if np.isfinite(H) and np.isfinite(L) and H > L and L > 0:
            eta_day = np.log(H / L) / 0.8325546
            alpha_fixed = float(np.log(max(eta_day, eps)))
        else:
            eta_day = eps
            alpha_fixed = float(np.log(eta_day))

        # convert messages to dollars for helper funcs
        messages_dollars = messages_ticks.astype(float).copy()
        messages_dollars[:, PRICE_COL] /= tick_size

        # your helper funcs (unchanged) — IMPORTANT: market_volume takes execution_sum now
        impact, vwap_series, Q_cum, log_imp = calculate_impact(
            messages_dollars, valid_insertions, reference_price
        )
        V_exp, log_qv = calculate_market_volume(
            messages_dollars, hist_steps, valid_insertions, execution_sum
        )

        mask_zero = impact <= tol
        for j, _idx in enumerate(valid_insertions):
            if mask_zero[j] or (not np.isfinite(log_qv[j])) or (not np.isfinite(log_imp[j])):
                continue
            rows_points.append({
                "sample_id": sid,
                "insertion": int(j + 1),
                "x": float(log_qv[j]),
                "y": float(log_imp[j]),
            })

        coeff_rows.append({"sample_id": sid, "alpha_hat": alpha_fixed})

    points_df = pd.DataFrame(rows_points)
    coeffs_df = pd.DataFrame.from_records(coeff_rows).set_index("sample_id").sort_index() if coeff_rows else pd.DataFrame()
    return points_df, coeffs_df

def _fit_beta_tail(points_df, alpha_global):
    """
    Tail-only β(a): for each a, use all points with insertion >= a
    and compute fixed-intercept slope: mean((y - alpha_global)/x).
    """
    if points_df is None or len(points_df) == 0:
        return np.array([]), np.array([])

    COL_INS = "insertion" if "insertion" in points_df.columns else _safe_col(points_df, "insertion", ["ins_idx","idx"])
    COL_X   = "x"         if "x"         in points_df.columns else _safe_col(points_df, "x", ["log_qv"])
    COL_Y   = "y"         if "y"         in points_df.columns else _safe_col(points_df, "y", ["log_impact"])
    if COL_INS is None or COL_X is None or COL_Y is None:
        return np.array([]), np.array([])

    ins = pd.to_numeric(points_df[COL_INS], errors="coerce").dropna().astype(int)
    if ins.empty:
        return np.array([]), np.array([])

    ins_min, ins_max = int(ins.min()), int(ins.max())
    a_values = np.arange(ins_min, ins_max + 1, dtype=int)

    X_all = points_df[COL_X].to_numpy(dtype=float)
    Y_all = points_df[COL_Y].to_numpy(dtype=float)
    ins_a = ins.to_numpy(dtype=int)

    betas = np.full_like(a_values, np.nan, dtype=float)
    for i, a in enumerate(a_values):
        mask = ins_a >= a
        X = X_all[mask]; Y = Y_all[mask]
        valid = np.isfinite(X) & np.isfinite(Y) & (X != 0)
        if valid.sum() >= 2:
            betas[i] = float(np.mean((Y[valid] - alpha_global) / X[valid]))
    return a_values, betas

# --- main plotting ---
fig = go.Figure()

for label, exp_name in experiments.items():
    # 1) Load config
    CONFIG_PATH = f"{DATA_ROOT}/{exp_name}/used_config.yaml"
    with open(CONFIG_PATH, "r") as f:
        config = yaml.safe_load(f)

    num_insertions      = int(config["num_insertions"])
    midprice_step_size  = int(config["midprice_step_size"])
    hist_msgs           = int(config["n_messages"])
    n_gen_msgs          = int(config["n_gen_msgs"])

    # 2) Base series (unchanged for time axes/steps)
    merged = summary_table(exp_name)
    x_base, all_series_base = build_zero_padded_series(hist_msgs, n_gen_msgs, midprice_step_size, merged)
    hist_steps_base = hist_msgs // midprice_step_size
    gen_steps_base  = n_gen_msgs // midprice_step_size
    gen_block_base  = gen_steps_base + 1

    # 3) Build merged dicts for b & m ONCE per experiment
    b_folder      = f"{DATA_ROOT}/{exp_name}/b_seq_gen_doubled"
    b_batch_pref  = "b_seq_gen_doubled_batch"
    b_inp_pref    = "b_seq_inp"

    m_folder      = f"{DATA_ROOT}/{exp_name}/msgs_decoded_doubled"
    m_batch_pref  = "msgs_decoded_doubled_batch"
    m_inp_pref    = "m_seq_raw_inp"

    _, b_sorted, b_merged = build_and_merge(b_folder, b_batch_pref, b_inp_pref)
    _, m_sorted, m_merged = build_and_merge(m_folder, m_batch_pref, m_inp_pref)

    b_dict_full = {int(r.id): np.array(r.merged_data) for _, r in b_merged.iterrows()}
    m_dict_full = {int(r.id): np.array(r.merged_data) for _, r in m_merged.iterrows()}

    # add a zero row at the top of each sample (parity with your other notebook)
    for d in (b_dict_full, m_dict_full):
        for key, arr in d.items():
            zero = np.zeros((1, arr.shape[1]), dtype=arr.dtype)
            d[key] = np.vstack([zero, arr])

    # 4) For each cutoff, filter + compute tail β(a)
    for cutoff in CUTOFFS:
        x_filt, all_series_filt, merged_filt, hist_steps_filt, gen_block_filt = prepare_volatility_filtered_series(
            merged, hist_msgs, n_gen_msgs, midprice_step_size, volatility_cutoff=cutoff
        )
        filtered_ids = set(merged_filt["id"])
        print(f"[{label}] cutoff={cutoff}: {len(filtered_ids)} samples retained")

        b_dict = {k: v for k, v in b_dict_full.items() if k in filtered_ids}
        m_dict = {k: v for k, v in m_dict_full.items() if k in filtered_ids}
        if not b_dict or not m_dict:
            print(f"[{label}] cutoff={cutoff}: no overlapping samples; skipping.")
            continue

        # === compute points & per-sample α (Parkinson), then α_global ===
        points_df, coeffs_df = _compute_points_and_coeffs_like_dashboard(
            b_dict, m_dict,
            hist_steps=hist_steps_filt,
            gen_block=gen_block_filt,
            num_insertions=num_insertions,
            sample_day_map=sample_day_map,
            tick_size=TICK_SIZE
        )
        if points_df is None or points_df.empty:
            print(f"[{label}] cutoff={cutoff}: points_df empty; skipping.")
            continue

        alpha_global = float(coeffs_df["alpha_hat"].mean(skipna=True)) if not coeffs_df.empty else 0.0

        # === tail-only β(a) with fixed intercept ===
        a_vals, betas_tail = _fit_beta_tail(points_df, alpha_global=alpha_global)
        if a_vals.size == 0:
            print(f"[{label}] cutoff={cutoff}: no valid a-values; skipping.")
            continue

        fig.add_trace(go.Scatter(
            x=a_vals,
            y=betas_tail,
            mode="lines+markers",
            name=f"{label} [a:] (cutoff={cutoff})",
            line=dict(width=3, color=colors.get(label, None), dash=dash_for_cutoff.get(cutoff, "solid"))
        ))

# --- guides + layout ---
if len(fig.data) > 0:
    x_min = min(int(np.nanmin(tr.x)) for tr in fig.data if len(tr.x))
    x_max = max(int(np.nanmax(tr.x)) for tr in fig.data if len(tr.x))
else:
    x_min, x_max = 1, 20

fig.add_trace(go.Scatter(x=[x_min, x_max], y=[0.5, 0.5], mode="lines",
                         line=dict(dash="dash"), name="y = 0.5"))
fig.add_trace(go.Scatter(x=[x_min, x_max], y=[0.0, 0.0], mode="lines", name="y = 0"))

fig.update_xaxes(title_text="a (insertion index threshold)", dtick=1)
fig.update_yaxes(title_text="β (slope)")
fig.update_layout(
    title="Tail-only Global β(a) across experiments — filtered",
    template="plotly_white",
    width=800,
    height=800,
    legend=dict(x=1.00, y=0.99)
)
fig.show()
# Out:
# Before filtering: 352 samples
#
# After filtering: 352 samples
#
# [Plain] cutoff=0.0: 352 samples retained
# Before filtering: 352 samples
#
# After filtering: 317 samples
#
# [Plain] cutoff=0.1: 317 samples retained
# Before filtering: 352 samples
#
# After filtering: 282 samples
#
# [Plain] cutoff=0.2: 282 samples retained
# Before filtering: 360 samples
#
# After filtering: 360 samples
#
# [Heuristic] cutoff=0.0: 360 samples retained
# Before filtering: 360 samples
#
# After filtering: 324 samples
#
# [Heuristic] cutoff=0.1: 324 samples retained
# Before filtering: 360 samples
#
# After filtering: 288 samples
#
# [Heuristic] cutoff=0.2: 288 samples retained
# Before filtering: 272 samples
#
# After filtering: 272 samples
#
# [GenAI] cutoff=0.0: 272 samples retained
# Before filtering: 272 samples
#
# After filtering: 245 samples
#
# [GenAI] cutoff=0.1: 245 samples retained
# Before filtering: 272 samples
#
# After filtering: 218 samples
#
# [GenAI] cutoff=0.2: 218 samples retained

# %%
# ===== Prefix-only β(a) vs sample size (N=25,50,75,...) + FULL across experiments =====
import os, yaml, glob, re
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# ---------------- config / styles ----------------
SAMPLE_SIZES = [25, 50, 75, 100, 150, 200]   # base sweep
PREFIX_MODE  = "le"   # <= a
TICK_SIZE    = 100

colors = {"Plain": "black", "Heuristic": "blue", "GenAI": "red"}
dash_for_size = {25:"dot", 50:"dash", 75:"longdash", 100:"dashdot", 150:"longdashdot", 200:"solid"}

# --------------- small helpers -------------------
def _safe_col(points_df, preferred, fallbacks):
    if preferred in points_df.columns:
        return preferred
    for c in fallbacks:
        if c in points_df.columns:
            return c
    return None

def build_and_merge(folder, batch_prefix, inp_prefix):
    files   = glob.glob(os.path.join(folder, "*.npy"))
    rx_iter = re.compile(rf"{re.escape(batch_prefix)}_\[(.+)\]_iter_(\d+)\.npy$")
    rx_inp  = re.compile(rf"{re.escape(inp_prefix)}_\[(.+)\]\.npy$")
    rec = []
    for f in files:
        nm = os.path.basename(f)
        m  = rx_iter.match(nm)
        if m:
            rng, itr = m.group(1).replace(" ", ""), int(m.group(2))
        else:
            m2 = rx_inp.match(nm)
            if not m2: continue
            rng, itr = m2.group(1).replace(" ", ""), 0
        batch = np.load(f)  # (batch, time, feat)
        rec.append({"range": rng, "iteration": itr, "batch": batch})
    if not rec:
        return pd.DataFrame(), pd.DataFrame(), pd.DataFrame()

    df = pd.DataFrame(rec).sort_values(["range","iteration"]).reset_index(drop=True)
    df["ids"] = df["range"].str.split(",").apply(lambda L: [int(x) for x in L])

    rows = []
    for _, r in df.iterrows():
        for idx, sample_id in enumerate(r["ids"]):
            single = r["batch"][idx]
            if r["iteration"] > 0:
                n_keep = 51 if r["iteration"] <= num_insertions else 50
                single = single[-n_keep:, :]
            rows.append({"id": int(sample_id), "iteration": int(r["iteration"]), "data": single})

    if not rows:
        return df, pd.DataFrame(), pd.DataFrame()

    df_sorted = pd.DataFrame(rows).sort_values(["id","iteration"]).reset_index(drop=True)

    merged = []
    for id_val, grp in df_sorted.groupby("id", sort=True):
        arrs = [row.data for _, row in grp.iterrows()]
        big  = np.concatenate(arrs, axis=0)
        merged.append({"id": int(id_val), "merged_data": big})
    merged_df = pd.DataFrame(merged).sort_values("id").reset_index(drop=True)
    return df, df_sorted, merged_df

# === dashboard-parity compute: x,y via helpers; α from Parkinson using sample_day_map ===
def _compute_points_and_coeffs_like_dashboard(
    b_dict_local, m_dict_local, *, hist_steps, gen_block, num_insertions, sample_day_map, tick_size=100
):
    EVENT_TYPE_COL = 1
    PRICE_COL      = 3
    SIZE_COL       = 5
    eps = 1e-12
    tol = 1e-12

    sample_ids = sorted(set(b_dict_local.keys()) & set(m_dict_local.keys()))
    rows_points, coeff_rows = [], []

    for sid in sample_ids:
        messages_ticks = m_dict_local[sid]
        T = len(messages_ticks)

        insertion_positions = hist_steps + np.arange(1, num_insertions + 1) * gen_block
        valid_insertions = [pos for pos in insertion_positions if pos < T]
        if not valid_insertions:
            coeff_rows.append({"sample_id": sid, "alpha_hat": np.nan})
            continue

        # Reference price at first insertion (ticks -> $)
        ref_idx = valid_insertions[0]
        reference_price = float(messages_ticks[ref_idx, PRICE_COL]) / tick_size

        # Read H, L, execution_sum from sample_day_map (fallback to window)
        try:
            day_row = sample_day_map[sample_day_map['sample_id'] == sid]
            if not day_row.empty:
                H_ticks = float(day_row.iloc[0]['highest_price'])
                L_ticks = float(day_row.iloc[0]['lowest_price'])
                execution_sum = float(day_row.iloc[0]['execution_sum'])
            else:
                H_ticks = float(np.max(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.max(messages_ticks[:, PRICE_COL]))
                L_ticks = float(np.min(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.min(messages_ticks[:, PRICE_COL]))
                exec_mask = (messages_ticks[:, EVENT_TYPE_COL].astype(int) == 4)
                execution_sum = float(np.sum(messages_ticks[exec_mask, SIZE_COL].astype(float)))
        except Exception:
            H_ticks = float(np.max(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.max(messages_ticks[:, PRICE_COL]))
            L_ticks = float(np.min(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.min(messages_ticks[:, PRICE_COL]))
            exec_mask = (messages_ticks[:, EVENT_TYPE_COL].astype(int) == 4)
            execution_sum = float(np.sum(messages_ticks[exec_mask, SIZE_COL].astype(float)))

        # Parkinson η_day and α = ln(η_day)
        H = float(H_ticks) / tick_size
        L = float(L_ticks) / tick_size
        if np.isfinite(H) and np.isfinite(L) and H > L and L > 0:
            eta_day = np.log(H / L) / 0.8325546
            alpha_fixed = float(np.log(max(eta_day, eps)))
        else:
            eta_day = eps
            alpha_fixed = float(np.log(eta_day))

        # Convert messages to dollars
        messages_dollars = messages_ticks.astype(float).copy()
        messages_dollars[:, PRICE_COL] /= tick_size

        # Helper funcs (unchanged signatures)
        impact, vwap_series, Q_cum, log_imp = calculate_impact(
            messages_dollars, valid_insertions, reference_price
        )
        V_exp, log_qv = calculate_market_volume(
            messages_dollars, hist_steps, valid_insertions, execution_sum
        )

        mask_zero = impact <= tol
        for j, _idx in enumerate(valid_insertions):
            if mask_zero[j] or (not np.isfinite(log_qv[j])) or (not np.isfinite(log_imp[j])):
                continue
            rows_points.append({
                "sample_id": sid,
                "insertion": int(j + 1),
                "x": float(log_qv[j]),
                "y": float(log_imp[j]),
            })

        coeff_rows.append({"sample_id": sid, "alpha_hat": alpha_fixed})

    points_df = pd.DataFrame(rows_points)
    coeffs_df = pd.DataFrame.from_records(coeff_rows).set_index("sample_id").sort_index() if coeff_rows else pd.DataFrame()
    return points_df, coeffs_df

def _fit_beta_prefix(points_df, alpha_global, prefix_mode="le"):
    """
    Prefix-only β(a) with fixed intercept:
        for each a, use points with insertion <= a (or < a) and compute
        beta = mean((y - alpha_global) / x) over finite, nonzero x.
    """
    if points_df is None or len(points_df) == 0:
        return np.array([]), np.array([])

    COL_INS = "insertion" if "insertion" in points_df.columns else _safe_col(points_df, "insertion", ["ins_idx","idx"])
    COL_X   = "x"         if "x"         in points_df.columns else _safe_col(points_df, "x", ["log_qv"])
    COL_Y   = "y"         if "y"         in points_df.columns else _safe_col(points_df, "y", ["log_impact"])
    if COL_INS is None or COL_X is None or COL_Y is None:
        return np.array([]), np.array([])

    ins_series = pd.to_numeric(points_df[COL_INS], errors="coerce").dropna().astype(int)
    if ins_series.empty:
        return np.array([]), np.array([])

    ins_max = int(ins_series.max())
    a_values = np.arange(1, ins_max + 1, dtype=int)

    X_all = points_df[COL_X].to_numpy(dtype=float)
    Y_all = points_df[COL_Y].to_numpy(dtype=float)
    ins_a = ins_series.to_numpy(dtype=int)

    betas = np.full_like(a_values, np.nan, dtype=float)
    for i, a in enumerate(a_values):
        mask = (ins_a <= a) if prefix_mode == "le" else (ins_a < a)
        X = X_all[mask]; Y = Y_all[mask]
        valid = np.isfinite(X) & np.isfinite(Y) & (X != 0)
        if valid.sum() >= 2:
            betas[i] = float(np.mean((Y[valid] - alpha_global) / X[valid]))
    return a_values, betas

# ------------------ main plotting ------------------
fig = go.Figure()

for label, exp_name in experiments.items():
    # 1) Load config
    CONFIG_PATH = f"{DATA_ROOT}/{exp_name}/used_config.yaml"
    with open(CONFIG_PATH, "r") as f:
        config = yaml.safe_load(f)

    num_insertions      = int(config["num_insertions"])
    midprice_step_size  = int(config["midprice_step_size"])
    hist_msgs           = int(config["n_messages"])
    n_gen_msgs          = int(config["n_gen_msgs"])

    # 2) Base series (time/grid params)
    merged = summary_table(exp_name)
    x_base, all_series_base = build_zero_padded_series(hist_msgs, n_gen_msgs, midprice_step_size, merged)
    hist_steps_base = hist_msgs // midprice_step_size
    gen_steps_base  = n_gen_msgs // midprice_step_size
    gen_block_base  = gen_steps_base + 1

    # 3) Build merged dicts for b & m once
    b_folder      = f"{DATA_ROOT}/{exp_name}/b_seq_gen_doubled"
    b_batch_pref  = "b_seq_gen_doubled_batch"
    b_inp_pref    = "b_seq_inp"

    m_folder      = f"{DATA_ROOT}/{exp_name}/msgs_decoded_doubled"
    m_batch_pref  = "msgs_decoded_doubled_batch"
    m_inp_pref    = "m_seq_raw_inp"

    _, b_sorted, b_merged = build_and_merge(b_folder, b_batch_pref, b_inp_pref)
    _, m_sorted, m_merged = build_and_merge(m_folder, m_batch_pref, m_inp_pref)

    if b_merged.empty or m_merged.empty:
        print(f"[{label}] No merged b/m data; skipping.")
        continue

    b_dict_full = {int(r.id): np.array(r.merged_data) for _, r in b_merged.iterrows()}
    m_dict_full = {int(r.id): np.array(r.merged_data) for _, r in m_merged.iterrows()}

    # add a zero row at the top of each sample
    for d in (b_dict_full, m_dict_full):
        for key, arr in d.items():
            zero = np.zeros((1, arr.shape[1]), dtype=arr.dtype)
            d[key] = np.vstack([zero, arr])

    # ---------------- iterate over sample sizes (plus FULL) ----------------
    all_ids_sorted = sorted(set(b_dict_full.keys()) & set(m_dict_full.keys()))
    FULL_N = len(all_ids_sorted)
    print(f"[{label}] total available samples: {FULL_N}")

    # sizes to run = filtered SAMPLE_SIZES that are <= FULL_N, plus FULL_N if not already present
    sizes_to_run = [s for s in SAMPLE_SIZES if s <= FULL_N]
    if FULL_N not in sizes_to_run and FULL_N > 0:
        sizes_to_run.append(FULL_N)

    for N in sizes_to_run:
        ids_N = all_ids_sorted[:N]
        print(f"[{label}] N={N}: using {len(ids_N)} samples")

        b_dict = {k: b_dict_full[k] for k in ids_N if k in b_dict_full}
        m_dict = {k: m_dict_full[k] for k in ids_N if k in m_dict_full}
        if not b_dict or not m_dict:
            print(f"[{label}] N={N}: missing b/m overlap; skipping.")
            continue

        # Build points & per-sample α (Parkinson), then α_global
        points_df, coeffs_df = _compute_points_and_coeffs_like_dashboard(
            b_dict, m_dict,
            hist_steps=hist_steps_base,
            gen_block=gen_block_base,
            num_insertions=num_insertions,
            sample_day_map=sample_day_map,
            tick_size=TICK_SIZE
        )
        if points_df is None or points_df.empty:
            print(f"[{label}] N={N}: points_df empty; skipping.")
            continue

        alpha_global = float(coeffs_df["alpha_hat"].mean(skipna=True)) if not coeffs_df.empty else 0.0

        # Prefix-only β(a) with fixed intercept
        a_vals, betas_prefix = _fit_beta_prefix(points_df, alpha_global=alpha_global, prefix_mode=PREFIX_MODE)
        if a_vals.size == 0:
            print(f"[{label}] N={N}: no valid a-values; skipping.")
            continue

        # Make FULL thicker for visibility
        is_full = (N == FULL_N)
        fig.add_trace(go.Scatter(
            x=a_vals,
            y=betas_prefix,
            mode="lines+markers",
            name=(f"(N=FULL:{FULL_N}) {label} [:a]" if is_full else f"(N={N}) {label} [:a]"),
            line=dict(
                width=(4 if is_full else 3),
                color=colors.get(label, None),
                dash=(dash_for_size.get(N, "solid") if not is_full else "solid")
            )
        ))

# ---------------- guides + layout ----------------
if len(fig.data) > 0:
    x_min = min(int(np.nanmin(tr.x)) for tr in fig.data if len(tr.x))
    x_max = max(int(np.nanmax(tr.x)) for tr in fig.data if len(tr.x))
else:
    x_min, x_max = 1, 20

fig.add_trace(go.Scatter(x=[x_min, x_max], y=[0.5, 0.5],
                         mode="lines", line=dict(dash="dash"), name="y = 0.5"))
fig.add_trace(go.Scatter(x=[x_min, x_max], y=[0.0, 0.0],
                         mode="lines", name="y = 0"))

fig.update_xaxes(title_text="a (insertion index threshold)", dtick=1)
fig.update_yaxes(title_text="β (slope)")
fig.update_layout(
    title="Prefix-only Global β(a) across experiments — growing sample sizes (incl. FULL)",
    template="plotly_white",
    width=1150, height=620,
    legend=dict(x=0.01, y=0.99)
)
fig.show()
# Out:
# [Plain] total available samples: 352
# [Plain] N=25: using 25 samples
# [Plain] N=50: using 50 samples
# [Plain] N=75: using 75 samples
# [Plain] N=100: using 100 samples
# [Plain] N=150: using 150 samples
# [Plain] N=200: using 200 samples
# [Plain] N=352: using 352 samples
# [Heuristic] total available samples: 360
# [Heuristic] N=25: using 25 samples
# [Heuristic] N=50: using 50 samples
# [Heuristic] N=75: using 75 samples
# [Heuristic] N=100: using 100 samples
# [Heuristic] N=150: using 150 samples
# [Heuristic] N=200: using 200 samples
# [Heuristic] N=360: using 360 samples
# [GenAI] total available samples: 272
# [GenAI] N=25: using 25 samples
# [GenAI] N=50: using 50 samples
# [GenAI] N=75: using 75 samples
# [GenAI] N=100: using 100 samples
# [GenAI] N=150: using 150 samples
# [GenAI] N=200: using 200 samples
# [GenAI] N=272: using 272 samples

# %%
# ===== Tail-only β(a) vs sample size (N=25,50,75,...) + FULL — RANDOM SAMPLES, fixed-intercept, new x/y =====
import os, yaml, glob, re, hashlib
import numpy as np
import pandas as pd
import plotly.graph_objects as go

# ---------------- config / styles ----------------
SAMPLE_SIZES = [25, 50, 75, 100, 150, 200]   # base sweep
TICK_SIZE    = 100
RNG_SEED     = 20250821    # base seed for reproducibility
PRINT_SAMPLED_IDS = False  # set True to print chosen IDs per (exp,N)
MAX_IDS_TO_PRINT  = 25

colors = {"Plain": "black", "Heuristic": "blue", "GenAI": "red"}
dash_for_size = {25:"dot", 50:"dash", 75:"longdash", 100:"dashdot", 150:"longdashdot", 200:"solid"}

# --------------- small helpers -------------------
def _safe_col(points_df, preferred, fallbacks):
    if preferred in points_df.columns: return preferred
    for c in fallbacks:
        if c in points_df.columns: return c
    return None

def _stable_seed_for_experiment(exp_name: str, base_seed: int) -> int:
    h = hashlib.sha256(exp_name.encode()).hexdigest()[:8]  # 32-bit
    return (int(h, 16) ^ (base_seed & 0xFFFFFFFF)) & 0xFFFFFFFF

def build_and_merge(folder, batch_prefix, inp_prefix):
    files   = glob.glob(os.path.join(folder, "*.npy"))
    rx_iter = re.compile(rf"{re.escape(batch_prefix)}_\[(.+)\]_iter_(\d+)\.npy$")
    rx_inp  = re.compile(rf"{re.escape(inp_prefix)}_\[(.+)\]\.npy$")
    rec = []
    for f in files:
        nm = os.path.basename(f)
        m  = rx_iter.match(nm)
        if m:
            rng, itr = m.group(1).replace(" ", ""), int(m.group(2))
        else:
            m2 = rx_inp.match(nm)
            if not m2: continue
            rng, itr = m2.group(1).replace(" ", ""), 0
        batch = np.load(f)  # (batch, time, feat)
        rec.append({"range": rng, "iteration": itr, "batch": batch})
    if not rec:
        return pd.DataFrame(), pd.DataFrame(), pd.DataFrame()

    df = pd.DataFrame(rec).sort_values(["range","iteration"]).reset_index(drop=True)
    df["ids"] = df["range"].str.split(",").apply(lambda L: [int(x) for x in L])

    rows = []
    for _, r in df.iterrows():
        for idx, sample_id in enumerate(r["ids"]):
            single = r["batch"][idx]
            if r["iteration"] > 0:
                n_keep = 51 if r["iteration"] <= num_insertions else 50
                single = single[-n_keep:, :]
            rows.append({"id": int(sample_id), "iteration": int(r["iteration"]), "data": single})

    if not rows:
        return df, pd.DataFrame(), pd.DataFrame()

    df_sorted = pd.DataFrame(rows).sort_values(["id","iteration"]).reset_index(drop=True)

    merged = []
    for id_val, grp in df_sorted.groupby("id", sort=True):
        arrs = [row.data for _, row in grp.iterrows()]
        big  = np.concatenate(arrs, axis=0)
        merged.append({"id": int(id_val), "merged_data": big})
    merged_df = pd.DataFrame(merged).sort_values("id").reset_index(drop=True)
    return df, df_sorted, merged_df

# === dashboard-parity compute: x,y via helpers; α from Parkinson using sample_day_map ===
def _compute_points_and_coeffs_like_dashboard(
    b_dict_local, m_dict_local, *, hist_steps, gen_block, num_insertions, sample_day_map, tick_size=100
):
    EVENT_TYPE_COL = 1; PRICE_COL = 3; SIZE_COL = 5
    eps = 1e-12; tol = 1e-12
    sample_ids = sorted(set(b_dict_local.keys()) & set(m_dict_local.keys()))
    rows_points, coeff_rows = [], []

    for sid in sample_ids:
        messages_ticks = m_dict_local[sid]
        T = len(messages_ticks)

        insertion_positions = hist_steps + np.arange(1, num_insertions + 1) * gen_block
        valid_insertions = [pos for pos in insertion_positions if pos < T]
        if not valid_insertions:
            coeff_rows.append({"sample_id": sid, "alpha_hat": np.nan})
            continue

        ref_idx = valid_insertions[0]
        reference_price = float(messages_ticks[ref_idx, PRICE_COL]) / tick_size

        try:
            day_row = sample_day_map[sample_day_map['sample_id'] == sid]
            if not day_row.empty:
                H_ticks = float(day_row.iloc[0]['highest_price'])
                L_ticks = float(day_row.iloc[0]['lowest_price'])
                execution_sum = float(day_row.iloc[0]['execution_sum'])
            else:
                H_ticks = float(np.max(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.max(messages_ticks[:, PRICE_COL]))
                L_ticks = float(np.min(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.min(messages_ticks[:, PRICE_COL]))
                exec_mask = (messages_ticks[:, EVENT_TYPE_COL].astype(int) == 4)
                execution_sum = float(np.sum(messages_ticks[exec_mask, SIZE_COL].astype(float)))
        except Exception:
            H_ticks = float(np.max(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.max(messages_ticks[:, PRICE_COL]))
            L_ticks = float(np.min(messages_ticks[:hist_steps, PRICE_COL])) if hist_steps <= T else float(np.min(messages_ticks[:, PRICE_COL]))
            exec_mask = (messages_ticks[:, EVENT_TYPE_COL].astype(int) == 4)
            execution_sum = float(np.sum(messages_ticks[exec_mask, SIZE_COL].astype(float)))

        H = float(H_ticks) / tick_size
        L = float(L_ticks) / tick_size
        if np.isfinite(H) and np.isfinite(L) and H > L and L > 0:
            eta_day = np.log(H / L) / 0.8325546
            alpha_fixed = float(np.log(max(eta_day, eps)))
        else:
            eta_day = eps
            alpha_fixed = float(np.log(eta_day))

        messages_dollars = messages_ticks.astype(float).copy()
        messages_dollars[:, PRICE_COL] /= tick_size

        impact, vwap_series, Q_cum, log_imp = calculate_impact(
            messages_dollars, valid_insertions, reference_price
        )
        V_exp, log_qv = calculate_market_volume(
            messages_dollars, hist_steps, valid_insertions, execution_sum
        )

        mask_zero = impact <= tol
        for j, _idx in enumerate(valid_insertions):
            if mask_zero[j] or (not np.isfinite(log_qv[j])) or (not np.isfinite(log_imp[j])):
                continue
            rows_points.append({"sample_id": sid, "insertion": int(j + 1),
                                "x": float(log_qv[j]), "y": float(log_imp[j])})
        coeff_rows.append({"sample_id": sid, "alpha_hat": alpha_fixed})

    points_df = pd.DataFrame(rows_points)
    coeffs_df = pd.DataFrame.from_records(coeff_rows).set_index("sample_id").sort_index() if coeff_rows else pd.DataFrame()
    return points_df, coeffs_df

def _fit_beta_tail(points_df, alpha_global):
    """
    Tail-only β(a) with fixed intercept:
        for each a, use points with insertion >= a and compute
        beta = mean((y - alpha_global) / x) over finite, nonzero x.
    """
    if points_df is None or len(points_df) == 0:
        return np.array([]), np.array([])

    COL_INS = "insertion" if "insertion" in points_df.columns else _safe_col(points_df, "insertion", ["ins_idx","idx"])
    COL_X   = "x"         if "x"         in points_df.columns else _safe_col(points_df, "x", ["log_qv"])
    COL_Y   = "y"         if "y"         in points_df.columns else _safe_col(points_df, "y", ["log_impact"])
    if COL_INS is None or COL_X is None or COL_Y is None:
        return np.array([]), np.array([])

    ins_series = pd.to_numeric(points_df[COL_INS], errors="coerce").dropna().astype(int)
    if ins_series.empty:
        return np.array([]), np.array([])

    ins_min, ins_max = int(ins_series.min()), int(ins_series.max())
    a_values = np.arange(ins_min, ins_max + 1, dtype=int)

    X_all = points_df[COL_X].to_numpy(dtype=float)
    Y_all = points_df[COL_Y].to_numpy(dtype=float)
    ins_a = ins_series.to_numpy(dtype=int)

    betas = np.full_like(a_values, np.nan, dtype=float)
    for i, a in enumerate(a_values):
        mask = (ins_a >= a)  # TAIL [a:]
        X = X_all[mask]; Y = Y_all[mask]
        valid = np.isfinite(X) & np.isfinite(Y) & (X != 0)
        if valid.sum() >= 2:
            betas[i] = float(np.mean((Y[valid] - alpha_global) / X[valid]))
    return a_values, betas

# ------------------ main plotting ------------------
fig = go.Figure()

for label, exp_name in experiments.items():
    # 1) Load config
    CONFIG_PATH = f"{DATA_ROOT}/{exp_name}/used_config.yaml"
    with open(CONFIG_PATH, "r") as f:
        config = yaml.safe_load(f)

    num_insertions      = int(config["num_insertions"])
    midprice_step_size  = int(config["midprice_step_size"])
    hist_msgs           = int(config["n_messages"])
    n_gen_msgs          = int(config["n_gen_msgs"])

    # 2) Base series (time/grid params)
    merged = summary_table(exp_name)
    x_base, all_series_base = build_zero_padded_series(hist_msgs, n_gen_msgs, midprice_step_size, merged)
    hist_steps_base = hist_msgs // midprice_step_size
    gen_steps_base  = n_gen_msgs // midprice_step_size
    gen_block_base  = gen_steps_base + 1

    # 3) Build merged dicts for b & m once
    b_folder      = f"{DATA_ROOT}/{exp_name}/b_seq_gen_doubled"
    b_batch_pref  = "b_seq_gen_doubled_batch"
    b_inp_pref    = "b_seq_inp"
    m_folder      = f"{DATA_ROOT}/{exp_name}/msgs_decoded_doubled"
    m_batch_pref  = "msgs_decoded_doubled_batch"
    m_inp_pref    = "m_seq_raw_inp"

    _, b_sorted, b_merged = build_and_merge(b_folder, b_batch_pref, b_inp_pref)
    _, m_sorted, m_merged = build_and_merge(m_folder, m_batch_pref, m_inp_pref)

    if b_merged.empty or m_merged.empty:
        print(f"[{label}] No merged b/m data; skipping.")
        continue

    b_dict_full = {int(r.id): np.array(r.merged_data) for _, r in b_merged.iterrows()}
    m_dict_full = {int(r.id): np.array(r.merged_data) for _, r in m_merged.iterrows()}

    # add a zero row at the top of each sample
    for d in (b_dict_full, m_dict_full):
        for key, arr in d.items():
            zero = np.zeros((1, arr.shape[1]), dtype=arr.dtype)
            d[key] = np.vstack([zero, arr])

    # ---------------- iterate over sample sizes (plus FULL) — RANDOMIZED ----------------
    all_ids_sorted = sorted(set(b_dict_full.keys()) & set(m_dict_full.keys()))
    FULL_N = len(all_ids_sorted)
    print(f"[{label}] total available samples: {FULL_N}")
    if FULL_N == 0:
        continue

    # Single random permutation per experiment => nested subsets across N
    exp_seed = _stable_seed_for_experiment(exp_name, RNG_SEED)
    rng = np.random.default_rng(exp_seed)
    permuted_ids = rng.permutation(all_ids_sorted)  # ndarray of ids in random order

    # sizes to run = SAMPLE_SIZES that are <= FULL_N, plus FULL_N if not already present
    sizes_to_run = [s for s in SAMPLE_SIZES if s <= FULL_N]
    if FULL_N not in sizes_to_run:
        sizes_to_run.append(FULL_N)

    for N in sizes_to_run:
        ids_N = list(permuted_ids[:N])  # nested random subset
        if PRINT_SAMPLED_IDS:
            print(f"[{label}] N={N} (seed={exp_seed}) sample IDs: {ids_N[:MAX_IDS_TO_PRINT]}{' ...' if len(ids_N)>MAX_IDS_TO_PRINT else ''}")

        b_dict = {k: b_dict_full[k] for k in ids_N if k in b_dict_full}
        m_dict = {k: m_dict_full[k] for k in ids_N if k in m_dict_full}
        if not b_dict or not m_dict:
            print(f"[{label}] N={N}: missing b/m overlap; skipping.")
            continue

        # Build points & per-sample α (Parkinson), then α_global
        points_df, coeffs_df = _compute_points_and_coeffs_like_dashboard(
            b_dict, m_dict,
            hist_steps=hist_steps_base,
            gen_block=gen_block_base,
            num_insertions=num_insertions,
            sample_day_map=sample_day_map,
            tick_size=TICK_SIZE
        )
        if points_df is None or points_df.empty:
            print(f"[{label}] N={N}: points_df empty; skipping.")
            continue

        alpha_global = float(coeffs_df["alpha_hat"].mean(skipna=True)) if not coeffs_df.empty else 0.0

        # Tail-only β(a) with fixed intercept
        a_vals, betas_tail = _fit_beta_tail(points_df, alpha_global=alpha_global)
        if a_vals.size == 0:
            print(f"[{label}] N={N}: no valid a-values; skipping.")
            continue

        is_full = (N == FULL_N)
        fig.add_trace(go.Scatter(
            x=a_vals, y=betas_tail, mode="lines+markers",
            name=(f"(N=FULL:{FULL_N}) {label} [a:]" if is_full else f"(N={N}) {label} [a:]"),
            line=dict(
                width=(4 if is_full else 3),
                color=colors.get(label, None),
                dash=("solid" if is_full else dash_for_size.get(N, "solid"))
            )
        ))

# ---------------- guides + layout ----------------
if len(fig.data) > 0:
    x_min = min(int(np.nanmin(tr.x)) for tr in fig.data if len(tr.x))
    x_max = max(int(np.nanmax(tr.x)) for tr in fig.data if len(tr.x))
else:
    x_min, x_max = 1, 20

fig.add_trace(go.Scatter(x=[x_min, x_max], y=[0.5, 0.5],
                         mode="lines", line=dict(dash="dash"), name="y = 0.5"))
fig.add_trace(go.Scatter(x=[x_min, x_max], y=[0.0, 0.0],
                         mode="lines", name="y = 0"))

fig.update_xaxes(title_text="a (insertion index threshold)", dtick=1)
fig.update_yaxes(title_text="β (slope)")
fig.update_layout(
    title="Tail-only Global β(a) across experiments — RANDOM nested samples (incl. FULL)",
    template="plotly_white",
    width=1150, height=620,
    legend=dict(x=1.01, y=0.99)
)
fig.show()
# Out:
# [Plain] total available samples: 352
# [Heuristic] total available samples: 360
# [GenAI] total available samples: 272

# %%
# ===== Prefix-only β(a) vs sample size (N=25,50,75,...) — GenAI with volatility filters 0.0/0.2/0.4 =====
import os, yaml, glob, re
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression

# ---------------- config / styles ----------------
SAMPLE_SIZES = [25, 50, 75, 100, 150, 200]   # изменяй по необходимости
PREFIX_MODE  = "le"   # <= a

# используем ТОЛЬКО GenAI из твоего словаря experiments
GENAI_LABEL = "GenAI"

# Цвет по cutoff (оттенки красного), штриховка — по N
color_for_cutoff = {
    0.0: "red",
    0.2: "orangered",
    0.4: "darkred",
}
CUT_OFFS = [0.0, 0.2, 0.4]

dash_for_size = {
    25:  "dot",
    50:  "dash",
    75:  "longdash",
    100: "dashdot",
    150: "longdashdot",
    200: "solid",
}

# --------------- small helpers -------------------
def _safe_col(points_df, preferred, fallbacks):
    if preferred in points_df.columns:
        return preferred
    for c in fallbacks:
        if c in points_df.columns:
            return c
    return None

def build_and_merge(folder, batch_prefix, inp_prefix):
    # Load every .npy (shape (batch, time, feat))
    files   = glob.glob(os.path.join(folder, "*.npy"))
    rx_iter = re.compile(rf"{re.escape(batch_prefix)}_\[(.+)\]_iter_(\d+)\.npy$")
    rx_inp  = re.compile(rf"{re.escape(inp_prefix)}_\[(.+)\]\.npy$")
    rec = []
    for f in files:
        nm = os.path.basename(f)
        m  = rx_iter.match(nm)
        if m:
            rng, itr = m.group(1).replace(" ", ""), int(m.group(2))
        else:
            m2 = rx_inp.match(nm)
            if not m2:
                continue
            rng, itr = m2.group(1).replace(" ", ""), 0

        batch = np.load(f)  # shape (batch_size, time, features)
        print(f"Loaded {nm} with shape {batch.shape}")
        rec.append({"range": rng, "iteration": itr, "batch": batch})

    if not rec:
        return pd.DataFrame(), pd.DataFrame(), pd.DataFrame()

    df = pd.DataFrame(rec).sort_values(["range","iteration"]).reset_index(drop=True)
    df["ids"] = df["range"].str.split(",").apply(lambda L: [int(x) for x in L])

    rows = []
    for _, r in df.iterrows():
        for idx, sample_id in enumerate(r["ids"]):
            single = r["batch"][idx]   # (time, features)
            if r["iteration"] > 0:
                n_keep = 51 if r["iteration"] <= num_insertions else 50
                single = single[-n_keep:, :]
            rows.append({"id": int(sample_id), "iteration": int(r["iteration"]), "data": single})

    if not rows:
        return df, pd.DataFrame(), pd.DataFrame()

    df_sorted = pd.DataFrame(rows).sort_values(["id","iteration"]).reset_index(drop=True)

    merged = []
    for id_val, grp in df_sorted.groupby("id", sort=True):
        arrs = [row.data for _, row in grp.iterrows()]
        big  = np.concatenate(arrs, axis=0)
        merged.append({"id": int(id_val), "merged_data": big})
    merged_df = pd.DataFrame(merged).sort_values("id").reset_index(drop=True)

    return df, df_sorted, merged_df

def global_beta_points_df(
    b_seq_inp,
    msg_seq_raw,
    *,
    hist_steps=550,
    gen_block=50,
    num_insertions=20,
    special_first=(79, 15),
):
    """
    Build tidy points_df: ['sample_id','insertion','x','y'].
    x = normalized log relative size, y = normalized log impact.
    """
    if isinstance(b_seq_inp, pd.DataFrame):
        b_dict_local = {int(r.id): np.array(r.merged_data) for _, r in b_seq_inp.iterrows()}
    else:
        b_dict_local = b_seq_inp or {}
    if isinstance(msg_seq_raw, pd.DataFrame):
        m_dict_local = {int(r.id): np.array(r.merged_data) for _, r in msg_seq_raw.iterrows()}
    else:
        m_dict_local = msg_seq_raw or {}

    if not b_dict_local or not m_dict_local:
        return pd.DataFrame()

    EVENT_TYPE_COL = 1
    PRICE_COL      = 3
    SIZE_COL       = 5
    eps = 1e-12
    tol = 1e-12

    sample_ids = sorted(set(b_dict_local.keys()) & set(m_dict_local.keys()))
    if not sample_ids:
        return pd.DataFrame()

    col_names = [f"ins_{i}" for i in range(1, num_insertions + 1)]
    x_df = pd.DataFrame(index=sample_ids, columns=col_names, dtype=object)
    y_df = pd.DataFrame(index=sample_ids, columns=col_names, dtype=object)

    def per_sample(sample_id):
        messages = m_dict_local[sample_id]
        T = len(messages)
        insertion_positions = hist_steps + np.arange(1, num_insertions + 1) * gen_block
        valid_insertions = [pos for pos in insertion_positions if pos < T]
        if not valid_insertions:
            return dict(valid_insertions=[], x_norm=None, y_norm=None, mask_zero=None)

        ref_idx = valid_insertions[0]
        reference_price_ticks = float(messages[ref_idx, PRICE_COL])

        insert_sizes  = messages[valid_insertions, SIZE_COL].astype(float)
        insert_prices = messages[valid_insertions, PRICE_COL].astype(float)
        Q_cum    = np.cumsum(insert_sizes)
        notional = np.cumsum(insert_sizes * insert_prices)
        vwap_ticks_series = notional / np.maximum(Q_cum, eps)
        impact_ticks = np.abs(vwap_ticks_series - reference_price_ticks)

        evt_types    = messages[:, EVENT_TYPE_COL].astype(int)
        exec_sizes   = np.where(evt_types == 4, messages[:, SIZE_COL].astype(float), 0.0)
        cum_exec_vol = np.cumsum(exec_sizes)
        V_exp = np.array([float(cum_exec_vol[idx-1] if (idx-1) >= 0 else 0.0)
                          for idx in valid_insertions])

        rel_size   = Q_cum / np.maximum(V_exp, eps)
        log_qv     = np.log(np.maximum(rel_size, eps))
        log_imp    = np.log(np.maximum(impact_ticks, eps))
        mask_zero  = impact_ticks <= tol

        used_x_raw = log_qv[~mask_zero]
        used_y_raw = log_imp[~mask_zero]

        if used_x_raw.size >= 2:
            mu_x = float(used_x_raw.mean());  mu_y = float(used_y_raw.mean())
            std_x = float(np.sqrt(max(float(used_x_raw.var(ddof=0)), eps)))
            std_y = float(np.sqrt(max(float(used_y_raw.var(ddof=0)), eps)))
            x_norm_all = (log_qv - mu_x) / std_x
            y_norm_all = (log_imp - mu_y) / std_y
        else:
            x_norm_all = np.full_like(log_qv, np.nan, dtype=float)
            y_norm_all = np.full_like(log_imp, np.nan, dtype=float)

        return dict(valid_insertions=valid_insertions,
                    x_norm=x_norm_all, y_norm=y_norm_all, mask_zero=mask_zero)

    for sid in sample_ids:
        res = per_sample(sid)
        valid_ins = res["valid_insertions"]
        x_norm    = res["x_norm"]
        y_norm    = res["y_norm"]
        mask_zero = res["mask_zero"]
        for j, _idx in enumerate(valid_ins):
            col = f"ins_{j+1}"
            if mask_zero[j]:
                x_df.loc[sid, col] = "ZERO"
                y_df.loc[sid, col] = "ZERO"
            else:
                xv = x_norm[j]; yv = y_norm[j]
                x_df.loc[sid, col] = float(xv) if np.isfinite(xv) else np.nan
                y_df.loc[sid, col] = float(yv) if np.isfinite(yv) else np.nan

    # tidy
    all_ids = list(x_df.index)
    ordered_ids = [sid for sid in (special_first or []) if sid in all_ids]
    ordered_ids += [sid for sid in sorted(all_ids) if sid not in ordered_ids]

    rows = []
    for sid in ordered_ids:
        for j, col in enumerate(x_df.columns, start=1):
            xv = x_df.loc[sid, col]
            yv = y_df.loc[sid, col]
            if isinstance(xv, (int, float, np.floating)) and isinstance(yv, (int, float, np.floating)):
                if np.isfinite(xv) and np.isfinite(yv):
                    rows.append({"sample_id": sid, "insertion": j, "x": float(xv), "y": float(yv)})
    return pd.DataFrame(rows)

def _fit_beta_prefix(points_df, prefix_mode="le"):
    """Compute prefix-only β(a)."""
    if points_df is None or len(points_df) == 0:
        return np.array([]), np.array([])

    COL_INS = "insertion" if "insertion" in points_df.columns else _safe_col(points_df, "insertion", ["ins_idx","idx"])
    COL_X   = "x"         if "x"         in points_df.columns else _safe_col(points_df, "x", ["log_qv"])
    COL_Y   = "y"         if "y"         in points_df.columns else _safe_col(points_df, "y", ["log_impact"])
    if COL_INS is None or COL_X is None or COL_Y is None:
        return np.array([]), np.array([])

    ins_series = pd.to_numeric(points_df[COL_INS], errors="coerce").dropna().astype(int)
    if ins_series.empty:
        return np.array([]), np.array([])

    ins_max = int(ins_series.max())
    a_values = np.arange(1, ins_max + 1, dtype=int)

    lr = LinearRegression()
    betas = np.full_like(a_values, np.nan, dtype=float)
    for i, a in enumerate(a_values):
        sub = points_df[ins_series <= a] if prefix_mode == "le" else points_df[ins_series < a]
        if len(sub) >= 2:
            X = sub[COL_X].to_numpy().reshape(-1, 1)
            Y = sub[COL_Y].to_numpy()
            mask = np.isfinite(X).ravel() & np.isfinite(Y)
            if mask.sum() >= 2:
                lr.fit(X[mask].reshape(-1, 1), Y[mask])
                betas[i] = float(lr.coef_[0])
    return a_values, betas

# ------------------ main ------------------
fig = go.Figure()

# 1) найти путь к GenAI
if GENAI_LABEL not in experiments:
    raise KeyError(f"'{GENAI_LABEL}' not found in experiments dict")
exp_name = experiments[GENAI_LABEL]

# 2) загрузить конфиг и базовые ряды
CONFIG_PATH = f"{DATA_ROOT}/{exp_name}/used_config.yaml"
with open(CONFIG_PATH, "r") as f:
    config = yaml.safe_load(f)

num_insertions      = int(config["num_insertions"])
midprice_step_size  = int(config["midprice_step_size"])
hist_msgs           = int(config["n_messages"])
n_gen_msgs          = int(config["n_gen_msgs"])

merged = summary_table(exp_name)
x_base, all_series_base = build_zero_padded_series(hist_msgs, n_gen_msgs, midprice_step_size, merged)
hist_steps_base = hist_msgs // midprice_step_size
gen_steps_base  = n_gen_msgs // midprice_step_size
gen_block_base  = gen_steps_base + 1

# 3) собрать b/m один раз (без фильтра)
experiment_name = exp_name
b_folder      = f"{DATA_ROOT}/{experiment_name}/b_seq_gen_doubled"
b_batch_pref  = "b_seq_gen_doubled_batch"
b_inp_pref    = "b_seq_inp"

m_folder      = f"{DATA_ROOT}/{experiment_name}/msgs_decoded_doubled"
m_batch_pref  = "msgs_decoded_doubled_batch"
m_inp_pref    = "m_seq_raw_inp"

_, b_sorted, b_merged = build_and_merge(b_folder, b_batch_pref, b_inp_pref)
_, m_sorted, m_merged = build_and_merge(m_folder, m_batch_pref, m_inp_pref)

if b_merged.empty or m_merged.empty:
    raise RuntimeError("No merged b/m data for GenAI")

b_dict_full = {int(r.id): np.array(r.merged_data) for _, r in b_merged.iterrows()}
m_dict_full = {int(r.id): np.array(r.merged_data) for _, r in m_merged.iterrows()}

# добавить нулевую строку
for d in (b_dict_full, m_dict_full):
    for key, arr in d.items():
        zero = np.zeros((1, arr.shape[1]), dtype=arr.dtype)
        d[key] = np.vstack([zero, arr])

# 4) пройдём по cutoffs и по N
for cutoff in CUT_OFFS:
    # фильтрация только merged-таблиц для отбора ID
    x_filt, all_series_filt, merged_filt, hist_steps_filt, gen_block_filt = prepare_volatility_filtered_series(
        merged, hist_msgs, n_gen_msgs, midprice_step_size, volatility_cutoff=cutoff
    )
    filtered_ids_all = sorted(set(merged_filt["id"]))
    print(f"[GenAI] cutoff={cutoff}: {len(filtered_ids_all)} samples available")

    for N in SAMPLE_SIZES:
        if not filtered_ids_all:
            print(f"[GenAI] cutoff={cutoff}, N={N}: no ids; skipping")
            continue
        ids_N = filtered_ids_all[:min(N, len(filtered_ids_all))]
        print(f"[GenAI] cutoff={cutoff}, N={N}: using {len(ids_N)} samples")

        b_dict = {k: b_dict_full[k] for k in ids_N if k in b_dict_full}
        m_dict = {k: m_dict_full[k] for k in ids_N if k in m_dict_full}
        if not b_dict or not m_dict:
            print(f"[GenAI] cutoff={cutoff}, N={N}: empty dicts; skipping")
            continue

        # points_df и β(a)
        points_df = global_beta_points_df(
            b_dict, m_dict,
            hist_steps=hist_steps_filt,   # важно: те же шаги, что после фильтра
            gen_block=gen_block_filt,
            num_insertions=num_insertions,
            special_first=(79, 15),
        )
        if points_df is None or points_df.empty:
            print(f"[GenAI] cutoff={cutoff}, N={N}: points_df empty; skipping.")
            continue

        a_vals, betas_prefix = _fit_beta_prefix(points_df, prefix_mode=PREFIX_MODE)
        if a_vals.size == 0:
            print(f"[GenAI] cutoff={cutoff}, N={N}: no valid a; skipping.")
            continue

        fig.add_trace(go.Scatter(
            x=a_vals, y=betas_prefix,
            mode="lines+markers",
            name=f"v={cutoff} (N={len(ids_N)}) [:a] GenAI",
            line=dict(width=3, color=color_for_cutoff.get(cutoff, "red"),
                      dash=dash_for_size.get(N, "solid"))
        ))

# ---------------- guides + layout ----------------
if len(fig.data) > 0:
    x_min = min(int(np.nanmin(tr.x)) for tr in fig.data if len(tr.x))
    x_max = max(int(np.nanmax(tr.x)) for tr in fig.data if len(tr.x))
else:
    x_min, x_max = 1, 20

fig.add_trace(go.Scatter(
    x=[x_min, x_max], y=[0.5, 0.5],
    mode="lines", line=dict(dash="dash"), name="y = 0.5"
))
fig.add_trace(go.Scatter(
    x=[x_min, x_max], y=[0.0, 0.0],
    mode="lines", name="y = 0"
))

fig.update_xaxes(title_text="a (insertion index threshold)", dtick=1)
fig.update_yaxes(title_text="β (slope)")
fig.update_layout(
    title="Prefix-only Global β(a) — GenAI with volatility filters (v=0.0,0.2,0.4) and growing N",
    template="plotly_white",
    width=1150,
    height=620,
    legend=dict(x=0.01, y=0.99)
)
fig.show()
# Out:
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5526, 6868, 1033, 528]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7078, 3728, 1563, 470]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5797, 508, 5507, 2167]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6910, 2659, 4946, 2810]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[4310, 3072, 399, 6521].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5526, 6868, 1033, 528]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1910, 5524, 6179, 5968]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5526, 6868, 1033, 528]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5526, 6868, 1033, 528]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_inp_[1652, 6865, 3808, 6681].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3306, 251, 947, 2413]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6910, 2659, 4946, 2810]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5279, 2986, 7049, 6132]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[79, 402, 3959, 7212]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3573, 1332, 5439, 2191]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3919, 201, 6004, 6542]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_inp_[453, 3952, 4972, 6029].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6597, 2042, 15, 2256]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6649, 5572, 459, 6467]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6649, 5572, 459, 6467]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6649, 5572, 459, 6467]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1910, 5524, 6179, 5968]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_inp_[865, 1225, 5874, 5305].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5279, 2986, 7049, 6132]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5279, 2986, 7049, 6132]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6331, 878, 6164, 3001]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6513, 1911, 926, 2618]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5279, 2986, 7049, 6132]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1924, 633, 5664, 2863]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3306, 251, 947, 2413]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[79, 402, 3959, 7212]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1910, 5524, 6179, 5968]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1924, 633, 5664, 2863]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6910, 2659, 4946, 2810]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6513, 1911, 926, 2618]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1910, 5524, 6179, 5968]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3919, 201, 6004, 6542]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2087, 3994, 414, 2821]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1924, 633, 5664, 2863]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1910, 5524, 6179, 5968]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3919, 201, 6004, 6542]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1910, 5524, 6179, 5968]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6331, 878, 6164, 3001]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[79, 402, 3959, 7212]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6597, 2042, 15, 2256]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3919, 201, 6004, 6542]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3919, 201, 6004, 6542]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3573, 1332, 5439, 2191]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3306, 251, 947, 2413]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1910, 5524, 6179, 5968]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5526, 6868, 1033, 528]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[79, 402, 3959, 7212]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6331, 878, 6164, 3001]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6331, 878, 6164, 3001]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3306, 251, 947, 2413]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6649, 5572, 459, 6467]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6331, 878, 6164, 3001]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5527, 4242, 1062, 4386]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5279, 2986, 7049, 6132]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7078, 3728, 1563, 470]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6597, 2042, 15, 2256]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[7182, 2137, 4796, 1907].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5279, 2986, 7049, 6132]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[140, 4708, 1141, 5951].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[79, 402, 3959, 7212]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7078, 3728, 1563, 470]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3803, 1404, 4513, 3763]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[79, 402, 3959, 7212]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3919, 201, 6004, 6542]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4238, 275, 2107, 4834]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3573, 1332, 5439, 2191]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_inp_[3306, 251, 947, 2413].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6331, 878, 6164, 3001]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7078, 3728, 1563, 470]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_29.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5317, 2178, 3859, 1730]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5526, 6868, 1033, 528]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1924, 633, 5664, 2863]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6649, 5572, 459, 6467]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1924, 633, 5664, 2863]_iter_27.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3948, 69, 5452, 1947]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[79, 402, 3959, 7212]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3306, 251, 947, 2413]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5279, 2986, 7049, 6132]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1928, 2921, 461, 97]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1924, 633, 5664, 2863]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6513, 1911, 926, 2618]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[5898, 699, 2074, 2026].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3573, 1332, 5439, 2191]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6597, 2042, 15, 2256]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6331, 878, 6164, 3001]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5797, 508, 5507, 2167]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2088, 5221, 6453, 2023]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_inp_[6866, 6936, 2681, 6698].npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_36.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1515, 1460, 4904, 6933]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6597, 2042, 15, 2256]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7078, 3728, 1563, 470]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6910, 2659, 4946, 2810]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_3.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5279, 2986, 7049, 6132]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6910, 2659, 4946, 2810]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6331, 878, 6164, 3001]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[37, 6195, 1183, 780]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5797, 508, 5507, 2167]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6931, 4464, 4402, 2408]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_4.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[4310, 3072, 399, 6521]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6372, 3567, 1479, 3127]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_18.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5580, 220, 4907, 2025]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1833, 6991, 5093, 899]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5905, 6920, 2417, 2757]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[453, 3952, 4972, 6029]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3600, 2758, 4892, 2560]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[875, 731, 3699, 4695]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3306, 251, 947, 2413]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_47.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_11.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5964, 4470, 3909, 6469]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_41.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1764, 7187, 7098, 5800]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_37.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3067, 2470, 4180, 3232]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_22.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7078, 3728, 1563, 470]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3573, 1332, 5439, 2191]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3868, 6391, 6213, 1572]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_1.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5526, 6868, 1033, 528]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_21.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3919, 201, 6004, 6542]_iter_32.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[5898, 699, 2074, 2026]_iter_39.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7231, 1060, 4480, 3951]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5797, 508, 5507, 2167]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_44.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_8.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2911, 568, 1661, 5380]_iter_40.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2097, 6583, 4121, 6072]_iter_38.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6866, 6936, 2681, 6698]_iter_49.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6513, 1911, 926, 2618]_iter_12.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7078, 3728, 1563, 470]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_2.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6479, 4289, 2562, 646]_iter_13.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[2865, 4249, 6106, 1851]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1924, 633, 5664, 2863]_iter_30.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[346, 1483, 2512, 5215]_iter_7.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6540, 5120, 5066, 5127]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_6.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6597, 2042, 15, 2256]_iter_25.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6597, 2042, 15, 2256]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[1638, 2934, 1548, 2634]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_9.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[7182, 2137, 4796, 1907]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[7011, 3911, 150, 6287]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2029, 5967, 5558, 3773]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[5499, 339, 4819, 797]_iter_50.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3306, 251, 947, 2413]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6597, 2042, 15, 2256]_iter_17.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_14.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6513, 1911, 926, 2618]_iter_24.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2649, 1217, 5285, 1579]_iter_31.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1910, 5524, 6179, 5968]_iter_5.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[975, 6842, 5118, 5252]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[140, 4708, 1141, 5951]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3398, 945, 3019, 1832]_iter_33.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3573, 1332, 5439, 2191]_iter_19.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[865, 1225, 5874, 5305]_iter_43.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3573, 1332, 5439, 2191]_iter_16.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[6031, 5446, 739, 4418]_iter_28.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6513, 1911, 926, 2618]_iter_20.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[410, 4610, 3384, 3588]_iter_15.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[445, 3938, 6659, 3593]_iter_45.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3683, 6629, 1469, 5105]_iter_42.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[869, 5837, 2713, 5383]_iter_26.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1070, 6489, 4084, 2680]_iter_10.npy with shape (4, 501, 501)
# Loaded b_seq_gen_doubled_batch_[3690, 6757, 5282, 7240]_iter_23.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3374, 2414, 3786, 879]_iter_48.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[6493, 2220, 7009, 5741]_iter_34.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[3573, 1332, 5439, 2191]_iter_35.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[2640, 4030, 1086, 2674]_iter_46.npy with shape (4, 500, 501)
# Loaded b_seq_gen_doubled_batch_[1652, 6865, 3808, 6681]_iter_33.npy with shape (4, 500, 501)
# ...
# Loaded m_seq_raw_inp_[5905, 6920, 2417, 2757].npy with shape (4, 500, 14)
# Loaded msgs_decoded_doubled_batch_[7011, 3911, 150, 6287]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6910, 2659, 4946, 2810]_iter_9.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_3.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5905, 6920, 2417, 2757]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5499, 339, 4819, 797]_iter_10.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3374, 2414, 3786, 879]_iter_14.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3690, 6757, 5282, 7240]_iter_41.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1924, 633, 5664, 2863]_iter_37.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5527, 4242, 1062, 4386]_iter_38.npy with shape (4, 50, 14)
# Loaded m_seq_raw_inp_[5898, 699, 2074, 2026].npy with shape (4, 500, 14)
# Loaded msgs_decoded_doubled_batch_[5905, 6920, 2417, 2757]_iter_2.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[7011, 3911, 150, 6287]_iter_48.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1515, 1460, 4904, 6933]_iter_17.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1652, 6865, 3808, 6681]_iter_47.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3803, 1404, 4513, 3763]_iter_20.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5526, 6868, 1033, 528]_iter_28.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1910, 5524, 6179, 5968]_iter_4.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[7231, 1060, 4480, 3951]_iter_43.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1833, 6991, 5093, 899]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5797, 508, 5507, 2167]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_50.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_17.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[7182, 2137, 4796, 1907]_iter_31.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6331, 878, 6164, 3001]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[7231, 1060, 4480, 3951]_iter_19.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_19.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3803, 1404, 4513, 3763]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3306, 251, 947, 2413]_iter_13.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3868, 6391, 6213, 1572]_iter_24.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[7078, 3728, 1563, 470]_iter_14.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[37, 6195, 1183, 780]_iter_44.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6331, 878, 6164, 3001]_iter_1.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6031, 5446, 739, 4418]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_33.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[7011, 3911, 150, 6287]_iter_19.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[410, 4610, 3384, 3588]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_19.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_7.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_41.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3948, 69, 5452, 1947]_iter_46.npy with shape (4, 50, 14)
# Loaded m_seq_raw_inp_[6513, 1911, 926, 2618].npy with shape (4, 500, 14)
# Loaded msgs_decoded_doubled_batch_[3398, 945, 3019, 1832]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_45.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_40.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3573, 1332, 5439, 2191]_iter_18.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6513, 1911, 926, 2618]_iter_18.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3398, 945, 3019, 1832]_iter_27.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5580, 220, 4907, 2025]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1833, 6991, 5093, 899]_iter_22.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[865, 1225, 5874, 5305]_iter_24.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_26.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_43.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1638, 2934, 1548, 2634]_iter_34.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_6.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[453, 3952, 4972, 6029]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1924, 633, 5664, 2863]_iter_41.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5527, 4242, 1062, 4386]_iter_39.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[79, 402, 3959, 7212]_iter_16.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5905, 6920, 2417, 2757]_iter_34.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[865, 1225, 5874, 5305]_iter_4.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1928, 2921, 461, 97]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6513, 1911, 926, 2618]_iter_44.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3690, 6757, 5282, 7240]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6540, 5120, 5066, 5127]_iter_1.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[37, 6195, 1183, 780]_iter_39.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6597, 2042, 15, 2256]_iter_17.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6372, 3567, 1479, 3127]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3573, 1332, 5439, 2191]_iter_43.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6031, 5446, 739, 4418]_iter_31.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_39.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[37, 6195, 1183, 780]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[4310, 3072, 399, 6521]_iter_28.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_31.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1910, 5524, 6179, 5968]_iter_7.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5964, 4470, 3909, 6469]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5964, 4470, 3909, 6469]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_5.npy with shape (4, 51, 14)
# Loaded m_seq_raw_inp_[869, 5837, 2713, 5383].npy with shape (4, 500, 14)
# Loaded msgs_decoded_doubled_batch_[4238, 275, 2107, 4834]_iter_32.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[79, 402, 3959, 7212]_iter_33.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3919, 201, 6004, 6542]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6031, 5446, 739, 4418]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_9.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6331, 878, 6164, 3001]_iter_33.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[869, 5837, 2713, 5383]_iter_34.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[7182, 2137, 4796, 1907]_iter_28.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3948, 69, 5452, 1947]_iter_44.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[346, 1483, 2512, 5215]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5964, 4470, 3909, 6469]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2087, 3994, 414, 2821]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_40.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3690, 6757, 5282, 7240]_iter_48.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[7182, 2137, 4796, 1907]_iter_45.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2088, 5221, 6453, 2023]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5898, 699, 2074, 2026]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6597, 2042, 15, 2256]_iter_27.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6031, 5446, 739, 4418]_iter_36.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5279, 2986, 7049, 6132]_iter_33.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5317, 2178, 3859, 1730]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5526, 6868, 1033, 528]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6479, 4289, 2562, 646]_iter_18.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[37, 6195, 1183, 780]_iter_27.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_32.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3600, 2758, 4892, 2560]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5898, 699, 2074, 2026]_iter_15.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1652, 6865, 3808, 6681]_iter_7.npy with shape (4, 51, 14)
# Loaded m_seq_raw_inp_[1928, 2921, 461, 97].npy with shape (4, 500, 14)
# Loaded msgs_decoded_doubled_batch_[3683, 6629, 1469, 5105]_iter_47.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_33.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_40.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6513, 1911, 926, 2618]_iter_40.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[445, 3938, 6659, 3593]_iter_2.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6910, 2659, 4946, 2810]_iter_33.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1910, 5524, 6179, 5968]_iter_34.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6513, 1911, 926, 2618]_iter_16.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[2911, 568, 1661, 5380]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[37, 6195, 1183, 780]_iter_11.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3868, 6391, 6213, 1572]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3573, 1332, 5439, 2191]_iter_25.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[2029, 5967, 5558, 3773]_iter_23.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5580, 220, 4907, 2025]_iter_26.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3948, 69, 5452, 1947]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[875, 731, 3699, 4695]_iter_8.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1924, 633, 5664, 2863]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[4238, 275, 2107, 4834]_iter_39.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3306, 251, 947, 2413]_iter_35.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3306, 251, 947, 2413]_iter_49.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[5317, 2178, 3859, 1730]_iter_41.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6931, 4464, 4402, 2408]_iter_22.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_1.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[1910, 5524, 6179, 5968]_iter_21.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6493, 2220, 7009, 5741]_iter_45.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3067, 2470, 4180, 3232]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1070, 6489, 4084, 2680]_iter_12.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[4238, 275, 2107, 4834]_iter_42.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[4310, 3072, 399, 6521]_iter_1.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[6866, 6936, 2681, 6698]_iter_38.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[6649, 5572, 459, 6467]_iter_46.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[3306, 251, 947, 2413]_iter_17.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[5317, 2178, 3859, 1730]_iter_30.npy with shape (4, 50, 14)
# Loaded msgs_decoded_doubled_batch_[1764, 7187, 7098, 5800]_iter_3.npy with shape (4, 51, 14)
# Loaded msgs_decoded_doubled_batch_[3600, 2758, 4892, 2560]_iter_18.npy with shape (4, 51, 14)
# Before filtering: 272 samples
#
# After filtering: 272 samples
#
# [GenAI] cutoff=0.0: 272 samples available
# [GenAI] cutoff=0.0, N=25: using 25 samples
# [GenAI] cutoff=0.0, N=50: using 50 samples
# [GenAI] cutoff=0.0, N=75: using 75 samples
# [GenAI] cutoff=0.0, N=100: using 100 samples
# [GenAI] cutoff=0.0, N=150: using 150 samples
# [GenAI] cutoff=0.0, N=200: using 200 samples
# Before filtering: 272 samples
#
# After filtering: 218 samples
#
# [GenAI] cutoff=0.2: 218 samples available
# [GenAI] cutoff=0.2, N=25: using 25 samples
# [GenAI] cutoff=0.2, N=50: using 50 samples
# [GenAI] cutoff=0.2, N=75: using 75 samples
# [GenAI] cutoff=0.2, N=100: using 100 samples
# [GenAI] cutoff=0.2, N=150: using 150 samples
# [GenAI] cutoff=0.2, N=200: using 200 samples
# Before filtering: 272 samples
#
# After filtering: 164 samples
#
# [GenAI] cutoff=0.4: 164 samples available
# [GenAI] cutoff=0.4, N=25: using 25 samples
# [GenAI] cutoff=0.4, N=50: using 50 samples
# [GenAI] cutoff=0.4, N=75: using 75 samples
# [GenAI] cutoff=0.4, N=100: using 100 samples
# [GenAI] cutoff=0.4, N=150: using 150 samples
# [GenAI] cutoff=0.4, N=200: using 164 samples

# %%
# --- Prepare base GenAI data (no filtering) ---
x, all_series, merged_filt, hist_steps, gen_block = prepare_volatility_filtered_series(
    merged, hist_msgs, n_gen_msgs, midprice_step_size, volatility_cutoff=0.0
)
# Out:
# Before filtering: 272 samples
#
# After filtering: 272 samples

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
from sklearn.linear_model import LinearRegression

# ================= CONFIG =================
DEBUG = True
MAX_IDS_TO_PRINT = 30
START_PREFIX_AT = 1
PREFIX_MODE = "le"         # "lt" -> insertion < a, "le" -> insertion <= a
SAMPLE_SIZES = [25, 50, 75, 100, 150, 200]

pd.set_option("display.width", 160)
pd.set_option("display.max_columns", 200)
pd.set_option("display.max_rows", 50)

# ================ HELPERS ================
def _safe_col(points_df, preferred, fallbacks):
    if preferred in points_df.columns:
        return preferred
    for c in fallbacks:
        if c in points_df.columns:
            return c
    return None

def _print_section(h):
    print("\n" + "="*24 + f" {h} " + "="*24)

def _format_pairs_inline(series_like):
    pairs = [f"{int(k)}:{int(series_like.loc[k])}" for k in sorted(series_like.index)]
    return ", ".join(pairs) + "."

def debug_points_df(points_df, tag=""):
    _print_section(f"[DEBUG] points_df summary {tag}")
    if points_df is None or len(points_df) == 0:
        print("points_df is None or EMPTY")
        return
    print(f"shape: {points_df.shape}")
    print(f"columns: {list(points_df.columns)}")
    print(points_df.head(5))
    col_i = _safe_col(points_df, "ins_idx", ["ins_idx", "insertion_idx", "idx", "insertion"])
    if col_i:
        ii = pd.to_numeric(points_df[col_i], errors="coerce").dropna().astype(int)
        print(f"insertion: min={ii.min()}, max={ii.max()}, unique_count={ii.nunique()}, total={len(ii)}")
        cnt_by_ins = ii.value_counts().sort_index()
        print("insertion counts: " + _format_pairs_inline(cnt_by_ins))
    if "sample_id" in points_df.columns:
        sid = points_df["sample_id"].dropna()
        print(f"sample_id: unique={sid.nunique()}, total_rows_with_id={sid.shape[0]}")

# ================= MAIN =================
fig = go.Figure()

all_ids_sorted = sorted(set(b_dict.keys()) & set(m_dict.keys()))
print(f"[GenAI] total available samples: {len(all_ids_sorted)}")

for N in SAMPLE_SIZES:
    ids_sel = all_ids_sorted[:min(N, len(all_ids_sorted))]
    print(f"[GenAI] N={N}: using {len(ids_sel)} samples")

    b_dict_filt = {k: b_dict[k] for k in ids_sel if k in b_dict}
    m_dict_filt = {k: m_dict[k] for k in ids_sel if k in m_dict}

    _fig_cut, points_df = global_beta_plot_from_raw(
        b_dict_filt, m_dict_filt, all_series, x,
        hist_steps=hist_steps,
        gen_block=gen_block,
        num_insertions=num_insertions,
        beta_theory=0.5,
        samples_used=None,
        special_first=(79, 15),
        nbins_hist=30
    )
    if DEBUG:
        debug_points_df(points_df, tag=f"(N={N})")
    if points_df is None or len(points_df) == 0:
        continue

    COL_INS = "insertion" if "insertion" in points_df.columns else _safe_col(points_df, "insertion", ["ins_idx", "idx"])
    COL_X   = "x" if "x" in points_df.columns else _safe_col(points_df, "x", ["log_qv"])
    COL_Y   = "y" if "y" in points_df.columns else _safe_col(points_df, "y", ["log_impact"])

    ins_series = pd.to_numeric(points_df[COL_INS], errors="coerce").dropna().astype(int)
    ins_min, ins_max = int(ins_series.min()), int(ins_series.max())

    lr = LinearRegression()

    # Tail [a:]
    a_tail = list(range(ins_min, ins_max + 1))
    betas_tail = []
    for a in a_tail:
        sub = points_df[points_df[COL_INS] >= a]
        betas_tail.append(lr.fit(sub[COL_X].to_numpy().reshape(-1, 1), sub[COL_Y]).coef_[0]
                          if len(sub) >= 2 else np.nan)

    # Prefix [:a]
    a_pref = list(range(max(START_PREFIX_AT, 1), ins_max + 1))
    betas_pref = []
    for a in a_pref:
        sub = points_df[points_df[COL_INS] <= a] if PREFIX_MODE == "le" else points_df[points_df[COL_INS] < a]
        betas_pref.append(lr.fit(sub[COL_X].to_numpy().reshape(-1, 1), sub[COL_Y]).coef_[0]
                          if len(sub) >= 2 else np.nan)

    # Exact [exact @ a]
    a_exact = list(range(ins_min, ins_max + 1))
    betas_exact = []
    for a in a_exact:
        sub = points_df[points_df[COL_INS] == a]
        betas_exact.append(lr.fit(sub[COL_X].to_numpy().reshape(-1, 1), sub[COL_Y]).coef_[0]
                           if len(sub) >= 2 else np.nan)

    # Plot
    fig.add_trace(go.Scatter(x=a_tail, y=betas_tail, mode="lines+markers", name=f"N={N} [a:] (tail)"))
    fig.add_trace(go.Scatter(x=a_pref, y=betas_pref, mode="lines+markers", name=f"N={N} [:a] (prefix)"))
    fig.add_trace(go.Scatter(x=a_exact, y=betas_exact, mode="lines+markers", name=f"N={N} [exact @ a]"))

# Guides
if len(fig.data) > 0:
    all_x = np.concatenate([np.asarray(tr.x, dtype=float) for tr in fig.data if len(tr.x)])
    x_min, x_max = int(np.nanmin(all_x)), int(np.nanmax(all_x))
else:
    x_min, x_max = 1, 20

fig.add_trace(go.Scatter(x=[x_min, x_max], y=[0.5, 0.5], mode="lines", line=dict(dash="dash"), name="y = 0.5"))
fig.add_trace(go.Scatter(x=[x_min, x_max], y=[0, 0], mode="lines", name="y = 0"))

fig.update_xaxes(title_text="a (insertion index threshold)", dtick=1)
fig.update_yaxes(title_text="β (slope)")
fig.update_layout(
    title=f"Global β vs a — tail, prefix, exact for GenAI across N",
    template="plotly_white", width=980, height=560
)
fig.show()
# Out:
# [GenAI] total available samples: 164
# [GenAI] N=25: using 25 samples
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:64                                                                                   │
# │                                                                                                  │
# │    61 │   b_dict_filt = {k: b_dict[k] for k in ids_sel if k in b_dict}                           │
# │    62 │   m_dict_filt = {k: m_dict[k] for k in ids_sel if k in m_dict}                           │
# │    63 │                                                                                          │
# │ ❱  64 │   _fig_cut, points_df = global_beta_plot_from_raw(                                       │
# │    65 │   │   b_dict_filt, m_dict_filt, all_series, x,                                           │
# │    66 │   │   hist_steps=hist_steps,                                                             │
# │    67 │   │   gen_block=gen_block,                                                               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'global_beta_plot_from_raw' is not defined

# %% [markdown]
# # check if samples are right with file

# %%
from filtration_utils import jupyter_show_all_ids

# your existing dict:
# experiments = {"Plain": "...", "Heuristic": "...", "GenAI": "..."}

ids_info = jupyter_show_all_ids(experiments)

# Access full ordered lists without sorting:
plain_ids = ids_info["Plain"]["unique_ordered"]
heur_ids  = ids_info["Heuristic"]["unique_ordered"]
genai_ids = ids_info["GenAI"]["unique_ordered"]

# If you want exact per-file batches & iterations:
plain_batches = ids_info["Plain"]["per_file"]

# %%
import json
import pandas as pd

# Load the JSON file
with open("/app/sample_indices_b250_bs4_ins15_cool35.json", "r") as f:
    data = json.load(f)

# Convert to DataFrame
df = pd.DataFrame(data)

# Display the table (each column = one ID in the batch)
df

# %%
import pandas as pd

def ids_to_list_column(ids_list, per_row=4):
    # Group into batches of `per_row` and store as lists
    return [ids_list[i:i+per_row] for i in range(0, len(ids_list), per_row)]

# Build columns for each experiment
col_plain = ids_to_list_column(plain_ids,  per_row=4)
col_heur  = ids_to_list_column(heur_ids,   per_row=4)
col_genai = ids_to_list_column(genai_ids,  per_row=4)

# Align lengths by padding with None
max_len = max(len(col_plain), len(col_heur), len(col_genai))
col_plain += [None] * (max_len - len(col_plain))
col_heur  += [None] * (max_len - len(col_heur))
col_genai += [None] * (max_len - len(col_genai))

# Create DataFrame
df_all = pd.DataFrame({
    "Plain": col_plain,
    "Heuristic": col_heur,
    "GenAI": col_genai
})

display(df_all)
